# %%
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import random
from dreal import *
import matplotlib.patches as patches
from matplotlib import cm

# %%
import sys
import os

sys.path.append(os.path.join(os.path.dirname(os.path.abspath("__file__")), ".."))

from Neural_Density_Training.Models import (
    Polynomial_net,
    Polynomial_net_bias_zero,
    Numerator_polynomial_net,
    GammaFunctionNet,
)
from Neural_Density_Training.loss import (
    stability_loss,
    invariance_loss,
    safety_loss,
)
from Neural_Density_Training.falsifier import checkSMTconstraints, AddCounterexamples
from Neural_Density_Training.extract_model import SymbolicNN, activSymbolicNN
from Neural_Density_Training.plotter import (
    plot_contour_density,
    plot_contour_mixed_density,
)

# %% [markdown]
# ## Sample Data
#
# We will use seed to ensure the reproducibility

# %%
torch.cuda.empty_cache()
torch.manual_seed(17)
random.seed()

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Pre-allocate numerical_x
numerical_x = torch.Tensor(2000, 2).uniform_(-6, 6).float().to(device)
# Out:
# Using device: cpu

# %% [markdown]
# ## Define the Dynamics:
#
# We will define the dynamics of the system below. In particular, the dynamics must be described as following:
# \begin{align}
#     \dot{x}=f(x)+g(x)u(x)
# \end{align}

# %%
def f(x):
    """ Vectorized example 2 dynamics f(x)- handles batched input"""
    if x.dim() == 1:
        x = x.unsqueeze(0)  # Add batch dimension if input is 1D
    
    val = torch.stack([
        2 * (x[:,0]**3) + (x[:,0]**2) * x[:,1]-6*x[:,0]*(x[:,1]**2) + 5 * x[:,1]**3, torch.zeros_like(x[:,0])
    ], dim=1)

    return val.squeeze(0) if val.shape[0] == 1 else val

def g(x):
    """Vectorized g(x) - handles batched input"""
    if x.dim() == 1:
        x = x.unsqueeze(0)
    
    val = torch.stack([
        torch.zeros_like(x[:, 0]),
        torch.ones_like(x[:, 0])
    ], dim=1)

    return val.squeeze(0) if val.shape[0] == 1 else val

def div_f(x):
    """vectorized divergence of f"""
    divergence = 6 * (x[:, 0]**2) + 2 * x[:, 0] * x[:, 1] - 6 * (x[:, 1]**2)
    return divergence if divergence.dim() == 1 else divergence.squeeze(1)
def div_g(x):
    """vectorized divergence of g"""
    return torch.zeros(x.shape[0], device=device)

# %% [markdown]
# ## Describe the constraints
#
# Ideally I would have want this to be automated through utils file as well but sadly dreal doesn't process the functions quite well and hence has to be done manually.

# %%
def candidate_constraint_learnt(vars,a_fun,b_fun,c_fun):
    """
    Construct candidate constraints for the learnt functions.
    
    Args:
        vars: List of dReal Variables
        a_fun: Function representing a(x).
        b_fun: Function representing b(x).
        c_fun: Function representing c(x).

    Returns:
        Symbolic expression for the candidate constraint.
    """
    a_sym = activSymbolicNN(a_fun).forward_symbolic(vars)[0]
    b_sym = SymbolicNN(b_fun).forward_symbolic(vars)
    c_sym = SymbolicNN(c_fun).forward_symbolic(vars)[0]

    # b_sym = ||b_sym||^2
    b_sym = sum([bi**2 for bi in b_sym])
    # write f and g in terms of val
    f_val = [2*(vars[0]**3)+(vars[0]**2)*vars[1]-6*vars[0]*(vars[1]**2)+5*vars[1]**3, 0]
    # print("f_val: ", f_val)
    g_val = [0*vars[0],1]
    # print("g_val: ", g_val)
    f_div = 6*(vars[0]**2) + 2 * vars[0] * vars[1] - 6 * (vars[1]**2) 
    g_div = 0 
    grad_a = [a_sym.Differentiate(vars[i]) for i in range(len(vars))]
    grad_c = [c_sym.Differentiate(vars[i]) for i in range(len(vars))]
    grad_b = [b_sym.Differentiate(vars[i]) for i in range(len(vars))]

    constraint1 = a_sym * f_div + g_div * c_sym + sum([grad_a[i] * f_val[i] for i in range(len(f_val))]) + sum([grad_c[i] * g_val[i] for i in range(len(g_val))])
  
    scaled_vars = [2 * var_i for var_i in vars]
    constraint2 = [scaled_vars[i] + grad_b[i] for i in range(len(vars))]

    constraint2 = sum([constraint2[i] * (f_val[i] * a_sym + g_val[i] * c_sym) for i in range(len(f_val))])  
    constraint = constraint1 - constraint2
    return a_sym , constraint

# %%
def train_density(
    x,                          # initial sample tensor  [N, state_dim]
    f,                          # dynamics callable
    g,                          # control matrix callable
    div_f,                      # divergence of f callable
    div_g,                      # divergence of g callable
    device,
    # --- training ---
    epochs          = 2000,
    lr              = 1e-2,
    loss_threshold  = 5e-4,
    # --- SMT verification ---
    ball_lb         = 0.05,
    ball_ub         = 6.0,
    check_interval  = 10,
    n_counterex     = 100,
):
    
    # Instantiate neural networks for a, b, c, gamma
    a_net = Numerator_polynomial_net(layers=2, input_dim=2, hidden_dim=1, output_dim=1).to(device)
    b_net = Polynomial_net_bias_zero(layers=2, input_dim=2, hidden_dim=1, output_dim=1).to(device)
    c_net = Polynomial_net(layers=4, input_dim=2, hidden_dim=3, output_dim=1).to(device)
    gamma_net = GammaFunctionNet(input_dim=2,output_dim=1).to(device)


    
    # Loss and Optimizer
    criterion = stability_loss(f=f,g=g,div_f=div_f,div_g=div_g)



    optimizer = torch.optim.Adam(list(a_net.parameters()) +
                                    list(b_net.parameters()) + 
                                    list(c_net.parameters()) + 
                                    list(gamma_net.parameters()), lr=lr)
    
    # dReal Configuration
    config = Config()
    config.use_polytope_in_forall = True
    config.use_local_optimization = True
    config.precision = 1e-5   

    # CEGIS Loop
    loss_history = []
    valid = False 
    print("=" * 60)
    print("Training density function with SMT-CEGIS verification")
    print(f"  Initial dataset size: {x.shape[0]}")
    print("=" * 60)    

    while not valid:
        for epoch in range(epochs):
            optimizer.zero_grad()
            loss = criterion(x, a_net, b_net, c_net, gamma_net)   
            loss_history.append(loss.item())
            loss.backward()
            optimizer.step()

            
            # ---------- early-exit on convergence ----------
            if loss.item() < loss_threshold:
                print(f"  [Epoch {epoch}] Loss {loss.item():.6f} < threshold to checking SMT...")
                valid = True
                break

            # ---------- periodic progress print ------------
            if epoch % 50 == 0:
                print(
                    f"  Epoch {epoch:>5}/{epochs} | "
                    f"Loss: {loss.item():.6f} | "
                    f"Dataset: {x.shape[0]}"
                )            
 
            # ---------- SMT counterexample check -----------
            if epoch % check_interval == 0 and epoch > 0:
                vars_sym = [Variable("x1"), Variable("x2")]
                try:
                    a_sym, div_sym = candidate_constraint_learnt(
                        vars_sym, a_net, b_net, c_net
                    )
                    CE = checkSMTconstraints(
                        vars_sym, a_sym, div_sym, ball_lb, ball_ub, config
                    )
 
                    if CE:
                        before = x.shape[0]
                        x, _ = AddCounterexamples(x, CE, n_counterex, device)
                        after = x.shape[0]
                        print(
                            f"  [Epoch {epoch}] CE found → "
                            f"dataset {before} → {after} (+{after - before})"
                        )
                    else:
                        valid = True
                        print(f"  [Epoch {epoch}] SMT satisfied — no counterexample found ✓")
                        break
 
                except Exception as e:
                    print(f"  [Epoch {epoch}] SMT check failed: {e}")
                    continue
 
    # ------------------------------------------------------------------
    # 5. Final summary
    # ------------------------------------------------------------------
    test_point = torch.zeros(1, 2, dtype=torch.float32, device=device)
    margin     = gamma_net(test_point).item()
 
    print("\n" + "=" * 60)
    print("Training complete")
    print(f"  Final loss     : {loss_history[-1]:.6f}")
    print(f"  Learned margin : {margin:.6f}")
    print(f"  Final dataset  : {x.shape[0]}")
    print("=" * 60)
 
    return loss_history, a_net, b_net, c_net, gamma_net

# %%
print("Starting training...")
loss_history1, a_net1, b_net1, c_net1, gamma_net1 = train_density(
    numerical_x, f, g, div_f, div_g, device,
    epochs=4000,
    lr=1e-3,
    loss_threshold=5e-3,
    ball_lb=0.05,
    ball_ub=6.0,
    check_interval=3000,
    n_counterex=100
)
# Out:
# Starting training...
# ============================================================
# Training density function with SMT-CEGIS verification
#   Initial dataset size: 2000
# ============================================================
#   Epoch     0/4000 | Loss: 278.034393 | Dataset: 2000
#   Epoch    50/4000 | Loss: 264.545959 | Dataset: 2000
#   Epoch   100/4000 | Loss: 250.742813 | Dataset: 2000
#   Epoch   150/4000 | Loss: 235.790649 | Dataset: 2000
#   Epoch   200/4000 | Loss: 219.418991 | Dataset: 2000
#   Epoch   250/4000 | Loss: 203.130371 | Dataset: 2000
#   Epoch   300/4000 | Loss: 187.309555 | Dataset: 2000
#   Epoch   350/4000 | Loss: 171.111694 | Dataset: 2000
#   Epoch   400/4000 | Loss: 154.719055 | Dataset: 2000
#   Epoch   450/4000 | Loss: 138.998856 | Dataset: 2000
#   Epoch   500/4000 | Loss: 124.955727 | Dataset: 2000
#   Epoch   550/4000 | Loss: 112.975197 | Dataset: 2000
#   Epoch   600/4000 | Loss: 102.750214 | Dataset: 2000
#   Epoch   650/4000 | Loss: 93.823784 | Dataset: 2000
#   Epoch   700/4000 | Loss: 85.857964 | Dataset: 2000
#   Epoch   750/4000 | Loss: 78.664848 | Dataset: 2000
#   Epoch   800/4000 | Loss: 72.145485 | Dataset: 2000
#   Epoch   850/4000 | Loss: 66.212860 | Dataset: 2000
#   Epoch   900/4000 | Loss: 60.795052 | Dataset: 2000
#   Epoch   950/4000 | Loss: 55.848511 | Dataset: 2000
#   Epoch  1000/4000 | Loss: 51.350689 | Dataset: 2000
#   Epoch  1050/4000 | Loss: 47.235931 | Dataset: 2000
#   Epoch  1100/4000 | Loss: 43.473312 | Dataset: 2000
#   Epoch  1150/4000 | Loss: 40.021744 | Dataset: 2000
#   Epoch  1200/4000 | Loss: 36.857010 | Dataset: 2000
#   Epoch  1250/4000 | Loss: 33.958492 | Dataset: 2000
#   Epoch  1300/4000 | Loss: 31.286715 | Dataset: 2000
#   Epoch  1350/4000 | Loss: 28.811420 | Dataset: 2000
#   Epoch  1400/4000 | Loss: 26.544352 | Dataset: 2000
#   Epoch  1450/4000 | Loss: 24.463106 | Dataset: 2000
#   Epoch  1500/4000 | Loss: 22.566298 | Dataset: 2000
#   Epoch  1550/4000 | Loss: 20.845772 | Dataset: 2000
#   Epoch  1600/4000 | Loss: 19.274008 | Dataset: 2000
#   Epoch  1650/4000 | Loss: 17.827454 | Dataset: 2000
#   Epoch  1700/4000 | Loss: 16.509499 | Dataset: 2000
#   Epoch  1750/4000 | Loss: 15.313366 | Dataset: 2000
#   Epoch  1800/4000 | Loss: 14.228855 | Dataset: 2000
#   Epoch  1850/4000 | Loss: 13.223490 | Dataset: 2000
#   Epoch  1900/4000 | Loss: 12.310556 | Dataset: 2000
#   Epoch  1950/4000 | Loss: 11.477842 | Dataset: 2000
#   Epoch  2000/4000 | Loss: 10.709532 | Dataset: 2000
#   Epoch  2050/4000 | Loss: 10.014721 | Dataset: 2000
#   Epoch  2100/4000 | Loss: 9.389326 | Dataset: 2000
#   Epoch  2150/4000 | Loss: 8.822410 | Dataset: 2000
#   Epoch  2200/4000 | Loss: 8.314460 | Dataset: 2000
#   Epoch  2250/4000 | Loss: 7.867162 | Dataset: 2000
#   Epoch  2300/4000 | Loss: 7.453070 | Dataset: 2000
#   Epoch  2350/4000 | Loss: 7.073422 | Dataset: 2000
#   Epoch  2400/4000 | Loss: 6.721099 | Dataset: 2000
#   Epoch  2450/4000 | Loss: 6.399170 | Dataset: 2000
#   Epoch  2500/4000 | Loss: 6.102345 | Dataset: 2000
#   Epoch  2550/4000 | Loss: 5.825858 | Dataset: 2000
#   Epoch  2600/4000 | Loss: 5.572499 | Dataset: 2000
#   Epoch  2650/4000 | Loss: 5.329761 | Dataset: 2000
#   Epoch  2700/4000 | Loss: 5.100580 | Dataset: 2000
#   Epoch  2750/4000 | Loss: 4.886976 | Dataset: 2000
#   Epoch  2800/4000 | Loss: 4.684383 | Dataset: 2000
#   Epoch  2850/4000 | Loss: 4.497496 | Dataset: 2000
#   Epoch  2900/4000 | Loss: 4.331239 | Dataset: 2000
#   Epoch  2950/4000 | Loss: 4.176884 | Dataset: 2000
#   Epoch  3000/4000 | Loss: 4.030296 | Dataset: 2000
#   [Epoch 3000] CE found → dataset 2000 → 2100 (+100)
#   Epoch  3050/4000 | Loss: 3.707383 | Dataset: 2100
#   Epoch  3100/4000 | Loss: 3.580829 | Dataset: 2100
#   Epoch  3150/4000 | Loss: 3.458600 | Dataset: 2100
#   Epoch  3200/4000 | Loss: 3.341964 | Dataset: 2100
#   Epoch  3250/4000 | Loss: 3.228224 | Dataset: 2100
#   Epoch  3300/4000 | Loss: 3.119665 | Dataset: 2100
#   Epoch  3350/4000 | Loss: 3.014676 | Dataset: 2100
#   Epoch  3400/4000 | Loss: 2.912814 | Dataset: 2100
#   Epoch  3450/4000 | Loss: 2.812875 | Dataset: 2100
#   Epoch  3500/4000 | Loss: 2.716016 | Dataset: 2100
#   Epoch  3550/4000 | Loss: 2.623390 | Dataset: 2100
#   Epoch  3600/4000 | Loss: 2.536649 | Dataset: 2100
#   Epoch  3650/4000 | Loss: 2.452720 | Dataset: 2100
#   Epoch  3700/4000 | Loss: 2.371362 | Dataset: 2100
#   Epoch  3750/4000 | Loss: 2.292346 | Dataset: 2100
#   Epoch  3800/4000 | Loss: 2.215996 | Dataset: 2100
#   Epoch  3850/4000 | Loss: 2.142424 | Dataset: 2100
#   Epoch  3900/4000 | Loss: 2.071663 | Dataset: 2100
#   Epoch  3950/4000 | Loss: 2.002896 | Dataset: 2100
#   Epoch     0/4000 | Loss: 1.936823 | Dataset: 2100
#   Epoch    50/4000 | Loss: 1.874127 | Dataset: 2100
#   Epoch   100/4000 | Loss: 1.815924 | Dataset: 2100
#   Epoch   150/4000 | Loss: 1.762664 | Dataset: 2100
#   Epoch   200/4000 | Loss: 1.711321 | Dataset: 2100
#   Epoch   250/4000 | Loss: 1.661333 | Dataset: 2100
#   Epoch   300/4000 | Loss: 1.613151 | Dataset: 2100
#   Epoch   350/4000 | Loss: 1.566183 | Dataset: 2100
#   Epoch   400/4000 | Loss: 1.520171 | Dataset: 2100
#   Epoch   450/4000 | Loss: 1.475393 | Dataset: 2100
#   Epoch   500/4000 | Loss: 1.432318 | Dataset: 2100
#   Epoch   550/4000 | Loss: 1.389751 | Dataset: 2100
#   Epoch   600/4000 | Loss: 1.347699 | Dataset: 2100
#   Epoch   650/4000 | Loss: 1.306230 | Dataset: 2100
#   Epoch   700/4000 | Loss: 1.265828 | Dataset: 2100
#   Epoch   750/4000 | Loss: 1.226772 | Dataset: 2100
#   Epoch   800/4000 | Loss: 1.188756 | Dataset: 2100
#   Epoch   850/4000 | Loss: 1.152806 | Dataset: 2100
#   Epoch   900/4000 | Loss: 1.118460 | Dataset: 2100
#   Epoch   950/4000 | Loss: 1.085256 | Dataset: 2100
#   Epoch  1000/4000 | Loss: 1.052529 | Dataset: 2100
#   Epoch  1050/4000 | Loss: 1.020608 | Dataset: 2100
#   Epoch  1100/4000 | Loss: 0.989850 | Dataset: 2100
#   Epoch  1150/4000 | Loss: 0.960191 | Dataset: 2100
#   Epoch  1200/4000 | Loss: 0.931621 | Dataset: 2100
#   Epoch  1250/4000 | Loss: 0.903556 | Dataset: 2100
#   Epoch  1300/4000 | Loss: 0.876500 | Dataset: 2100
#   Epoch  1350/4000 | Loss: 0.851315 | Dataset: 2100
#   Epoch  1400/4000 | Loss: 0.826859 | Dataset: 2100
#   Epoch  1450/4000 | Loss: 0.802607 | Dataset: 2100
#   Epoch  1500/4000 | Loss: 0.778572 | Dataset: 2100
#   Epoch  1550/4000 | Loss: 0.755087 | Dataset: 2100
#   Epoch  1600/4000 | Loss: 0.732347 | Dataset: 2100
#   Epoch  1650/4000 | Loss: 0.711115 | Dataset: 2100
#   Epoch  1700/4000 | Loss: 0.690491 | Dataset: 2100
#   Epoch  1750/4000 | Loss: 0.670450 | Dataset: 2100
#   Epoch  1800/4000 | Loss: 0.651199 | Dataset: 2100
#   Epoch  1850/4000 | Loss: 0.632719 | Dataset: 2100
#   Epoch  1900/4000 | Loss: 0.614788 | Dataset: 2100
#   Epoch  1950/4000 | Loss: 0.597218 | Dataset: 2100
#   Epoch  2000/4000 | Loss: 0.580183 | Dataset: 2100
#   Epoch  2050/4000 | Loss: 0.563643 | Dataset: 2100
#   Epoch  2100/4000 | Loss: 0.547494 | Dataset: 2100
#   Epoch  2150/4000 | Loss: 0.531772 | Dataset: 2100
#   Epoch  2200/4000 | Loss: 0.517074 | Dataset: 2100
#   Epoch  2250/4000 | Loss: 0.502730 | Dataset: 2100
#   Epoch  2300/4000 | Loss: 0.488503 | Dataset: 2100
#   Epoch  2350/4000 | Loss: 0.474339 | Dataset: 2100
#   Epoch  2400/4000 | Loss: 0.460330 | Dataset: 2100
#   Epoch  2450/4000 | Loss: 0.446656 | Dataset: 2100
#   Epoch  2500/4000 | Loss: 0.433246 | Dataset: 2100
#   Epoch  2550/4000 | Loss: 0.420121 | Dataset: 2100
#   Epoch  2600/4000 | Loss: 0.407265 | Dataset: 2100
#   Epoch  2650/4000 | Loss: 0.395240 | Dataset: 2100
#   Epoch  2700/4000 | Loss: 0.383928 | Dataset: 2100
#   Epoch  2750/4000 | Loss: 0.373021 | Dataset: 2100
#   Epoch  2800/4000 | Loss: 0.362807 | Dataset: 2100
#   Epoch  2850/4000 | Loss: 0.352704 | Dataset: 2100
#   Epoch  2900/4000 | Loss: 0.342860 | Dataset: 2100
#   Epoch  2950/4000 | Loss: 0.333240 | Dataset: 2100
#   Epoch  3000/4000 | Loss: 0.323791 | Dataset: 2100
#   [Epoch 3000] CE found → dataset 2100 → 2200 (+100)
#   Epoch  3050/4000 | Loss: 0.300683 | Dataset: 2200
#   Epoch  3100/4000 | Loss: 0.292204 | Dataset: 2200
#   Epoch  3150/4000 | Loss: 0.284157 | Dataset: 2200
#   Epoch  3200/4000 | Loss: 0.276243 | Dataset: 2200
#   Epoch  3250/4000 | Loss: 0.268553 | Dataset: 2200
#   Epoch  3300/4000 | Loss: 0.261008 | Dataset: 2200
#   Epoch  3350/4000 | Loss: 0.253490 | Dataset: 2200
#   Epoch  3400/4000 | Loss: 0.246060 | Dataset: 2200
#   Epoch  3450/4000 | Loss: 0.238950 | Dataset: 2200
#   Epoch  3500/4000 | Loss: 0.232064 | Dataset: 2200
#   Epoch  3550/4000 | Loss: 0.225805 | Dataset: 2200
#   Epoch  3600/4000 | Loss: 0.220146 | Dataset: 2200
#   Epoch  3650/4000 | Loss: 0.214596 | Dataset: 2200
#   Epoch  3700/4000 | Loss: 0.209231 | Dataset: 2200
#   Epoch  3750/4000 | Loss: 0.204049 | Dataset: 2200
#   Epoch  3800/4000 | Loss: 0.198886 | Dataset: 2200
#   Epoch  3850/4000 | Loss: 0.193988 | Dataset: 2200
#   Epoch  3900/4000 | Loss: 0.189373 | Dataset: 2200
#   Epoch  3950/4000 | Loss: 0.185071 | Dataset: 2200
#   Epoch     0/4000 | Loss: 0.181057 | Dataset: 2200
#   Epoch    50/4000 | Loss: 0.177233 | Dataset: 2200
#   Epoch   100/4000 | Loss: 0.173443 | Dataset: 2200
#   Epoch   150/4000 | Loss: 0.169650 | Dataset: 2200
#   Epoch   200/4000 | Loss: 0.165857 | Dataset: 2200
#   Epoch   250/4000 | Loss: 0.162073 | Dataset: 2200
#   Epoch   300/4000 | Loss: 0.158484 | Dataset: 2200
#   Epoch   350/4000 | Loss: 0.154924 | Dataset: 2200
#   Epoch   400/4000 | Loss: 0.151386 | Dataset: 2200
#   Epoch   450/4000 | Loss: 0.147921 | Dataset: 2200
#   Epoch   500/4000 | Loss: 0.144469 | Dataset: 2200
#   Epoch   550/4000 | Loss: 0.141015 | Dataset: 2200
#   Epoch   600/4000 | Loss: 0.137548 | Dataset: 2200
#   Epoch   650/4000 | Loss: 0.134265 | Dataset: 2200
#   Epoch   700/4000 | Loss: 0.131190 | Dataset: 2200
#   Epoch   750/4000 | Loss: 0.128144 | Dataset: 2200
#   Epoch   800/4000 | Loss: 0.125260 | Dataset: 2200
#   Epoch   850/4000 | Loss: 0.122525 | Dataset: 2200
#   Epoch   900/4000 | Loss: 0.119905 | Dataset: 2200
#   Epoch   950/4000 | Loss: 0.117298 | Dataset: 2200
#   Epoch  1000/4000 | Loss: 0.114711 | Dataset: 2200
#   Epoch  1050/4000 | Loss: 0.112197 | Dataset: 2200
#   Epoch  1100/4000 | Loss: 0.109764 | Dataset: 2200
#   Epoch  1150/4000 | Loss: 0.107393 | Dataset: 2200
#   Epoch  1200/4000 | Loss: 0.105201 | Dataset: 2200
#   Epoch  1250/4000 | Loss: 0.103043 | Dataset: 2200
#   Epoch  1300/4000 | Loss: 0.100892 | Dataset: 2200
#   Epoch  1350/4000 | Loss: 0.098721 | Dataset: 2200
#   Epoch  1400/4000 | Loss: 0.096594 | Dataset: 2200
#   Epoch  1450/4000 | Loss: 0.094512 | Dataset: 2200
#   Epoch  1500/4000 | Loss: 0.092496 | Dataset: 2200
#   Epoch  1550/4000 | Loss: 0.090486 | Dataset: 2200
#   Epoch  1600/4000 | Loss: 0.088571 | Dataset: 2200
#   Epoch  1650/4000 | Loss: 0.086820 | Dataset: 2200
#   Epoch  1700/4000 | Loss: 0.085133 | Dataset: 2200
#   Epoch  1750/4000 | Loss: 0.083593 | Dataset: 2200
#   Epoch  1800/4000 | Loss: 0.082295 | Dataset: 2200
#   Epoch  1850/4000 | Loss: 0.081078 | Dataset: 2200
#   Epoch  1900/4000 | Loss: 0.079871 | Dataset: 2200
#   Epoch  1950/4000 | Loss: 0.078645 | Dataset: 2200
#   Epoch  2000/4000 | Loss: 0.077439 | Dataset: 2200
#   Epoch  2050/4000 | Loss: 0.076253 | Dataset: 2200
#   Epoch  2100/4000 | Loss: 0.075078 | Dataset: 2200
#   Epoch  2150/4000 | Loss: 0.073902 | Dataset: 2200
#   Epoch  2200/4000 | Loss: 0.072729 | Dataset: 2200
#   Epoch  2250/4000 | Loss: 0.071596 | Dataset: 2200
#   Epoch  2300/4000 | Loss: 0.070569 | Dataset: 2200
#   Epoch  2350/4000 | Loss: 0.069598 | Dataset: 2200
#   Epoch  2400/4000 | Loss: 0.068630 | Dataset: 2200
#   Epoch  2450/4000 | Loss: 0.067663 | Dataset: 2200
#   Epoch  2500/4000 | Loss: 0.066690 | Dataset: 2200
#   Epoch  2550/4000 | Loss: 0.065723 | Dataset: 2200
#   Epoch  2600/4000 | Loss: 0.064815 | Dataset: 2200
#   Epoch  2650/4000 | Loss: 0.063979 | Dataset: 2200
#   Epoch  2700/4000 | Loss: 0.063160 | Dataset: 2200
#   Epoch  2750/4000 | Loss: 0.062359 | Dataset: 2200
#   Epoch  2800/4000 | Loss: 0.061575 | Dataset: 2200
#   Epoch  2850/4000 | Loss: 0.060812 | Dataset: 2200
#   Epoch  2900/4000 | Loss: 0.060066 | Dataset: 2200
#   Epoch  2950/4000 | Loss: 0.059325 | Dataset: 2200
#   Epoch  3000/4000 | Loss: 0.058632 | Dataset: 2200
#   [Epoch 3000] CE found → dataset 2200 → 2299 (+99)
#   Epoch  3050/4000 | Loss: 0.055642 | Dataset: 2299
#   Epoch  3100/4000 | Loss: 0.054899 | Dataset: 2299
#   Epoch  3150/4000 | Loss: 0.054308 | Dataset: 2299
#   Epoch  3200/4000 | Loss: 0.053718 | Dataset: 2299
#   Epoch  3250/4000 | Loss: 0.053125 | Dataset: 2299
#   Epoch  3300/4000 | Loss: 0.052532 | Dataset: 2299
#   Epoch  3350/4000 | Loss: 0.051949 | Dataset: 2299
#   Epoch  3400/4000 | Loss: 0.051385 | Dataset: 2299
#   Epoch  3450/4000 | Loss: 0.050822 | Dataset: 2299
#   Epoch  3500/4000 | Loss: 0.050259 | Dataset: 2299
#   Epoch  3550/4000 | Loss: 0.049696 | Dataset: 2299
#   Epoch  3600/4000 | Loss: 0.049131 | Dataset: 2299
#   Epoch  3650/4000 | Loss: 0.048565 | Dataset: 2299
#   Epoch  3700/4000 | Loss: 0.048000 | Dataset: 2299
#   Epoch  3750/4000 | Loss: 0.047434 | Dataset: 2299
#   Epoch  3800/4000 | Loss: 0.046868 | Dataset: 2299
#   Epoch  3850/4000 | Loss: 0.046303 | Dataset: 2299
#   Epoch  3900/4000 | Loss: 0.045735 | Dataset: 2299
#   Epoch  3950/4000 | Loss: 0.045169 | Dataset: 2299
#   Epoch     0/4000 | Loss: 0.044606 | Dataset: 2299
#   Epoch    50/4000 | Loss: 0.044039 | Dataset: 2299
#   Epoch   100/4000 | Loss: 0.043476 | Dataset: 2299
#   Epoch   150/4000 | Loss: 0.042912 | Dataset: 2299
#   Epoch   200/4000 | Loss: 0.042348 | Dataset: 2299
#   Epoch   250/4000 | Loss: 0.041788 | Dataset: 2299
#   Epoch   300/4000 | Loss: 0.041227 | Dataset: 2299
#   Epoch   350/4000 | Loss: 0.040714 | Dataset: 2299
#   Epoch   400/4000 | Loss: 0.040210 | Dataset: 2299
#   Epoch   450/4000 | Loss: 0.039709 | Dataset: 2299
#   Epoch   500/4000 | Loss: 0.039208 | Dataset: 2299
#   Epoch   550/4000 | Loss: 0.038709 | Dataset: 2299
#   Epoch   600/4000 | Loss: 0.038213 | Dataset: 2299
#   Epoch   650/4000 | Loss: 0.037715 | Dataset: 2299
#   Epoch   700/4000 | Loss: 0.037222 | Dataset: 2299
#   Epoch   750/4000 | Loss: 0.036729 | Dataset: 2299
#   Epoch   800/4000 | Loss: 0.036275 | Dataset: 2299
#   Epoch   850/4000 | Loss: 0.035846 | Dataset: 2299
#   Epoch   900/4000 | Loss: 0.035418 | Dataset: 2299
#   Epoch   950/4000 | Loss: 0.034991 | Dataset: 2299
#   Epoch  1000/4000 | Loss: 0.034568 | Dataset: 2299
#   Epoch  1050/4000 | Loss: 0.034147 | Dataset: 2299
#   Epoch  1100/4000 | Loss: 0.033723 | Dataset: 2299
#   Epoch  1150/4000 | Loss: 0.033335 | Dataset: 2299
#   Epoch  1200/4000 | Loss: 0.032959 | Dataset: 2299
#   Epoch  1250/4000 | Loss: 0.032593 | Dataset: 2299
#   Epoch  1300/4000 | Loss: 0.032233 | Dataset: 2299
#   Epoch  1350/4000 | Loss: 0.031859 | Dataset: 2299
#   Epoch  1400/4000 | Loss: 0.031501 | Dataset: 2299
#   Epoch  1450/4000 | Loss: 0.031131 | Dataset: 2299
#   Epoch  1500/4000 | Loss: 0.030775 | Dataset: 2299
#   Epoch  1550/4000 | Loss: 0.030409 | Dataset: 2299
#   Epoch  1600/4000 | Loss: 0.030054 | Dataset: 2299
#   Epoch  1650/4000 | Loss: 0.029701 | Dataset: 2299
#   Epoch  1700/4000 | Loss: 0.029373 | Dataset: 2299
#   Epoch  1750/4000 | Loss: 0.029066 | Dataset: 2299
#   Epoch  1800/4000 | Loss: 0.028768 | Dataset: 2299
#   Epoch  1850/4000 | Loss: 0.028466 | Dataset: 2299
#   Epoch  1900/4000 | Loss: 0.028161 | Dataset: 2299
#   Epoch  1950/4000 | Loss: 0.027860 | Dataset: 2299
#   Epoch  2000/4000 | Loss: 0.027569 | Dataset: 2299
#   Epoch  2050/4000 | Loss: 0.027283 | Dataset: 2299
#   Epoch  2100/4000 | Loss: 0.027015 | Dataset: 2299
#   Epoch  2150/4000 | Loss: 0.026739 | Dataset: 2299
#   Epoch  2200/4000 | Loss: 0.026477 | Dataset: 2299
#   Epoch  2250/4000 | Loss: 0.026217 | Dataset: 2299
#   Epoch  2300/4000 | Loss: 0.025947 | Dataset: 2299
#   Epoch  2350/4000 | Loss: 0.025708 | Dataset: 2299
#   Epoch  2400/4000 | Loss: 0.025460 | Dataset: 2299
#   Epoch  2450/4000 | Loss: 0.025226 | Dataset: 2299
#   Epoch  2500/4000 | Loss: 0.024995 | Dataset: 2299
#   Epoch  2550/4000 | Loss: 0.024781 | Dataset: 2299
#   Epoch  2600/4000 | Loss: 0.024562 | Dataset: 2299
#   Epoch  2650/4000 | Loss: 0.024337 | Dataset: 2299
#   Epoch  2700/4000 | Loss: 0.024126 | Dataset: 2299
#   Epoch  2750/4000 | Loss: 0.023902 | Dataset: 2299
#   Epoch  2800/4000 | Loss: 0.023683 | Dataset: 2299
#   Epoch  2850/4000 | Loss: 0.023460 | Dataset: 2299
#   Epoch  2900/4000 | Loss: 0.023233 | Dataset: 2299
#   Epoch  2950/4000 | Loss: 0.023017 | Dataset: 2299
#   Epoch  3000/4000 | Loss: 0.022795 | Dataset: 2299
#   [Epoch 3000] CE found → dataset 2299 → 2306 (+7)
#   Epoch  3050/4000 | Loss: 0.022507 | Dataset: 2306
#   Epoch  3100/4000 | Loss: 0.022274 | Dataset: 2306
#   Epoch  3150/4000 | Loss: 0.022052 | Dataset: 2306
#   Epoch  3200/4000 | Loss: 0.021828 | Dataset: 2306
#   Epoch  3250/4000 | Loss: 0.021602 | Dataset: 2306
#   Epoch  3300/4000 | Loss: 0.021379 | Dataset: 2306
#   Epoch  3350/4000 | Loss: 0.021154 | Dataset: 2306
#   Epoch  3400/4000 | Loss: 0.020927 | Dataset: 2306
#   Epoch  3450/4000 | Loss: 0.020702 | Dataset: 2306
#   Epoch  3500/4000 | Loss: 0.020476 | Dataset: 2306
#   Epoch  3550/4000 | Loss: 0.020249 | Dataset: 2306
#   Epoch  3600/4000 | Loss: 0.020022 | Dataset: 2306
#   Epoch  3650/4000 | Loss: 0.019794 | Dataset: 2306
#   Epoch  3700/4000 | Loss: 0.019568 | Dataset: 2306
#   Epoch  3750/4000 | Loss: 0.019338 | Dataset: 2306
#   Epoch  3800/4000 | Loss: 0.019111 | Dataset: 2306
#   Epoch  3850/4000 | Loss: 0.018881 | Dataset: 2306
#   Epoch  3900/4000 | Loss: 0.018654 | Dataset: 2306
#   Epoch  3950/4000 | Loss: 0.018424 | Dataset: 2306
#   Epoch     0/4000 | Loss: 0.018196 | Dataset: 2306
#   Epoch    50/4000 | Loss: 0.017965 | Dataset: 2306
#   Epoch   100/4000 | Loss: 0.017744 | Dataset: 2306
#   Epoch   150/4000 | Loss: 0.017510 | Dataset: 2306
#   Epoch   200/4000 | Loss: 0.017277 | Dataset: 2306
#   Epoch   250/4000 | Loss: 0.017056 | Dataset: 2306
#   Epoch   300/4000 | Loss: 0.016822 | Dataset: 2306
#   Epoch   350/4000 | Loss: 0.016587 | Dataset: 2306
#   Epoch   400/4000 | Loss: 0.016358 | Dataset: 2306
#   Epoch   450/4000 | Loss: 0.016126 | Dataset: 2306
#   Epoch   500/4000 | Loss: 0.015895 | Dataset: 2306
#   Epoch   550/4000 | Loss: 0.015666 | Dataset: 2306
#   Epoch   600/4000 | Loss: 0.015435 | Dataset: 2306
#   Epoch   650/4000 | Loss: 0.015211 | Dataset: 2306
#   Epoch   700/4000 | Loss: 0.014977 | Dataset: 2306
#   Epoch   750/4000 | Loss: 0.014745 | Dataset: 2306
#   Epoch   800/4000 | Loss: 0.014512 | Dataset: 2306
#   Epoch   850/4000 | Loss: 0.014287 | Dataset: 2306
#   Epoch   900/4000 | Loss: 0.014056 | Dataset: 2306
#   Epoch   950/4000 | Loss: 0.013822 | Dataset: 2306
#   Epoch  1000/4000 | Loss: 0.013592 | Dataset: 2306
#   Epoch  1050/4000 | Loss: 0.013361 | Dataset: 2306
#   Epoch  1100/4000 | Loss: 0.013132 | Dataset: 2306
#   Epoch  1150/4000 | Loss: 0.012911 | Dataset: 2306
#   Epoch  1200/4000 | Loss: 0.012675 | Dataset: 2306
#   Epoch  1250/4000 | Loss: 0.012446 | Dataset: 2306
#   Epoch  1300/4000 | Loss: 0.012214 | Dataset: 2306
#   Epoch  1350/4000 | Loss: 0.011984 | Dataset: 2306
#   Epoch  1400/4000 | Loss: 0.011756 | Dataset: 2306
#   Epoch  1450/4000 | Loss: 0.011527 | Dataset: 2306
#   Epoch  1500/4000 | Loss: 0.011298 | Dataset: 2306
#   Epoch  1550/4000 | Loss: 0.011077 | Dataset: 2306
#   Epoch  1600/4000 | Loss: 0.010845 | Dataset: 2306
#   Epoch  1650/4000 | Loss: 0.010618 | Dataset: 2306
#   Epoch  1700/4000 | Loss: 0.010390 | Dataset: 2306
#   Epoch  1750/4000 | Loss: 0.010163 | Dataset: 2306
#   Epoch  1800/4000 | Loss: 0.009938 | Dataset: 2306
#   Epoch  1850/4000 | Loss: 0.009711 | Dataset: 2306
#   Epoch  1900/4000 | Loss: 0.009486 | Dataset: 2306
#   Epoch  1950/4000 | Loss: 0.009261 | Dataset: 2306
#   Epoch  2000/4000 | Loss: 0.009041 | Dataset: 2306
#   Epoch  2050/4000 | Loss: 0.008815 | Dataset: 2306
#   Epoch  2100/4000 | Loss: 0.008591 | Dataset: 2306
#   Epoch  2150/4000 | Loss: 0.008368 | Dataset: 2306
#   Epoch  2200/4000 | Loss: 0.008143 | Dataset: 2306
#   Epoch  2250/4000 | Loss: 0.007921 | Dataset: 2306
#   Epoch  2300/4000 | Loss: 0.007700 | Dataset: 2306
#   Epoch  2350/4000 | Loss: 0.007479 | Dataset: 2306
#   Epoch  2400/4000 | Loss: 0.007260 | Dataset: 2306
#   Epoch  2450/4000 | Loss: 0.007039 | Dataset: 2306
#   Epoch  2500/4000 | Loss: 0.006822 | Dataset: 2306
#   Epoch  2550/4000 | Loss: 0.006603 | Dataset: 2306
#   Epoch  2600/4000 | Loss: 0.006384 | Dataset: 2306
#   Epoch  2650/4000 | Loss: 0.006165 | Dataset: 2306
#   Epoch  2700/4000 | Loss: 0.005948 | Dataset: 2306
#   Epoch  2750/4000 | Loss: 0.005731 | Dataset: 2306
#   Epoch  2800/4000 | Loss: 0.005517 | Dataset: 2306
#   Epoch  2850/4000 | Loss: 0.005301 | Dataset: 2306
#   Epoch  2900/4000 | Loss: 0.005088 | Dataset: 2306
#   [Epoch 2922] Loss 0.004997 < threshold to checking SMT...
#
# ============================================================
# Training complete
#   Final loss     : 0.004997
#   Learned margin : 0.000055
#   Final dataset  : 2306
# ============================================================

# %%
fig, ax = plot_contour_density(
    f,g,a_net1,b_net1,c_net1,x_lim = [-6,6],
    y_lim = [-6,6],
    density_threshold = 1e-12,
    title =" ",
    x_axis_title = "$x_1$",
    y_axis_title = "$x_2$",
    device = device
)
