# %%
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import random
from dreal import *
import matplotlib.patches as patches
from matplotlib import cm

# %%
import sys
import os

sys.path.append(os.path.join(os.path.dirname(os.path.abspath("__file__")), ".."))

from Neural_Density_Training.Models import (
    Polynomial_net,
    Polynomial_net_bias_zero,
    Numerator_polynomial_net,
    GammaFunctionNet,
)
from Neural_Density_Training.loss import (
    stability_loss,
    invariance_loss,
    safety_loss,
)
from Neural_Density_Training.falsifier import checkSMTconstraints, AddCounterexamples
from Neural_Density_Training.extract_model import SymbolicNN, activSymbolicNN
from Neural_Density_Training.plotter import (
    plot_contour_density,
    plot_contour_mixed_density,
)

# %%
torch.cuda.empty_cache()
torch.manual_seed(17)
random.seed()

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Pre-allocate numerical_x
numerical_x = torch.Tensor(500, 2).uniform_(-6, 6).float().to(device)
# Out:
# Using device: cpu

# %%
def f(x):
    if x.dim() == 1:
        x = x.unsqueeze(0)
    val = torch.stack([
        -6*x[:,0]*(x[:,1]**2)-(x[:,0]**2)*x[:,1]+2*(x[:,1]**3),
        torch.zeros_like(x[:,0])
    ], dim=1)
   
    return val.squeeze(0) if val.shape[0] == 1 else val

def g(x):
    """Vectorized g(x) - handles batched input"""
    if x.dim() == 1:
        x = x.unsqueeze(0)
    
    val = torch.stack([
        torch.zeros_like(x[:, 0]),
        torch.ones_like(x[:, 0])
    ], dim=1)
    
    return val.squeeze(0) if val.shape[0] == 1 else val

def div_f(x):
    divergence = -6 * (x[:, 1] ** 2) - 2 * x[:, 0] * x[:, 1] 
    return divergence if divergence.dim() == 1 else divergence.squeeze(1)

def div_g(x):
    """Vectorized divergence of g"""
    if x.dim() == 1:
        return torch.tensor(0.0, device=device)
    else:
        return torch.zeros(x.shape[0], device=device)

# %%
def candidate_constraint_learnt(vars,a_fun,b_fun,c_fun):
    """
    Construct candidate constraints for the learnt functions.
    
    Args:
        vars: List of dReal Variables
        a_fun: Function representing a(x).
        b_fun: Function representing b(x).
        c_fun: Function representing c(x).

    Returns:
        Symbolic expression for the candidate constraint.
    """
    a_sym = activSymbolicNN(a_fun).forward_symbolic(vars)[0]
    b_sym = SymbolicNN(b_fun).forward_symbolic(vars)
    c_sym = SymbolicNN(c_fun).forward_symbolic(vars)[0]

    # b_sym = ||b_sym||^2
    b_sym = sum([bi**2 for bi in b_sym])
    # write f and g in terms of val
    f_val = [-6*vars[0]*(vars[1]**2)-(vars[0]**2)*vars[1]+2*(vars[1]**3), 0]
    # print("f_val: ", f_val)
    g_val = [0,vars[1]]
    # print("g_val: ", g_val)
    f_div = -6* (vars[1]**2) - 2 * vars[0]*vars[1]
    g_div = 1
    grad_a = [a_sym.Differentiate(vars[i]) for i in range(len(vars))]
    grad_c = [c_sym.Differentiate(vars[i]) for i in range(len(vars))]
    grad_b = [b_sym.Differentiate(vars[i]) for i in range(len(vars))]

    constraint1 = a_sym * f_div + g_div * c_sym + sum([grad_a[i] * f_val[i] for i in range(len(f_val))]) + sum([grad_c[i] * g_val[i] for i in range(len(g_val))])
  
    scaled_vars = [2 * var_i for var_i in vars]
    constraint2 = [scaled_vars[i] + grad_b[i] for i in range(len(vars))]

    constraint2 = sum([constraint2[i] * (f_val[i] * a_sym + g_val[i] * c_sym) for i in range(len(f_val))])  
    constraint = constraint1 - constraint2
    return a_sym , constraint

# %%
def train_density(
    x,                          # initial sample tensor  [N, state_dim]
    f,                          # dynamics callable
    g,                          # control matrix callable
    div_f,                      # divergence of f callable
    div_g,                      # divergence of g callable
    device,
    # --- training ---
    epochs          = 2000,
    lr              = 1e-2,
    loss_threshold  = 5e-4,
    # --- SMT verification ---
    ball_lb         = 0.05,
    ball_ub         = 6.0,
    check_interval  = 10,
    n_counterex     = 100,
):
    
    # Instantiate neural networks for a, b, c, gamma
    a_net = Numerator_polynomial_net(layers=2, input_dim=2, hidden_dim=6, output_dim=1).to(device)
    b_net = Polynomial_net_bias_zero(layers=2, input_dim=2, hidden_dim=1, output_dim=1).to(device)
    c_net = Polynomial_net(layers=3, input_dim=2, hidden_dim=6, output_dim=1).to(device)
    gamma_net = GammaFunctionNet(input_dim=2,output_dim=1).to(device)

    
    # Loss and Optimizer
    criterion = stability_loss(f=f,g=g,div_f=div_f,div_g=div_g)

    optimizer = torch.optim.Adam(list(a_net.parameters()) +
                                    list(b_net.parameters()) + 
                                    list(c_net.parameters()) + 
                                    list(gamma_net.parameters()), lr=lr)
    
    # dReal Configuration
    config = Config()
    config.use_polytope_in_forall = True
    config.use_local_optimization = True
    config.precision = 1e-5   

    # CEGIS Loop
    loss_history = []
    valid = False 
    print("=" * 60)
    print("Training density function with SMT-CEGIS verification")
    print(f"  Initial dataset size: {x.shape[0]}")
    print("=" * 60)    

    while not valid:
        for epoch in range(epochs):
            optimizer.zero_grad()
            loss = criterion(x, a_net, b_net, c_net, gamma_net)         
            loss_history.append(loss.item())
            loss.backward()
            optimizer.step()

            
            # ---------- early-exit on convergence ----------
            if loss.item() < loss_threshold:
                print(f"  [Epoch {epoch}] Loss {loss.item():.6f} < threshold to checking SMT...")
                valid = True
                break

            # ---------- periodic progress print ------------
            if epoch % 50 == 0:
                print(
                    f"  Epoch {epoch:>5}/{epochs} | "
                    f"Loss: {loss.item():.6f} | "
                    f"Dataset: {x.shape[0]}"
                )            
 
            # ---------- SMT counterexample check -----------
            if epoch % check_interval == 0 and epoch > 0:
                vars_sym = [Variable("x1"), Variable("x2")]
                try:
                    a_sym, div_sym = candidate_constraint_learnt(
                        vars_sym, a_net, b_net, c_net
                    )
                    CE = checkSMTconstraints(
                        vars_sym, a_sym, div_sym, ball_lb, ball_ub, config
                    )
 
                    if CE:
                        before = x.shape[0]
                        x, _ = AddCounterexamples(x, CE, n_counterex, device)
                        after = x.shape[0]
                        print(
                            f"  [Epoch {epoch}] CE found → "
                            f"dataset {before} → {after} (+{after - before})"
                        )
                    else:
                        valid = True
                        print(f"  [Epoch {epoch}] SMT satisfied — no counterexample found ✓")
                        break
 
                except Exception as e:
                    print(f"  [Epoch {epoch}] SMT check failed: {e}")
                    continue
 
    # ------------------------------------------------------------------
    # 5. Final summary
    # ------------------------------------------------------------------
    test_point = torch.zeros(1, 2, dtype=torch.float32, device=device)
    margin     = gamma_net(test_point).item()
 
    print("\n" + "=" * 60)
    print("Training complete")
    print(f"  Final loss     : {loss_history[-1]:.6f}")
    print(f"  Learned margin : {margin:.6f}")
    print(f"  Final dataset  : {x.shape[0]}")
    print("=" * 60)
 
    return loss_history, a_net, b_net, c_net, gamma_net

# %%
print("Starting training...")
loss_history1, a_net1, b_net1, c_net1, gamma_net1 = train_density(
    numerical_x, f, g, div_f, div_g, device,
    epochs=4000,
    lr=1e-4,
    loss_threshold=5e-4,
    ball_lb=0.05,
    ball_ub=6.0,
    check_interval=500,
    n_counterex=100
)
# Out:
# Starting training...
# ============================================================
# Training density function with SMT-CEGIS verification
#   Initial dataset size: 500
# ============================================================
#   Epoch     0/4000 | Loss: 13.298873 | Dataset: 500
#   Epoch    50/4000 | Loss: 13.028281 | Dataset: 500
#   Epoch   100/4000 | Loss: 12.759854 | Dataset: 500
#   Epoch   150/4000 | Loss: 12.493292 | Dataset: 500
#   Epoch   200/4000 | Loss: 12.228755 | Dataset: 500
#   Epoch   250/4000 | Loss: 11.966508 | Dataset: 500
#   Epoch   300/4000 | Loss: 11.706341 | Dataset: 500
#   Epoch   350/4000 | Loss: 11.448189 | Dataset: 500
#   Epoch   400/4000 | Loss: 11.191932 | Dataset: 500
#   Epoch   450/4000 | Loss: 10.937342 | Dataset: 500
#   Epoch   500/4000 | Loss: 10.684114 | Dataset: 500
#   [Epoch 500] CE found → dataset 500 → 600 (+100)
#   Epoch   550/4000 | Loss: 8.789118 | Dataset: 600
#   Epoch   600/4000 | Loss: 8.613052 | Dataset: 600
#   Epoch   650/4000 | Loss: 8.436605 | Dataset: 600
#   Epoch   700/4000 | Loss: 8.261003 | Dataset: 600
#   Epoch   750/4000 | Loss: 8.083592 | Dataset: 600
#   Epoch   800/4000 | Loss: 7.903849 | Dataset: 600
#   Epoch   850/4000 | Loss: 7.721802 | Dataset: 600
#   Epoch   900/4000 | Loss: 7.537488 | Dataset: 600
#   Epoch   950/4000 | Loss: 7.350901 | Dataset: 600
#   Epoch  1000/4000 | Loss: 7.162086 | Dataset: 600
#   [Epoch 1000] CE found → dataset 600 → 700 (+100)
#   Epoch  1050/4000 | Loss: 6.018466 | Dataset: 700
#   Epoch  1100/4000 | Loss: 5.868259 | Dataset: 700
#   Epoch  1150/4000 | Loss: 5.718983 | Dataset: 700
#   Epoch  1200/4000 | Loss: 5.568890 | Dataset: 700
#   Epoch  1250/4000 | Loss: 5.423846 | Dataset: 700
#   Epoch  1300/4000 | Loss: 5.281573 | Dataset: 700
#   Epoch  1350/4000 | Loss: 5.141635 | Dataset: 700
#   Epoch  1400/4000 | Loss: 5.002125 | Dataset: 700
#   Epoch  1450/4000 | Loss: 4.862039 | Dataset: 700
#   Epoch  1500/4000 | Loss: 4.722630 | Dataset: 700
#   [Epoch 1500] CE found → dataset 700 → 800 (+100)
#   Epoch  1550/4000 | Loss: 4.056256 | Dataset: 800
#   Epoch  1600/4000 | Loss: 3.947214 | Dataset: 800
#   Epoch  1650/4000 | Loss: 3.837609 | Dataset: 800
#   Epoch  1700/4000 | Loss: 3.727346 | Dataset: 800
#   Epoch  1750/4000 | Loss: 3.616100 | Dataset: 800
#   Epoch  1800/4000 | Loss: 3.504281 | Dataset: 800
#   Epoch  1850/4000 | Loss: 3.393471 | Dataset: 800
#   Epoch  1900/4000 | Loss: 3.284691 | Dataset: 800
#   Epoch  1950/4000 | Loss: 3.177507 | Dataset: 800
#   Epoch  2000/4000 | Loss: 3.069787 | Dataset: 800
#   [Epoch 2000] CE found → dataset 800 → 897 (+97)
#   Epoch  2050/4000 | Loss: 2.679038 | Dataset: 897
#   Epoch  2100/4000 | Loss: 2.589782 | Dataset: 897
#   Epoch  2150/4000 | Loss: 2.500888 | Dataset: 897
#   Epoch  2200/4000 | Loss: 2.411492 | Dataset: 897
#   Epoch  2250/4000 | Loss: 2.321751 | Dataset: 897
#   Epoch  2300/4000 | Loss: 2.231824 | Dataset: 897
#   Epoch  2350/4000 | Loss: 2.141564 | Dataset: 897

# %%
fig, ax = plot_contour_density(
    f,g,a_net1,b_net1,c_net1,x_lim = [-6,6],
    y_lim = [-6,6],
    density_threshold = 1e-12,
    title =" ",
    x_axis_title = "$x_1$",
    y_axis_title = "$x_2$",
    device = device
)

# %%
# create new datasets to learn another density function and controller
numerical_x2 = torch.Tensor(500, 2).uniform_(-6, 6).float().to(device)

# run the training again with the new dataset
loss_history2, a_net2, b_net2, c_net2, gamma_net2 = train_density(
    numerical_x2, f, g, div_f, div_g, device,
    epochs=4000,
    lr=1e-4,
    loss_threshold=5e-4,
    ball_lb=0.05,
    ball_ub=6.0,
    check_interval=500,
    n_counterex=100
)
fig, ax = plot_contour_density(
    f,g,a_net2,b_net2,c_net2,x_lim = [-6,6],
    y_lim = [-6,6],
    density_threshold = 1e-12,
    title =" ",
    x_axis_title = "$x_1$",
    y_axis_title = "$x_2$",
    device = device
)
# Out:
# ============================================================
# Training density function with SMT-CEGIS verification
#   Initial dataset size: 500
# ============================================================
#   Epoch     0/4000 | Loss: 5.983933 | Dataset: 500
#   Epoch    50/4000 | Loss: 5.789924 | Dataset: 500
#   Epoch   100/4000 | Loss: 5.608386 | Dataset: 500
#   Epoch   150/4000 | Loss: 5.432111 | Dataset: 500
#   Epoch   200/4000 | Loss: 5.259523 | Dataset: 500
#   Epoch   250/4000 | Loss: 5.092293 | Dataset: 500
#   Epoch   300/4000 | Loss: 4.931188 | Dataset: 500
#   Epoch   350/4000 | Loss: 4.775933 | Dataset: 500
#   Epoch   400/4000 | Loss: 4.628895 | Dataset: 500
#   Epoch   450/4000 | Loss: 4.489875 | Dataset: 500
#   Epoch   500/4000 | Loss: 4.355604 | Dataset: 500
#   [Epoch 500] CE found → dataset 500 → 600 (+100)
#   Epoch   550/4000 | Loss: 3.775275 | Dataset: 600
#   Epoch   600/4000 | Loss: 3.684169 | Dataset: 600
#   Epoch   650/4000 | Loss: 3.597323 | Dataset: 600
#   Epoch   700/4000 | Loss: 3.511415 | Dataset: 600
#   Epoch   750/4000 | Loss: 3.432395 | Dataset: 600
#   Epoch   800/4000 | Loss: 3.353786 | Dataset: 600
#   Epoch   850/4000 | Loss: 3.275501 | Dataset: 600
#   Epoch   900/4000 | Loss: 3.198395 | Dataset: 600
#   Epoch   950/4000 | Loss: 3.122926 | Dataset: 600
#   Epoch  1000/4000 | Loss: 3.047722 | Dataset: 600
#   [Epoch 1000] CE found → dataset 600 → 699 (+99)
#   Epoch  1050/4000 | Loss: 2.729317 | Dataset: 699
#   Epoch  1100/4000 | Loss: 2.655971 | Dataset: 699
#   Epoch  1150/4000 | Loss: 2.579520 | Dataset: 699
#   Epoch  1200/4000 | Loss: 2.497931 | Dataset: 699
#   Epoch  1250/4000 | Loss: 2.408565 | Dataset: 699
#   Epoch  1300/4000 | Loss: 2.344885 | Dataset: 699
#   Epoch  1350/4000 | Loss: 2.292282 | Dataset: 699
#   Epoch  1400/4000 | Loss: 2.238719 | Dataset: 699
#   Epoch  1450/4000 | Loss: 2.183048 | Dataset: 699
#   Epoch  1500/4000 | Loss: 2.125968 | Dataset: 699
#   [Epoch 1500] CE found → dataset 699 → 799 (+100)
#   Epoch  1550/4000 | Loss: 2.090484 | Dataset: 799
#   Epoch  1600/4000 | Loss: 2.008919 | Dataset: 799
#   Epoch  1650/4000 | Loss: 1.929514 | Dataset: 799
#   Epoch  1700/4000 | Loss: 1.849990 | Dataset: 799
#   Epoch  1750/4000 | Loss: 1.769870 | Dataset: 799
#   Epoch  1800/4000 | Loss: 1.692208 | Dataset: 799
#   Epoch  1850/4000 | Loss: 1.615468 | Dataset: 799
#   Epoch  1900/4000 | Loss: 1.540342 | Dataset: 799
#   Epoch  1950/4000 | Loss: 1.504184 | Dataset: 799
#   Epoch  2000/4000 | Loss: 1.467875 | Dataset: 799
#   [Epoch 2000] CE found → dataset 799 → 899 (+100)
#   Epoch  2050/4000 | Loss: 1.275368 | Dataset: 899
#   Epoch  2100/4000 | Loss: 1.247931 | Dataset: 899
#   Epoch  2150/4000 | Loss: 1.220361 | Dataset: 899
#   Epoch  2200/4000 | Loss: 1.192611 | Dataset: 899
#   Epoch  2250/4000 | Loss: 1.164689 | Dataset: 899
#   Epoch  2300/4000 | Loss: 1.136600 | Dataset: 899
#   Epoch  2350/4000 | Loss: 1.109540 | Dataset: 899
#   Epoch  2400/4000 | Loss: 1.083201 | Dataset: 899
#   Epoch  2450/4000 | Loss: 1.059026 | Dataset: 899
#   Epoch  2500/4000 | Loss: 1.037441 | Dataset: 899
#   [Epoch 2500] CE found → dataset 899 → 927 (+28)
#   Epoch  2550/4000 | Loss: 1.030654 | Dataset: 927
#   Epoch  2600/4000 | Loss: 1.012480 | Dataset: 927
#   Epoch  2650/4000 | Loss: 0.994139 | Dataset: 927
#   Epoch  2700/4000 | Loss: 0.975596 | Dataset: 927
#   Epoch  2750/4000 | Loss: 0.956840 | Dataset: 927
#   Epoch  2800/4000 | Loss: 0.937868 | Dataset: 927
#   Epoch  2850/4000 | Loss: 0.918709 | Dataset: 927
#   Epoch  2900/4000 | Loss: 0.899327 | Dataset: 927
#   Epoch  2950/4000 | Loss: 0.879762 | Dataset: 927
#   Epoch  3000/4000 | Loss: 0.859985 | Dataset: 927
#   [Epoch 3000] CE found → dataset 927 → 971 (+44)
#   Epoch  3050/4000 | Loss: 0.865369 | Dataset: 971
#   Epoch  3100/4000 | Loss: 0.845810 | Dataset: 971
#   Epoch  3150/4000 | Loss: 0.826297 | Dataset: 971
#   Epoch  3200/4000 | Loss: 0.806793 | Dataset: 971
#   Epoch  3250/4000 | Loss: 0.788202 | Dataset: 971
#   Epoch  3300/4000 | Loss: 0.769704 | Dataset: 971
#   Epoch  3350/4000 | Loss: 0.751178 | Dataset: 971
#   Epoch  3400/4000 | Loss: 0.732618 | Dataset: 971
#   Epoch  3450/4000 | Loss: 0.714044 | Dataset: 971
#   Epoch  3500/4000 | Loss: 0.695387 | Dataset: 971
#   [Epoch 3500] CE found → dataset 971 → 1033 (+62)
#   Epoch  3550/4000 | Loss: 0.687687 | Dataset: 1033
#   Epoch  3600/4000 | Loss: 0.665646 | Dataset: 1033
#   Epoch  3650/4000 | Loss: 0.644189 | Dataset: 1033
#   Epoch  3700/4000 | Loss: 0.623272 | Dataset: 1033
#   Epoch  3750/4000 | Loss: 0.602752 | Dataset: 1033
#   Epoch  3800/4000 | Loss: 0.582368 | Dataset: 1033
#   Epoch  3850/4000 | Loss: 0.561941 | Dataset: 1033
#   Epoch  3900/4000 | Loss: 0.541264 | Dataset: 1033
#   Epoch  3950/4000 | Loss: 0.520188 | Dataset: 1033
#   Epoch     0/4000 | Loss: 0.498544 | Dataset: 1033
#   Epoch    50/4000 | Loss: 0.476475 | Dataset: 1033
#   Epoch   100/4000 | Loss: 0.454265 | Dataset: 1033
#   Epoch   150/4000 | Loss: 0.430634 | Dataset: 1033
#   Epoch   200/4000 | Loss: 0.406237 | Dataset: 1033
#   Epoch   250/4000 | Loss: 0.387516 | Dataset: 1033
#   Epoch   300/4000 | Loss: 0.371653 | Dataset: 1033
#   Epoch   350/4000 | Loss: 0.356970 | Dataset: 1033
#   Epoch   400/4000 | Loss: 0.342597 | Dataset: 1033
#   Epoch   450/4000 | Loss: 0.328130 | Dataset: 1033
#   Epoch   500/4000 | Loss: 0.313548 | Dataset: 1033
#   [Epoch 500] CE found → dataset 1033 → 1133 (+100)
#   Epoch   550/4000 | Loss: 0.273395 | Dataset: 1133
#   Epoch   600/4000 | Loss: 0.262599 | Dataset: 1133
#   Epoch   650/4000 | Loss: 0.251860 | Dataset: 1133
#   Epoch   700/4000 | Loss: 0.240971 | Dataset: 1133
#   Epoch   750/4000 | Loss: 0.229923 | Dataset: 1133
#   Epoch   800/4000 | Loss: 0.218814 | Dataset: 1133
#   Epoch   850/4000 | Loss: 0.208817 | Dataset: 1133
#   Epoch   900/4000 | Loss: 0.198836 | Dataset: 1133
#   Epoch   950/4000 | Loss: 0.188666 | Dataset: 1133
#   Epoch  1000/4000 | Loss: 0.178301 | Dataset: 1133
#   [Epoch 1000] CE found → dataset 1133 → 1233 (+100)
#   Epoch  1050/4000 | Loss: 0.154756 | Dataset: 1233
#   Epoch  1100/4000 | Loss: 0.145684 | Dataset: 1233
#   Epoch  1150/4000 | Loss: 0.138879 | Dataset: 1233
#   Epoch  1200/4000 | Loss: 0.132070 | Dataset: 1233
#   Epoch  1250/4000 | Loss: 0.125098 | Dataset: 1233
#   Epoch  1300/4000 | Loss: 0.118780 | Dataset: 1233
#   Epoch  1350/4000 | Loss: 0.112994 | Dataset: 1233
#   Epoch  1400/4000 | Loss: 0.107215 | Dataset: 1233
#   Epoch  1450/4000 | Loss: 0.101162 | Dataset: 1233
#   Epoch  1500/4000 | Loss: 0.095030 | Dataset: 1233
#   [Epoch 1500] CE found → dataset 1233 → 1333 (+100)
#   Epoch  1550/4000 | Loss: 0.082682 | Dataset: 1333
#   Epoch  1600/4000 | Loss: 0.078035 | Dataset: 1333
#   Epoch  1650/4000 | Loss: 0.073788 | Dataset: 1333
#   Epoch  1700/4000 | Loss: 0.069627 | Dataset: 1333
#   Epoch  1750/4000 | Loss: 0.066729 | Dataset: 1333
#   Epoch  1800/4000 | Loss: 0.064416 | Dataset: 1333
#   Epoch  1850/4000 | Loss: 0.061953 | Dataset: 1333
#   Epoch  1900/4000 | Loss: 0.059409 | Dataset: 1333
#   Epoch  1950/4000 | Loss: 0.056799 | Dataset: 1333
#   Epoch  2000/4000 | Loss: 0.054820 | Dataset: 1333
#   [Epoch 2000] CE found → dataset 1333 → 1433 (+100)
#   Epoch  2050/4000 | Loss: 0.052379 | Dataset: 1433
#   Epoch  2100/4000 | Loss: 0.050915 | Dataset: 1433
#   Epoch  2150/4000 | Loss: 0.049365 | Dataset: 1433
#   Epoch  2200/4000 | Loss: 0.048336 | Dataset: 1433
#   Epoch  2250/4000 | Loss: 0.047283 | Dataset: 1433
#   Epoch  2300/4000 | Loss: 0.046297 | Dataset: 1433
#   Epoch  2350/4000 | Loss: 0.045365 | Dataset: 1433
#   Epoch  2400/4000 | Loss: 0.044340 | Dataset: 1433
#   Epoch  2450/4000 | Loss: 0.043286 | Dataset: 1433
#   Epoch  2500/4000 | Loss: 0.042256 | Dataset: 1433
#   [Epoch 2500] CE found → dataset 1433 → 1533 (+100)
#   Epoch  2550/4000 | Loss: 0.038541 | Dataset: 1533
#   Epoch  2600/4000 | Loss: 0.037560 | Dataset: 1533
#   Epoch  2650/4000 | Loss: 0.036631 | Dataset: 1533
#   Epoch  2700/4000 | Loss: 0.035597 | Dataset: 1533
#   Epoch  2750/4000 | Loss: 0.034557 | Dataset: 1533
#   Epoch  2800/4000 | Loss: 0.033529 | Dataset: 1533
#   Epoch  2850/4000 | Loss: 0.032427 | Dataset: 1533
#   Epoch  2900/4000 | Loss: 0.031370 | Dataset: 1533
#   Epoch  2950/4000 | Loss: 0.030258 | Dataset: 1533
#   Epoch  3000/4000 | Loss: 0.029220 | Dataset: 1533
#   [Epoch 3000] CE found → dataset 1533 → 1633 (+100)
#   Epoch  3050/4000 | Loss: 0.026523 | Dataset: 1633
#   Epoch  3100/4000 | Loss: 0.025626 | Dataset: 1633
#   Epoch  3150/4000 | Loss: 0.024691 | Dataset: 1633
#   Epoch  3200/4000 | Loss: 0.023734 | Dataset: 1633
#   Epoch  3250/4000 | Loss: 0.022761 | Dataset: 1633
#   Epoch  3300/4000 | Loss: 0.021774 | Dataset: 1633
#   Epoch  3350/4000 | Loss: 0.020771 | Dataset: 1633
#   Epoch  3400/4000 | Loss: 0.019745 | Dataset: 1633
#   Epoch  3450/4000 | Loss: 0.018689 | Dataset: 1633
#   Epoch  3500/4000 | Loss: 0.017613 | Dataset: 1633
#   [Epoch 3500] CE found → dataset 1633 → 1733 (+100)
#   Epoch  3550/4000 | Loss: 0.015678 | Dataset: 1733
#   Epoch  3600/4000 | Loss: 0.014727 | Dataset: 1733
#   Epoch  3650/4000 | Loss: 0.013956 | Dataset: 1733
#   Epoch  3700/4000 | Loss: 0.013194 | Dataset: 1733
#   Epoch  3750/4000 | Loss: 0.012433 | Dataset: 1733
#   Epoch  3800/4000 | Loss: 0.011699 | Dataset: 1733
#   Epoch  3850/4000 | Loss: 0.010922 | Dataset: 1733
#   Epoch  3900/4000 | Loss: 0.010670 | Dataset: 1733
#   Epoch  3950/4000 | Loss: 0.010565 | Dataset: 1733
#   Epoch     0/4000 | Loss: 0.010412 | Dataset: 1733
#   Epoch    50/4000 | Loss: 0.010264 | Dataset: 1733
#   Epoch   100/4000 | Loss: 0.010109 | Dataset: 1733
#   Epoch   150/4000 | Loss: 0.009950 | Dataset: 1733
#   Epoch   200/4000 | Loss: 0.009806 | Dataset: 1733
#   Epoch   250/4000 | Loss: 0.009692 | Dataset: 1733
#   Epoch   300/4000 | Loss: 0.009539 | Dataset: 1733
#   Epoch   350/4000 | Loss: 0.009381 | Dataset: 1733
#   Epoch   400/4000 | Loss: 0.009211 | Dataset: 1733
#   Epoch   450/4000 | Loss: 0.009061 | Dataset: 1733
#   Epoch   500/4000 | Loss: 0.008938 | Dataset: 1733
#   [Epoch 500] CE found → dataset 1733 → 1832 (+99)
#   Epoch   550/4000 | Loss: 0.008312 | Dataset: 1832
#   Epoch   600/4000 | Loss: 0.008153 | Dataset: 1832
#   Epoch   650/4000 | Loss: 0.008001 | Dataset: 1832
#   Epoch   700/4000 | Loss: 0.007849 | Dataset: 1832
#   Epoch   750/4000 | Loss: 0.007725 | Dataset: 1832
#   Epoch   800/4000 | Loss: 0.007581 | Dataset: 1832
#   Epoch   850/4000 | Loss: 0.007410 | Dataset: 1832
#   Epoch   900/4000 | Loss: 0.007328 | Dataset: 1832
#   Epoch   950/4000 | Loss: 0.007242 | Dataset: 1832
#   Epoch  1000/4000 | Loss: 0.007151 | Dataset: 1832
#   [Epoch 1000] CE found → dataset 1832 → 1932 (+100)
#   Epoch  1050/4000 | Loss: 0.006694 | Dataset: 1932
#   Epoch  1100/4000 | Loss: 0.006600 | Dataset: 1932
#   Epoch  1150/4000 | Loss: 0.006497 | Dataset: 1932
#   Epoch  1200/4000 | Loss: 0.006398 | Dataset: 1932
#   Epoch  1250/4000 | Loss: 0.006335 | Dataset: 1932
#   Epoch  1300/4000 | Loss: 0.006273 | Dataset: 1932
#   Epoch  1350/4000 | Loss: 0.006169 | Dataset: 1932
#   Epoch  1400/4000 | Loss: 0.006107 | Dataset: 1932
#   Epoch  1450/4000 | Loss: 0.006040 | Dataset: 1932
#   Epoch  1500/4000 | Loss: 0.005952 | Dataset: 1932
#   [Epoch 1500] CE found → dataset 1932 → 2030 (+98)
#   Epoch  1550/4000 | Loss: 0.005995 | Dataset: 2030
#   Epoch  1600/4000 | Loss: 0.005835 | Dataset: 2030
#   Epoch  1650/4000 | Loss: 0.005672 | Dataset: 2030
#   Epoch  1700/4000 | Loss: 0.005504 | Dataset: 2030
#   Epoch  1750/4000 | Loss: 0.005483 | Dataset: 2030
#   Epoch  1800/4000 | Loss: 0.005369 | Dataset: 2030
#   Epoch  1850/4000 | Loss: 0.005342 | Dataset: 2030
#   Epoch  1900/4000 | Loss: 0.005289 | Dataset: 2030
#   Epoch  1950/4000 | Loss: 0.005236 | Dataset: 2030
#   Epoch  2000/4000 | Loss: 0.005215 | Dataset: 2030
#   [Epoch 2000] CE found → dataset 2030 → 2130 (+100)
#   Epoch  2050/4000 | Loss: 0.004960 | Dataset: 2130
#   Epoch  2100/4000 | Loss: 0.004911 | Dataset: 2130
#   Epoch  2150/4000 | Loss: 0.004862 | Dataset: 2130
#   Epoch  2200/4000 | Loss: 0.004883 | Dataset: 2130
#   Epoch  2250/4000 | Loss: 0.004828 | Dataset: 2130
#   Epoch  2300/4000 | Loss: 0.004778 | Dataset: 2130
#   Epoch  2350/4000 | Loss: 0.004757 | Dataset: 2130
#   Epoch  2400/4000 | Loss: 0.004743 | Dataset: 2130
#   Epoch  2450/4000 | Loss: 0.004692 | Dataset: 2130
#   Epoch  2500/4000 | Loss: 0.004640 | Dataset: 2130
#   [Epoch 2500] CE found → dataset 2130 → 2136 (+6)
#   Epoch  2550/4000 | Loss: 0.004649 | Dataset: 2136
#   Epoch  2600/4000 | Loss: 0.004596 | Dataset: 2136
#   Epoch  2650/4000 | Loss: 0.004561 | Dataset: 2136
#   Epoch  2700/4000 | Loss: 0.004524 | Dataset: 2136
#   Epoch  2750/4000 | Loss: 0.004487 | Dataset: 2136
#   Epoch  2800/4000 | Loss: 0.004450 | Dataset: 2136
#   Epoch  2850/4000 | Loss: 0.004412 | Dataset: 2136
#   Epoch  2900/4000 | Loss: 0.004373 | Dataset: 2136
#   Epoch  2950/4000 | Loss: 0.004333 | Dataset: 2136
#   Epoch  3000/4000 | Loss: 0.004293 | Dataset: 2136
#   [Epoch 3000] CE found → dataset 2136 → 2236 (+100)
#   Epoch  3050/4000 | Loss: 0.004062 | Dataset: 2236
#   Epoch  3100/4000 | Loss: 0.004024 | Dataset: 2236
#   Epoch  3150/4000 | Loss: 0.003983 | Dataset: 2236
#   Epoch  3200/4000 | Loss: 0.003943 | Dataset: 2236
#   Epoch  3250/4000 | Loss: 0.003901 | Dataset: 2236
#   Epoch  3300/4000 | Loss: 0.003860 | Dataset: 2236
#   Epoch  3350/4000 | Loss: 0.003815 | Dataset: 2236
#   Epoch  3400/4000 | Loss: 0.003771 | Dataset: 2236
#   Epoch  3450/4000 | Loss: 0.003726 | Dataset: 2236
#   Epoch  3500/4000 | Loss: 0.003679 | Dataset: 2236
#   [Epoch 3500] CE found → dataset 2236 → 2336 (+100)
#   Epoch  3550/4000 | Loss: 0.003477 | Dataset: 2336
#   Epoch  3600/4000 | Loss: 0.003432 | Dataset: 2336
#   Epoch  3650/4000 | Loss: 0.003386 | Dataset: 2336
#   Epoch  3700/4000 | Loss: 0.003340 | Dataset: 2336
#   Epoch  3750/4000 | Loss: 0.003291 | Dataset: 2336
#   Epoch  3800/4000 | Loss: 0.003242 | Dataset: 2336
#   Epoch  3850/4000 | Loss: 0.003190 | Dataset: 2336
#   Epoch  3900/4000 | Loss: 0.003138 | Dataset: 2336
#   Epoch  3950/4000 | Loss: 0.003085 | Dataset: 2336
#   Epoch     0/4000 | Loss: 0.003032 | Dataset: 2336
#   Epoch    50/4000 | Loss: 0.002989 | Dataset: 2336
#   Epoch   100/4000 | Loss: 0.002948 | Dataset: 2336
#   Epoch   150/4000 | Loss: 0.002906 | Dataset: 2336
#   Epoch   200/4000 | Loss: 0.002868 | Dataset: 2336
#   Epoch   250/4000 | Loss: 0.002836 | Dataset: 2336
#   Epoch   300/4000 | Loss: 0.002803 | Dataset: 2336
#   Epoch   350/4000 | Loss: 0.002771 | Dataset: 2336
#   Epoch   400/4000 | Loss: 0.002738 | Dataset: 2336
#   Epoch   450/4000 | Loss: 0.002708 | Dataset: 2336
#   Epoch   500/4000 | Loss: 0.002677 | Dataset: 2336
#   [Epoch 500] CE found → dataset 2336 → 2436 (+100)
#   Epoch   550/4000 | Loss: 0.002536 | Dataset: 2436
#   Epoch   600/4000 | Loss: 0.002507 | Dataset: 2436
#   Epoch   650/4000 | Loss: 0.002478 | Dataset: 2436
#   Epoch   700/4000 | Loss: 0.002447 | Dataset: 2436
#   Epoch   750/4000 | Loss: 0.002416 | Dataset: 2436
#   Epoch   800/4000 | Loss: 0.002395 | Dataset: 2436
#   Epoch   850/4000 | Loss: 0.002375 | Dataset: 2436
#   Epoch   900/4000 | Loss: 0.002354 | Dataset: 2436
#   Epoch   950/4000 | Loss: 0.002333 | Dataset: 2436
#   Epoch  1000/4000 | Loss: 0.002311 | Dataset: 2436
#   [Epoch 1000] CE found → dataset 2436 → 2536 (+100)
#   Epoch  1050/4000 | Loss: 0.002200 | Dataset: 2536
#   Epoch  1100/4000 | Loss: 0.002181 | Dataset: 2536
#   Epoch  1150/4000 | Loss: 0.002162 | Dataset: 2536
#   Epoch  1200/4000 | Loss: 0.002142 | Dataset: 2536
#   Epoch  1250/4000 | Loss: 0.002120 | Dataset: 2536
#   Epoch  1300/4000 | Loss: 0.002100 | Dataset: 2536
#   Epoch  1350/4000 | Loss: 0.002078 | Dataset: 2536
#   Epoch  1400/4000 | Loss: 0.002057 | Dataset: 2536
#   Epoch  1450/4000 | Loss: 0.002035 | Dataset: 2536
#   Epoch  1500/4000 | Loss: 0.002013 | Dataset: 2536
#   [Epoch 1500] CE found → dataset 2536 → 2636 (+100)
#   Epoch  1550/4000 | Loss: 0.001917 | Dataset: 2636
#   Epoch  1600/4000 | Loss: 0.001898 | Dataset: 2636
#   Epoch  1650/4000 | Loss: 0.001876 | Dataset: 2636
#   Epoch  1700/4000 | Loss: 0.001855 | Dataset: 2636
#   Epoch  1750/4000 | Loss: 0.001834 | Dataset: 2636
#   Epoch  1800/4000 | Loss: 0.001812 | Dataset: 2636
#   Epoch  1850/4000 | Loss: 0.001792 | Dataset: 2636
#   Epoch  1900/4000 | Loss: 0.001768 | Dataset: 2636
#   Epoch  1950/4000 | Loss: 0.001746 | Dataset: 2636
#   Epoch  2000/4000 | Loss: 0.001726 | Dataset: 2636
#   [Epoch 2000] CE found → dataset 2636 → 2736 (+100)
#   Epoch  2050/4000 | Loss: 0.001650 | Dataset: 2736
#   Epoch  2100/4000 | Loss: 0.001634 | Dataset: 2736
#   Epoch  2150/4000 | Loss: 0.001621 | Dataset: 2736
#   Epoch  2200/4000 | Loss: 0.001605 | Dataset: 2736
#   Epoch  2250/4000 | Loss: 0.001592 | Dataset: 2736
#   Epoch  2300/4000 | Loss: 0.001577 | Dataset: 2736
#   Epoch  2350/4000 | Loss: 0.001562 | Dataset: 2736
#   Epoch  2400/4000 | Loss: 0.001547 | Dataset: 2736
#   Epoch  2450/4000 | Loss: 0.001532 | Dataset: 2736
#   Epoch  2500/4000 | Loss: 0.001518 | Dataset: 2736
#   [Epoch 2500] CE found → dataset 2736 → 2836 (+100)
#   Epoch  2550/4000 | Loss: 0.001450 | Dataset: 2836
#   Epoch  2600/4000 | Loss: 0.001435 | Dataset: 2836
#   Epoch  2650/4000 | Loss: 0.001422 | Dataset: 2836
#   Epoch  2700/4000 | Loss: 0.001407 | Dataset: 2836
#   Epoch  2750/4000 | Loss: 0.001395 | Dataset: 2836
#   Epoch  2800/4000 | Loss: 0.001381 | Dataset: 2836
#   Epoch  2850/4000 | Loss: 0.001368 | Dataset: 2836
#   Epoch  2900/4000 | Loss: 0.001357 | Dataset: 2836
#   Epoch  2950/4000 | Loss: 0.001344 | Dataset: 2836
#   Epoch  3000/4000 | Loss: 0.001332 | Dataset: 2836
#   [Epoch 3000] CE found → dataset 2836 → 2936 (+100)
#   Epoch  3050/4000 | Loss: 0.014473 | Dataset: 2936
#   Epoch  3100/4000 | Loss: 0.012207 | Dataset: 2936
#   Epoch  3150/4000 | Loss: 0.011276 | Dataset: 2936
#   Epoch  3200/4000 | Loss: 0.010171 | Dataset: 2936
#   Epoch  3250/4000 | Loss: 0.009428 | Dataset: 2936
#   Epoch  3300/4000 | Loss: 0.008849 | Dataset: 2936
#   Epoch  3350/4000 | Loss: 0.008264 | Dataset: 2936
#   Epoch  3400/4000 | Loss: 0.007851 | Dataset: 2936
#   Epoch  3450/4000 | Loss: 0.007462 | Dataset: 2936
#   Epoch  3500/4000 | Loss: 0.007100 | Dataset: 2936
#   [Epoch 3500] CE found → dataset 2936 → 3036 (+100)
#   Epoch  3550/4000 | Loss: 0.006455 | Dataset: 3036
#   Epoch  3600/4000 | Loss: 0.006161 | Dataset: 3036
#   Epoch  3650/4000 | Loss: 0.005839 | Dataset: 3036
#   Epoch  3700/4000 | Loss: 0.005557 | Dataset: 3036
#   Epoch  3750/4000 | Loss: 0.005248 | Dataset: 3036
#   Epoch  3800/4000 | Loss: 0.004965 | Dataset: 3036
#   Epoch  3850/4000 | Loss: 0.004756 | Dataset: 3036
#   Epoch  3900/4000 | Loss: 0.004408 | Dataset: 3036
#   Epoch  3950/4000 | Loss: 0.004149 | Dataset: 3036
#   Epoch     0/4000 | Loss: 0.004129 | Dataset: 3036
#   Epoch    50/4000 | Loss: 0.004065 | Dataset: 3036
#   Epoch   100/4000 | Loss: 0.004058 | Dataset: 3036
#   Epoch   150/4000 | Loss: 0.004010 | Dataset: 3036
#   Epoch   200/4000 | Loss: 0.003944 | Dataset: 3036
#   Epoch   250/4000 | Loss: 0.003907 | Dataset: 3036
#   Epoch   300/4000 | Loss: 0.003873 | Dataset: 3036
#   Epoch   350/4000 | Loss: 0.003839 | Dataset: 3036
#   Epoch   400/4000 | Loss: 0.003793 | Dataset: 3036
#   Epoch   450/4000 | Loss: 0.003771 | Dataset: 3036
#   Epoch   500/4000 | Loss: 0.003720 | Dataset: 3036
#   [Epoch 500] CE found → dataset 3036 → 3136 (+100)
#   Epoch   550/4000 | Loss: 0.003584 | Dataset: 3136
#   Epoch   600/4000 | Loss: 0.003527 | Dataset: 3136
#   Epoch   650/4000 | Loss: 0.003488 | Dataset: 3136
#   Epoch   700/4000 | Loss: 0.003449 | Dataset: 3136
#   Epoch   750/4000 | Loss: 0.003425 | Dataset: 3136
#   Epoch   800/4000 | Loss: 0.003381 | Dataset: 3136
#   Epoch   850/4000 | Loss: 0.003333 | Dataset: 3136
#   Epoch   900/4000 | Loss: 0.003298 | Dataset: 3136
#   Epoch   950/4000 | Loss: 0.003255 | Dataset: 3136
#   Epoch  1000/4000 | Loss: 0.003244 | Dataset: 3136
#   [Epoch 1000] CE found → dataset 3136 → 3236 (+100)
#   Epoch  1050/4000 | Loss: 0.003073 | Dataset: 3236
#   Epoch  1100/4000 | Loss: 0.003038 | Dataset: 3236
#   Epoch  1150/4000 | Loss: 0.003003 | Dataset: 3236
#   Epoch  1200/4000 | Loss: 0.002986 | Dataset: 3236
#   Epoch  1250/4000 | Loss: 0.002918 | Dataset: 3236
#   Epoch  1300/4000 | Loss: 0.002922 | Dataset: 3236
#   Epoch  1350/4000 | Loss: 0.002835 | Dataset: 3236
#   Epoch  1400/4000 | Loss: 0.002788 | Dataset: 3236
#   Epoch  1450/4000 | Loss: 0.002753 | Dataset: 3236
#   Epoch  1500/4000 | Loss: 0.002703 | Dataset: 3236
#   [Epoch 1500] CE found → dataset 3236 → 3336 (+100)
#   Epoch  1550/4000 | Loss: 0.002583 | Dataset: 3336
#   Epoch  1600/4000 | Loss: 0.002539 | Dataset: 3336
#   Epoch  1650/4000 | Loss: 0.002493 | Dataset: 3336
#   Epoch  1700/4000 | Loss: 0.002459 | Dataset: 3336
#   Epoch  1750/4000 | Loss: 0.002407 | Dataset: 3336
#   Epoch  1800/4000 | Loss: 0.002360 | Dataset: 3336
#   Epoch  1850/4000 | Loss: 0.002317 | Dataset: 3336
#   Epoch  1900/4000 | Loss: 0.002263 | Dataset: 3336
#   Epoch  1950/4000 | Loss: 0.002211 | Dataset: 3336
#   Epoch  2000/4000 | Loss: 0.002159 | Dataset: 3336
#   [Epoch 2000] CE found → dataset 3336 → 3436 (+100)
#   Epoch  2050/4000 | Loss: 0.002045 | Dataset: 3436
#   Epoch  2100/4000 | Loss: 0.001993 | Dataset: 3436
#   Epoch  2150/4000 | Loss: 0.001935 | Dataset: 3436
#   Epoch  2200/4000 | Loss: 0.001876 | Dataset: 3436
#   Epoch  2250/4000 | Loss: 0.001816 | Dataset: 3436
#   Epoch  2300/4000 | Loss: 0.001761 | Dataset: 3436
#   Epoch  2350/4000 | Loss: 0.001720 | Dataset: 3436
#   Epoch  2400/4000 | Loss: 0.001672 | Dataset: 3436
#   Epoch  2450/4000 | Loss: 0.001618 | Dataset: 3436
#   Epoch  2500/4000 | Loss: 0.001572 | Dataset: 3436
#   [Epoch 2500] CE found → dataset 3436 → 3536 (+100)
#   Epoch  2550/4000 | Loss: 0.001483 | Dataset: 3536
#   Epoch  2600/4000 | Loss: 0.001436 | Dataset: 3536
#   Epoch  2650/4000 | Loss: 0.001396 | Dataset: 3536
#   Epoch  2700/4000 | Loss: 0.001366 | Dataset: 3536
#   Epoch  2750/4000 | Loss: 0.001331 | Dataset: 3536
#   Epoch  2800/4000 | Loss: 0.001305 | Dataset: 3536
#   Epoch  2850/4000 | Loss: 0.001266 | Dataset: 3536
#   Epoch  2900/4000 | Loss: 0.001233 | Dataset: 3536
#   Epoch  2950/4000 | Loss: 0.001198 | Dataset: 3536
#   Epoch  3000/4000 | Loss: 0.001166 | Dataset: 3536
#   [Epoch 3000] CE found → dataset 3536 → 3636 (+100)
#   Epoch  3050/4000 | Loss: 0.001100 | Dataset: 3636
#   Epoch  3100/4000 | Loss: 0.001066 | Dataset: 3636
#   Epoch  3150/4000 | Loss: 0.001035 | Dataset: 3636
#   Epoch  3200/4000 | Loss: 0.001008 | Dataset: 3636
#   Epoch  3250/4000 | Loss: 0.000978 | Dataset: 3636
#   Epoch  3300/4000 | Loss: 0.000947 | Dataset: 3636
#   Epoch  3350/4000 | Loss: 0.000919 | Dataset: 3636
#   Epoch  3400/4000 | Loss: 0.000886 | Dataset: 3636
#   Epoch  3450/4000 | Loss: 0.000851 | Dataset: 3636
#   Epoch  3500/4000 | Loss: 0.000818 | Dataset: 3636
#   [Epoch 3500] CE found → dataset 3636 → 3736 (+100)
#   Epoch  3550/4000 | Loss: 0.001007 | Dataset: 3736
#   Epoch  3600/4000 | Loss: 0.000762 | Dataset: 3736
#   Epoch  3650/4000 | Loss: 0.000679 | Dataset: 3736
#   Epoch  3700/4000 | Loss: 0.000650 | Dataset: 3736
#   Epoch  3750/4000 | Loss: 0.000623 | Dataset: 3736
#   Epoch  3800/4000 | Loss: 0.000608 | Dataset: 3736
#   Epoch  3850/4000 | Loss: 0.000599 | Dataset: 3736
#   Epoch  3900/4000 | Loss: 0.000589 | Dataset: 3736
#   Epoch  3950/4000 | Loss: 0.000579 | Dataset: 3736
#   Epoch     0/4000 | Loss: 0.000569 | Dataset: 3736
#   Epoch    50/4000 | Loss: 0.000561 | Dataset: 3736
#   Epoch   100/4000 | Loss: 0.000552 | Dataset: 3736
#   Epoch   150/4000 | Loss: 0.000543 | Dataset: 3736
#   Epoch   200/4000 | Loss: 0.000530 | Dataset: 3736
#   Epoch   250/4000 | Loss: 0.000520 | Dataset: 3736
#   Epoch   300/4000 | Loss: 0.000508 | Dataset: 3736
#   [Epoch 336] Loss 0.000500 < threshold to checking SMT...
#
# ============================================================
# Training complete
#   Final loss     : 0.000500
#   Learned margin : 0.000018
#   Final dataset  : 3736
# ============================================================

# %%
# plot the blended density function
fig, ax = plot_contour_mixed_density(
    f,g,a_net1,b_net1,c_net1,a_net2,b_net2,c_net2,x_lim = [-6,6],
    y_lim = [-6,6],
    density_threshold1 = 1e-12,
    density_threshold2=1e-12,
    density_threshold=1e-12,
    title =" ",
    x_axis_title = "$x_1$",
    y_axis_title = "$x_2$",
    device = device
)
