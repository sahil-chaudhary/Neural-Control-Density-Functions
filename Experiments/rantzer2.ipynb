# %%
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import random
from dreal import *
import matplotlib.patches as patches
from matplotlib import cm

# %%
import sys
import os

sys.path.append(os.path.join(os.path.dirname(os.path.abspath("__file__")), ".."))

from Neural_Density_Training.Models import (
    Polynomial_net,
    Polynomial_net_bias_zero,
    Numerator_polynomial_net,
    GammaFunctionNet,
)
from Neural_Density_Training.loss import (
    stability_loss,
    invariance_loss,
    safety_loss,
)
from Neural_Density_Training.falsifier import checkSMTconstraints, AddCounterexamples
from Neural_Density_Training.extract_model import SymbolicNN, activSymbolicNN
from Neural_Density_Training.plotter import (
    plot_contour_density,
    plot_contour_mixed_density,
)

# %%
torch.cuda.empty_cache()
torch.manual_seed(17)
random.seed()

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Pre-allocate numerical_x
numerical_x = torch.Tensor(500, 2).uniform_(-6, 6).float().to(device)
# Out:
# Using device: cpu

# %%
def f(x):
    if x.dim() == 1:
        x = x.unsqueeze(0)
    val = torch.stack([
        -2* x[:,0] + x[:,0]**2 - x[:,1]**2,
        -6*x[:,1] + 2*x[:,0]*x[:,1]
    ], dim=1)

    return val.squeeze(0) if val.shape[0] == 1 else val

def g(x):
    if x.dim() == 1:
        x = x.unsqueeze(0)
    val = torch.stack([
        torch.zeros_like(x[:,0]),
        torch.zeros_like(x[:,0])
    ], dim=1)

    return val.squeeze(0) if val.shape[0] == 1 else val

def div_f(x):
    divergence = 4*x[:,0] - 8
    return divergence.squeeze(0) if divergence.shape[0] == 1 else divergence

def div_g(x):
    """Vectorized divergence of g"""
    if x.dim() == 1:
        return torch.tensor(0.0, device=device)
    else:
        return torch.zeros(x.shape[0], device=device)

# %%
def candidate_constraint_learnt(vars,a_fun,b_fun,c_fun):
    """
    Construct candidate constraints for the learnt functions.
    
    Args:
        vars: List of dReal Variables
        a_fun: Function representing a(x).
        b_fun: Function representing b(x).
        c_fun: Function representing c(x).

    Returns:
        Symbolic expression for the candidate constraint.
    """
    a_sym = activSymbolicNN(a_fun).forward_symbolic(vars)[0]
    b_sym = SymbolicNN(b_fun).forward_symbolic(vars)
    c_sym = SymbolicNN(c_fun).forward_symbolic(vars)[0]

    # b_sym = ||b_sym||^2
    b_sym = sum([bi**2 for bi in b_sym])
    # write f and g in terms of val
    f_val = [-2*vars[0]+vars[0]**2 - vars[1]**2, -6*vars[1]+2*vars[0]*vars[1]]
    # print("f_val: ", f_val)
    g_val = [0*vars[0],0*vars[0]]
    # print("g_val: ", g_val)
    f_div = 4*vars[0]-8
    g_div = 0 
    grad_a = [a_sym.Differentiate(vars[i]) for i in range(len(vars))]
    grad_c = [c_sym.Differentiate(vars[i]) for i in range(len(vars))]
    grad_b = [b_sym.Differentiate(vars[i]) for i in range(len(vars))]

    constraint1 = a_sym * f_div + g_div * c_sym + sum([grad_a[i] * f_val[i] for i in range(len(f_val))]) + sum([grad_c[i] * g_val[i] for i in range(len(g_val))])
  
    scaled_vars = [2 * var_i for var_i in vars]
    constraint2 = [scaled_vars[i] + grad_b[i] for i in range(len(vars))]

    constraint2 = sum([constraint2[i] * (f_val[i] * a_sym + g_val[i] * c_sym) for i in range(len(f_val))])  
    constraint = constraint1 - constraint2
    return a_sym , constraint

# %%
def train_density(
    x,                          # initial sample tensor  [N, state_dim]
    f,                          # dynamics callable
    g,                          # control matrix callable
    div_f,                      # divergence of f callable
    div_g,                      # divergence of g callable
    device,
    # --- training ---
    epochs          = 2000,
    lr              = 1e-2,
    loss_threshold  = 5e-4,
    # --- SMT verification ---
    ball_lb         = 0.05,
    ball_ub         = 6.0,
    check_interval  = 10,
    n_counterex     = 100,
):
    
    # Instantiate neural networks for a, b, c, gamma
    a_net = Numerator_polynomial_net(layers=2, input_dim=1, hidden_dim=1, output_dim=1).to(device)
    b_net = Polynomial_net_bias_zero(layers=2, input_dim=2, hidden_dim=2, output_dim=2).to(device)
    c_net = Polynomial_net(layers=3, input_dim=1, hidden_dim=1, output_dim=1).to(device)
    gamma_net = GammaFunctionNet(input_dim=2,output_dim=1).to(device)

    
    # Loss and Optimizer
    criterion = stability_loss(f=f,g=g,div_f=div_f,div_g=div_g)

    optimizer = torch.optim.Adam(list(a_net.parameters()) +
                                    list(b_net.parameters()) + 
                                    list(c_net.parameters()) + 
                                    list(gamma_net.parameters()), lr=lr)
    
    # dReal Configuration
    config = Config()
    config.use_polytope_in_forall = True
    config.use_local_optimization = True
    config.precision = 1e-5   

    # CEGIS Loop
    loss_history = []
    valid = False 
    print("=" * 60)
    print("Training density function with SMT-CEGIS verification")
    print(f"  Initial dataset size: {x.shape[0]}")
    print("=" * 60)    

    while not valid:
        for epoch in range(epochs):
            optimizer.zero_grad()
            loss = criterion(x, a_net, b_net, c_net, gamma_net)         
            loss_history.append(loss.item())
            loss.backward()
            optimizer.step()

            
            # ---------- early-exit on convergence ----------
            if loss.item() < loss_threshold:
                print(f"  [Epoch {epoch}] Loss {loss.item():.6f} < threshold to checking SMT...")
                valid = True
                break

            # ---------- periodic progress print ------------
            if epoch % 50 == 0:
                print(
                    f"  Epoch {epoch:>5}/{epochs} | "
                    f"Loss: {loss.item():.6f} | "
                    f"Dataset: {x.shape[0]}"
                )            
 
            # ---------- SMT counterexample check -----------
            if epoch % check_interval == 0 and epoch > 0:
                vars_sym = [Variable("x1"), Variable("x2")]
                try:
                    a_sym, div_sym = candidate_constraint_learnt(
                        vars_sym, a_net, b_net, c_net
                    )
                    CE = checkSMTconstraints(
                        vars_sym, a_sym, div_sym, ball_lb, ball_ub, config
                    )
 
                    if CE:
                        before = x.shape[0]
                        x, _ = AddCounterexamples(x, CE, n_counterex, device)
                        after = x.shape[0]
                        print(
                            f"  [Epoch {epoch}] CE found → "
                            f"dataset {before} → {after} (+{after - before})"
                        )
                    else:
                        valid = True
                        print(f"  [Epoch {epoch}] SMT satisfied — no counterexample found ✓")
                        break
 
                except Exception as e:
                    print(f"  [Epoch {epoch}] SMT check failed: {e}")
                    continue
 
    # ------------------------------------------------------------------
    # 5. Final summary
    # ------------------------------------------------------------------
    test_point = torch.zeros(1, 2, dtype=torch.float32, device=device)
    margin     = gamma_net(test_point).item()
 
    print("\n" + "=" * 60)
    print("Training complete")
    print(f"  Final loss     : {loss_history[-1]:.6f}")
    print(f"  Learned margin : {margin:.6f}")
    print(f"  Final dataset  : {x.shape[0]}")
    print("=" * 60)
 
    return loss_history, a_net, b_net, c_net, gamma_net

# %%
print("Starting training...")
loss_history1, a_net1, b_net1, c_net1, gamma_net1 = train_density(
    numerical_x, f, g, div_f, div_g, device,
    epochs=4000,
    lr=1e-4,
    loss_threshold=5e-4,
    ball_lb=0.05,
    ball_ub=6.0,
    check_interval=500,
    n_counterex=100
)
# Out:
# Starting training...
# ============================================================
# Training density function with SMT-CEGIS verification
#   Initial dataset size: 500
# ============================================================
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[61], line 2
#       1 print("Starting training...")
# ----> 2 loss_history1, a_net1, b_net1, c_net1, gamma_net1 = train_density(
#       3     numerical_x, f, g, div_f, div_g, device,
#       4     epochs=4000,
#       5     lr=1e-4,
#       6     loss_threshold=5e-4,
#       7     ball_lb=0.05,
#       8     ball_ub=6.0,
#       9     check_interval=500,
#      10     n_counterex=100
#      11 )
#
# Cell In[60], line 51, in train_density(x, f, g, div_f, div_g, device, epochs, lr, loss_threshold, ball_lb, ball_ub, check_interval, n_counterex)
#      49 for epoch in range(epochs):
#      50     optimizer.zero_grad()
# ---> 51     loss = criterion(x, a_net, b_net, c_net, gamma_net)
#      52     loss_history.append(loss.item())
#      53     loss.backward()
#
# File ~/miniconda3/envs/dreal_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dreal_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/OneDrive/Academics/Research/Density Based Stability/Final Repo/Neural-Control-Density-Functions/Experiments/../Neural_Density_Training/loss.py:28, in stability_loss.forward(self, x, a_net, b_net, c_net, gamma_net)
#      27 def forward(self, x, a_net, b_net, c_net,gamma_net):
# ---> 28     divergence = self._control_density_risk(x, a_net, b_net, c_net)
#      29     gamma_vals = gamma_net(x).squeeze()
#      30     loss = F.relu(gamma_vals-divergence ).mean()
#
# File ~/OneDrive/Academics/Research/Density Based Stability/Final Repo/Neural-Control-Density-Functions/Experiments/../Neural_Density_Training/loss.py:55, in stability_loss._control_density_risk(self, x, a_net, b_net, c_net)
#      52 """Computes the control density risk for the given state x and networks a_net, b_net, c_net."""
#      54 # --- values --------------------------------------------------
# ---> 55 a_vals = a_net(x).squeeze()          # [B]
#      56 c_vals = c_net(x).squeeze()          # [B]
#      57 f_vals = self.f(x)                   # [B, 2]
#
# File ~/miniconda3/envs/dreal_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dreal_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/OneDrive/Academics/Research/Density Based Stability/Final Repo/Neural-Control-Density-Functions/Experiments/../Neural_Density_Training/Models.py:119, in Numerator_polynomial_net.forward(self, x)
#     117 def forward(self, x):
#     118     """Defines the forward pass of the network."""
# --> 119     return self.net(x)
#
# File ~/miniconda3/envs/dreal_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dreal_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/miniconda3/envs/dreal_env/lib/python3.8/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File ~/miniconda3/envs/dreal_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/dreal_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/miniconda3/envs/dreal_env/lib/python3.8/site-packages/torch/nn/modules/linear.py:117, in Linear.forward(self, input)
#     116 def forward(self, input: Tensor) -> Tensor:
# --> 117     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (500x2 and 1x1)

# %%
fig, ax = plot_contour_density(
    f,g,a_net1,b_net1,c_net1,x_lim = [-6,6],
    y_lim = [-6,6],
    density_threshold = 1e-12,
    title =" ",
    x_axis_title = "$x_1$",
    y_axis_title = "$x_2$",
    device = device
)

# %%
# get some fresh data 
torch.manual_seed(7)
random.seed()
# Learn a new density function with a different initial dataset

dataset= torch.Tensor(1000, 2).uniform_(-6, 6).float().to(device)

loss_history2, a_net2, b_net2, c_net2, gamma_net2 = train_density(   dataset, f, g, div_f, div_g, device,
    epochs=4000,
    lr=1e-4,
    loss_threshold=5e-4,
    ball_lb=0.05,
    ball_ub=6.0,
    check_interval=1000,
    n_counterex=100
)
# Out:
# ============================================================
# Training density function with SMT-CEGIS verification
#   Initial dataset size: 1000
# ============================================================
#   Epoch     0/4000 | Loss: 11.828092 | Dataset: 1000
#   Epoch    50/4000 | Loss: 11.797932 | Dataset: 1000
#   Epoch   100/4000 | Loss: 11.767751 | Dataset: 1000
#   Epoch   150/4000 | Loss: 11.737556 | Dataset: 1000
#   Epoch   200/4000 | Loss: 11.707345 | Dataset: 1000
#   Epoch   250/4000 | Loss: 11.677113 | Dataset: 1000
#   Epoch   300/4000 | Loss: 11.646848 | Dataset: 1000
#   Epoch   350/4000 | Loss: 11.616564 | Dataset: 1000
#   Epoch   400/4000 | Loss: 11.586242 | Dataset: 1000
#   Epoch   450/4000 | Loss: 11.555893 | Dataset: 1000
#   Epoch   500/4000 | Loss: 11.525539 | Dataset: 1000
#   Epoch   550/4000 | Loss: 11.495145 | Dataset: 1000
#   Epoch   600/4000 | Loss: 11.464717 | Dataset: 1000
#   Epoch   650/4000 | Loss: 11.434240 | Dataset: 1000
#   Epoch   700/4000 | Loss: 11.403723 | Dataset: 1000
#   Epoch   750/4000 | Loss: 11.373151 | Dataset: 1000
#   Epoch   800/4000 | Loss: 11.342530 | Dataset: 1000
#   Epoch   850/4000 | Loss: 11.311844 | Dataset: 1000
#   Epoch   900/4000 | Loss: 11.281098 | Dataset: 1000
#   Epoch   950/4000 | Loss: 11.250279 | Dataset: 1000
#   Epoch  1000/4000 | Loss: 11.219386 | Dataset: 1000
#   [Epoch 1000] CE found → dataset 1000 → 1100 (+100)
#   Epoch  1050/4000 | Loss: 10.346200 | Dataset: 1100
#   Epoch  1100/4000 | Loss: 10.316220 | Dataset: 1100
#   Epoch  1150/4000 | Loss: 10.286497 | Dataset: 1100
#   Epoch  1200/4000 | Loss: 10.256817 | Dataset: 1100
#   Epoch  1250/4000 | Loss: 10.227109 | Dataset: 1100
#   Epoch  1300/4000 | Loss: 10.197326 | Dataset: 1100
#   Epoch  1350/4000 | Loss: 10.167416 | Dataset: 1100
#   Epoch  1400/4000 | Loss: 10.137369 | Dataset: 1100
#   Epoch  1450/4000 | Loss: 10.107153 | Dataset: 1100
#   Epoch  1500/4000 | Loss: 10.076750 | Dataset: 1100
#   Epoch  1550/4000 | Loss: 10.046145 | Dataset: 1100
#   Epoch  1600/4000 | Loss: 10.015297 | Dataset: 1100
#   Epoch  1650/4000 | Loss: 9.984202 | Dataset: 1100
#   Epoch  1700/4000 | Loss: 9.952828 | Dataset: 1100
#   Epoch  1750/4000 | Loss: 9.921144 | Dataset: 1100
#   Epoch  1800/4000 | Loss: 9.889128 | Dataset: 1100
#   Epoch  1850/4000 | Loss: 9.856749 | Dataset: 1100
#   Epoch  1900/4000 | Loss: 9.823989 | Dataset: 1100
#   Epoch  1950/4000 | Loss: 9.790783 | Dataset: 1100
#   Epoch  2000/4000 | Loss: 9.757088 | Dataset: 1100
#   [Epoch 2000] CE found → dataset 1100 → 1200 (+100)
#   Epoch  2050/4000 | Loss: 9.034384 | Dataset: 1200
#   Epoch  2100/4000 | Loss: 9.001513 | Dataset: 1200
#   Epoch  2150/4000 | Loss: 8.968142 | Dataset: 1200
#   Epoch  2200/4000 | Loss: 8.934155 | Dataset: 1200
#   Epoch  2250/4000 | Loss: 8.899501 | Dataset: 1200
#   Epoch  2300/4000 | Loss: 8.864071 | Dataset: 1200
#   Epoch  2350/4000 | Loss: 8.827801 | Dataset: 1200
#   Epoch  2400/4000 | Loss: 8.790578 | Dataset: 1200
#   Epoch  2450/4000 | Loss: 8.752322 | Dataset: 1200
#   Epoch  2500/4000 | Loss: 8.712934 | Dataset: 1200
#   Epoch  2550/4000 | Loss: 8.672272 | Dataset: 1200
#   Epoch  2600/4000 | Loss: 8.630241 | Dataset: 1200
#   Epoch  2650/4000 | Loss: 8.586701 | Dataset: 1200
#   Epoch  2700/4000 | Loss: 8.541541 | Dataset: 1200
#   Epoch  2750/4000 | Loss: 8.494607 | Dataset: 1200
#   Epoch  2800/4000 | Loss: 8.445776 | Dataset: 1200
#   Epoch  2850/4000 | Loss: 8.394932 | Dataset: 1200
#   Epoch  2900/4000 | Loss: 8.341928 | Dataset: 1200
#   Epoch  2950/4000 | Loss: 8.286692 | Dataset: 1200
#   Epoch  3000/4000 | Loss: 8.229101 | Dataset: 1200
#   [Epoch 3000] CE found → dataset 1200 → 1300 (+100)
#   Epoch  3050/4000 | Loss: 7.621133 | Dataset: 1300
#   Epoch  3100/4000 | Loss: 7.564549 | Dataset: 1300
#   Epoch  3150/4000 | Loss: 7.505730 | Dataset: 1300
#   Epoch  3200/4000 | Loss: 7.444678 | Dataset: 1300
#   Epoch  3250/4000 | Loss: 7.381475 | Dataset: 1300
#   Epoch  3300/4000 | Loss: 7.316167 | Dataset: 1300
#   Epoch  3350/4000 | Loss: 7.248848 | Dataset: 1300
#   Epoch  3400/4000 | Loss: 7.179682 | Dataset: 1300
#   Epoch  3450/4000 | Loss: 7.108858 | Dataset: 1300
#   Epoch  3500/4000 | Loss: 7.036613 | Dataset: 1300
#   Epoch  3550/4000 | Loss: 6.963171 | Dataset: 1300
#   Epoch  3600/4000 | Loss: 6.888784 | Dataset: 1300
#   Epoch  3650/4000 | Loss: 6.813701 | Dataset: 1300
#   Epoch  3700/4000 | Loss: 6.738190 | Dataset: 1300
#   Epoch  3750/4000 | Loss: 6.662493 | Dataset: 1300
#   Epoch  3800/4000 | Loss: 6.586841 | Dataset: 1300
#   Epoch  3850/4000 | Loss: 6.511448 | Dataset: 1300
#   Epoch  3900/4000 | Loss: 6.436521 | Dataset: 1300
#   Epoch  3950/4000 | Loss: 6.362197 | Dataset: 1300
#   Epoch     0/4000 | Loss: 6.288636 | Dataset: 1300
#   Epoch    50/4000 | Loss: 6.215945 | Dataset: 1300
#   Epoch   100/4000 | Loss: 6.144225 | Dataset: 1300
#   Epoch   150/4000 | Loss: 6.073548 | Dataset: 1300
#   Epoch   200/4000 | Loss: 6.003974 | Dataset: 1300
#   Epoch   250/4000 | Loss: 5.935526 | Dataset: 1300
#   Epoch   300/4000 | Loss: 5.868242 | Dataset: 1300
#   Epoch   350/4000 | Loss: 5.802133 | Dataset: 1300
#   Epoch   400/4000 | Loss: 5.737196 | Dataset: 1300
#   Epoch   450/4000 | Loss: 5.673431 | Dataset: 1300
#   Epoch   500/4000 | Loss: 5.610835 | Dataset: 1300
#   Epoch   550/4000 | Loss: 5.549356 | Dataset: 1300
#   Epoch   600/4000 | Loss: 5.488981 | Dataset: 1300
#   Epoch   650/4000 | Loss: 5.429678 | Dataset: 1300
#   Epoch   700/4000 | Loss: 5.371424 | Dataset: 1300
#   Epoch   750/4000 | Loss: 5.314188 | Dataset: 1300
#   Epoch   800/4000 | Loss: 5.257948 | Dataset: 1300
#   Epoch   850/4000 | Loss: 5.202661 | Dataset: 1300
#   Epoch   900/4000 | Loss: 5.148316 | Dataset: 1300
#   Epoch   950/4000 | Loss: 5.094882 | Dataset: 1300
#   Epoch  1000/4000 | Loss: 5.042320 | Dataset: 1300
#   [Epoch 1000] CE found → dataset 1300 → 1400 (+100)
#   Epoch  1050/4000 | Loss: 4.636722 | Dataset: 1400
#   Epoch  1100/4000 | Loss: 4.592341 | Dataset: 1400
#   Epoch  1150/4000 | Loss: 4.548699 | Dataset: 1400
#   Epoch  1200/4000 | Loss: 4.505553 | Dataset: 1400
#   Epoch  1250/4000 | Loss: 4.462898 | Dataset: 1400
#   Epoch  1300/4000 | Loss: 4.420725 | Dataset: 1400
#   Epoch  1350/4000 | Loss: 4.379025 | Dataset: 1400
#   Epoch  1400/4000 | Loss: 4.337795 | Dataset: 1400
#   Epoch  1450/4000 | Loss: 4.297038 | Dataset: 1400
#   Epoch  1500/4000 | Loss: 4.256784 | Dataset: 1400
#   Epoch  1550/4000 | Loss: 4.217064 | Dataset: 1400
#   Epoch  1600/4000 | Loss: 4.177783 | Dataset: 1400
#   Epoch  1650/4000 | Loss: 4.138926 | Dataset: 1400
#   Epoch  1700/4000 | Loss: 4.100488 | Dataset: 1400
#   Epoch  1750/4000 | Loss: 4.062460 | Dataset: 1400
#   Epoch  1800/4000 | Loss: 4.024839 | Dataset: 1400
#   Epoch  1850/4000 | Loss: 3.987619 | Dataset: 1400
#   Epoch  1900/4000 | Loss: 3.950787 | Dataset: 1400
#   Epoch  1950/4000 | Loss: 3.914334 | Dataset: 1400
#   Epoch  2000/4000 | Loss: 3.878254 | Dataset: 1400
#   [Epoch 2000] CE found → dataset 1400 → 1500 (+100)
#   Epoch  2050/4000 | Loss: 3.588060 | Dataset: 1500
#   Epoch  2100/4000 | Loss: 3.557113 | Dataset: 1500
#   Epoch  2150/4000 | Loss: 3.526373 | Dataset: 1500
#   Epoch  2200/4000 | Loss: 3.495843 | Dataset: 1500
#   Epoch  2250/4000 | Loss: 3.465515 | Dataset: 1500
#   Epoch  2300/4000 | Loss: 3.435389 | Dataset: 1500
#   Epoch  2350/4000 | Loss: 3.405473 | Dataset: 1500
#   Epoch  2400/4000 | Loss: 3.375760 | Dataset: 1500
#   Epoch  2450/4000 | Loss: 3.346249 | Dataset: 1500
#   Epoch  2500/4000 | Loss: 3.316943 | Dataset: 1500
#   Epoch  2550/4000 | Loss: 3.287859 | Dataset: 1500
#   Epoch  2600/4000 | Loss: 3.259080 | Dataset: 1500
#   Epoch  2650/4000 | Loss: 3.230497 | Dataset: 1500
#   Epoch  2700/4000 | Loss: 3.202105 | Dataset: 1500
#   Epoch  2750/4000 | Loss: 3.173900 | Dataset: 1500
#   Epoch  2800/4000 | Loss: 3.145884 | Dataset: 1500
#   Epoch  2850/4000 | Loss: 3.118048 | Dataset: 1500
#   Epoch  2900/4000 | Loss: 3.090395 | Dataset: 1500
#   Epoch  2950/4000 | Loss: 3.062922 | Dataset: 1500
#   Epoch  3000/4000 | Loss: 3.035622 | Dataset: 1500
#   [Epoch 3000] CE found → dataset 1500 → 1600 (+100)
#   Epoch  3050/4000 | Loss: 2.821698 | Dataset: 1600
#   Epoch  3100/4000 | Loss: 2.797905 | Dataset: 1600
#   Epoch  3150/4000 | Loss: 2.774192 | Dataset: 1600
#   Epoch  3200/4000 | Loss: 2.750563 | Dataset: 1600
#   Epoch  3250/4000 | Loss: 2.727015 | Dataset: 1600
#   Epoch  3300/4000 | Loss: 2.703552 | Dataset: 1600
#   Epoch  3350/4000 | Loss: 2.680225 | Dataset: 1600
#   Epoch  3400/4000 | Loss: 2.656974 | Dataset: 1600
#   Epoch  3450/4000 | Loss: 2.633757 | Dataset: 1600
#   Epoch  3500/4000 | Loss: 2.610689 | Dataset: 1600
#   Epoch  3550/4000 | Loss: 2.588551 | Dataset: 1600
#   Epoch  3600/4000 | Loss: 2.566501 | Dataset: 1600
#   Epoch  3650/4000 | Loss: 2.544514 | Dataset: 1600
#   Epoch  3700/4000 | Loss: 2.522581 | Dataset: 1600
#   Epoch  3750/4000 | Loss: 2.500701 | Dataset: 1600
#   Epoch  3800/4000 | Loss: 2.478872 | Dataset: 1600
#   Epoch  3850/4000 | Loss: 2.457093 | Dataset: 1600
#   Epoch  3900/4000 | Loss: 2.435365 | Dataset: 1600
#   Epoch  3950/4000 | Loss: 2.413773 | Dataset: 1600
#   Epoch     0/4000 | Loss: 2.392275 | Dataset: 1600
#   Epoch    50/4000 | Loss: 2.370819 | Dataset: 1600
#   Epoch   100/4000 | Loss: 2.349455 | Dataset: 1600
#   Epoch   150/4000 | Loss: 2.328195 | Dataset: 1600
#   Epoch   200/4000 | Loss: 2.306980 | Dataset: 1600
#   Epoch   250/4000 | Loss: 2.285811 | Dataset: 1600
#   Epoch   300/4000 | Loss: 2.264679 | Dataset: 1600
#   Epoch   350/4000 | Loss: 2.243582 | Dataset: 1600
#   Epoch   400/4000 | Loss: 2.222546 | Dataset: 1600
#   Epoch   450/4000 | Loss: 2.201556 | Dataset: 1600
#   Epoch   500/4000 | Loss: 2.180595 | Dataset: 1600
#   Epoch   550/4000 | Loss: 2.159655 | Dataset: 1600
#   Epoch   600/4000 | Loss: 2.138732 | Dataset: 1600
#   Epoch   650/4000 | Loss: 2.117814 | Dataset: 1600
#   Epoch   700/4000 | Loss: 2.096938 | Dataset: 1600
#   Epoch   750/4000 | Loss: 2.076082 | Dataset: 1600
#   Epoch   800/4000 | Loss: 2.055228 | Dataset: 1600
#   Epoch   850/4000 | Loss: 2.034370 | Dataset: 1600
#   Epoch   900/4000 | Loss: 2.013501 | Dataset: 1600
#   Epoch   950/4000 | Loss: 1.992617 | Dataset: 1600
#   Epoch  1000/4000 | Loss: 1.971711 | Dataset: 1600
#   [Epoch 1000] CE found → dataset 1600 → 1700 (+100)
#   Epoch  1050/4000 | Loss: 1.839559 | Dataset: 1700
#   Epoch  1100/4000 | Loss: 1.820923 | Dataset: 1700
#   Epoch  1150/4000 | Loss: 1.802218 | Dataset: 1700
#   Epoch  1200/4000 | Loss: 1.783440 | Dataset: 1700
#   Epoch  1250/4000 | Loss: 1.764584 | Dataset: 1700
#   Epoch  1300/4000 | Loss: 1.745651 | Dataset: 1700
#   Epoch  1350/4000 | Loss: 1.726634 | Dataset: 1700
#   Epoch  1400/4000 | Loss: 1.707536 | Dataset: 1700
#   Epoch  1450/4000 | Loss: 1.688350 | Dataset: 1700
#   Epoch  1500/4000 | Loss: 1.669081 | Dataset: 1700
#   Epoch  1550/4000 | Loss: 1.649722 | Dataset: 1700
#   Epoch  1600/4000 | Loss: 1.630278 | Dataset: 1700
#   Epoch  1650/4000 | Loss: 1.610742 | Dataset: 1700
#   Epoch  1700/4000 | Loss: 1.591118 | Dataset: 1700
#   Epoch  1750/4000 | Loss: 1.571407 | Dataset: 1700
#   Epoch  1800/4000 | Loss: 1.551606 | Dataset: 1700
#   Epoch  1850/4000 | Loss: 1.531716 | Dataset: 1700
#   Epoch  1900/4000 | Loss: 1.511742 | Dataset: 1700
#   Epoch  1950/4000 | Loss: 1.491688 | Dataset: 1700
#   Epoch  2000/4000 | Loss: 1.471565 | Dataset: 1700
#   [Epoch 2000] CE found → dataset 1700 → 1800 (+100)
#   Epoch  2050/4000 | Loss: 1.373433 | Dataset: 1800
#   Epoch  2100/4000 | Loss: 1.355122 | Dataset: 1800
#   Epoch  2150/4000 | Loss: 1.336708 | Dataset: 1800
#   Epoch  2200/4000 | Loss: 1.318189 | Dataset: 1800
#   Epoch  2250/4000 | Loss: 1.299598 | Dataset: 1800
#   Epoch  2300/4000 | Loss: 1.280917 | Dataset: 1800
#   Epoch  2350/4000 | Loss: 1.262219 | Dataset: 1800
#   Epoch  2400/4000 | Loss: 1.243451 | Dataset: 1800
#   Epoch  2450/4000 | Loss: 1.224603 | Dataset: 1800
#   Epoch  2500/4000 | Loss: 1.205677 | Dataset: 1800
#   Epoch  2550/4000 | Loss: 1.186683 | Dataset: 1800
#   Epoch  2600/4000 | Loss: 1.167660 | Dataset: 1800
#   Epoch  2650/4000 | Loss: 1.148592 | Dataset: 1800
#   Epoch  2700/4000 | Loss: 1.129478 | Dataset: 1800
#   Epoch  2750/4000 | Loss: 1.110328 | Dataset: 1800
#   Epoch  2800/4000 | Loss: 1.091152 | Dataset: 1800
#   Epoch  2850/4000 | Loss: 1.071953 | Dataset: 1800
#   Epoch  2900/4000 | Loss: 1.052746 | Dataset: 1800
#   Epoch  2950/4000 | Loss: 1.033534 | Dataset: 1800
#   Epoch  3000/4000 | Loss: 1.014342 | Dataset: 1800
#   [Epoch 3000] CE found → dataset 1800 → 1900 (+100)
#   Epoch  3050/4000 | Loss: 0.943536 | Dataset: 1900
#   Epoch  3100/4000 | Loss: 0.926292 | Dataset: 1900
#   Epoch  3150/4000 | Loss: 0.909047 | Dataset: 1900
#   Epoch  3200/4000 | Loss: 0.891820 | Dataset: 1900
#   Epoch  3250/4000 | Loss: 0.874625 | Dataset: 1900
#   Epoch  3300/4000 | Loss: 0.857473 | Dataset: 1900
#   Epoch  3350/4000 | Loss: 0.840385 | Dataset: 1900
#   Epoch  3400/4000 | Loss: 0.823374 | Dataset: 1900
#   Epoch  3450/4000 | Loss: 0.806457 | Dataset: 1900
#   Epoch  3500/4000 | Loss: 0.789651 | Dataset: 1900
#   Epoch  3550/4000 | Loss: 0.772985 | Dataset: 1900
#   Epoch  3600/4000 | Loss: 0.756471 | Dataset: 1900
#   Epoch  3650/4000 | Loss: 0.740123 | Dataset: 1900
#   Epoch  3700/4000 | Loss: 0.723958 | Dataset: 1900
#   Epoch  3750/4000 | Loss: 0.707996 | Dataset: 1900
#   Epoch  3800/4000 | Loss: 0.692256 | Dataset: 1900
#   Epoch  3850/4000 | Loss: 0.676751 | Dataset: 1900
#   Epoch  3900/4000 | Loss: 0.661493 | Dataset: 1900
#   Epoch  3950/4000 | Loss: 0.646484 | Dataset: 1900
#   Epoch     0/4000 | Loss: 0.631704 | Dataset: 1900
#   Epoch    50/4000 | Loss: 0.617271 | Dataset: 1900
#   Epoch   100/4000 | Loss: 0.603187 | Dataset: 1900
#   Epoch   150/4000 | Loss: 0.589427 | Dataset: 1900
#   Epoch   200/4000 | Loss: 0.576001 | Dataset: 1900
#   Epoch   250/4000 | Loss: 0.562912 | Dataset: 1900
#   Epoch   300/4000 | Loss: 0.550160 | Dataset: 1900
#   Epoch   350/4000 | Loss: 0.537755 | Dataset: 1900
#   Epoch   400/4000 | Loss: 0.525704 | Dataset: 1900
#   Epoch   450/4000 | Loss: 0.514006 | Dataset: 1900
#   Epoch   500/4000 | Loss: 0.502657 | Dataset: 1900
#   Epoch   550/4000 | Loss: 0.491659 | Dataset: 1900
#   Epoch   600/4000 | Loss: 0.481005 | Dataset: 1900
#   Epoch   650/4000 | Loss: 0.470692 | Dataset: 1900
#   Epoch   700/4000 | Loss: 0.460712 | Dataset: 1900
#   Epoch   750/4000 | Loss: 0.451069 | Dataset: 1900
#   Epoch   800/4000 | Loss: 0.441743 | Dataset: 1900
#   Epoch   850/4000 | Loss: 0.432735 | Dataset: 1900
#   Epoch   900/4000 | Loss: 0.424032 | Dataset: 1900
#   Epoch   950/4000 | Loss: 0.415634 | Dataset: 1900
#   Epoch  1000/4000 | Loss: 0.407518 | Dataset: 1900
#   [Epoch 1000] CE found → dataset 1900 → 2000 (+100)
#   Epoch  1050/4000 | Loss: 0.380487 | Dataset: 2000
#   Epoch  1100/4000 | Loss: 0.373582 | Dataset: 2000
#   Epoch  1150/4000 | Loss: 0.366929 | Dataset: 2000
#   Epoch  1200/4000 | Loss: 0.360492 | Dataset: 2000
#   Epoch  1250/4000 | Loss: 0.354250 | Dataset: 2000
#   Epoch  1300/4000 | Loss: 0.348203 | Dataset: 2000
#   Epoch  1350/4000 | Loss: 0.342349 | Dataset: 2000
#   Epoch  1400/4000 | Loss: 0.336671 | Dataset: 2000
#   Epoch  1450/4000 | Loss: 0.331174 | Dataset: 2000
#   Epoch  1500/4000 | Loss: 0.325842 | Dataset: 2000
#   Epoch  1550/4000 | Loss: 0.320671 | Dataset: 2000
#   Epoch  1600/4000 | Loss: 0.315658 | Dataset: 2000
#   Epoch  1650/4000 | Loss: 0.310791 | Dataset: 2000
#   Epoch  1700/4000 | Loss: 0.306076 | Dataset: 2000
#   Epoch  1750/4000 | Loss: 0.301486 | Dataset: 2000
#   Epoch  1800/4000 | Loss: 0.297031 | Dataset: 2000
#   Epoch  1850/4000 | Loss: 0.292705 | Dataset: 2000
#   Epoch  1900/4000 | Loss: 0.288492 | Dataset: 2000
#   Epoch  1950/4000 | Loss: 0.284404 | Dataset: 2000
#   Epoch  2000/4000 | Loss: 0.280420 | Dataset: 2000
#   [Epoch 2000] CE found → dataset 2000 → 2100 (+100)
#   Epoch  2050/4000 | Loss: 0.263775 | Dataset: 2100
#   Epoch  2100/4000 | Loss: 0.260302 | Dataset: 2100
#   Epoch  2150/4000 | Loss: 0.256899 | Dataset: 2100
#   Epoch  2200/4000 | Loss: 0.253576 | Dataset: 2100
#   Epoch  2250/4000 | Loss: 0.250353 | Dataset: 2100
#   Epoch  2300/4000 | Loss: 0.247201 | Dataset: 2100
#   Epoch  2350/4000 | Loss: 0.244116 | Dataset: 2100
#   Epoch  2400/4000 | Loss: 0.241104 | Dataset: 2100
#   Epoch  2450/4000 | Loss: 0.238172 | Dataset: 2100
#   Epoch  2500/4000 | Loss: 0.235297 | Dataset: 2100
#   Epoch  2550/4000 | Loss: 0.232484 | Dataset: 2100
#   Epoch  2600/4000 | Loss: 0.229727 | Dataset: 2100
#   Epoch  2650/4000 | Loss: 0.227025 | Dataset: 2100
#   Epoch  2700/4000 | Loss: 0.224376 | Dataset: 2100
#   Epoch  2750/4000 | Loss: 0.221782 | Dataset: 2100
#   Epoch  2800/4000 | Loss: 0.219233 | Dataset: 2100
#   Epoch  2850/4000 | Loss: 0.216741 | Dataset: 2100
#   Epoch  2900/4000 | Loss: 0.214285 | Dataset: 2100
#   Epoch  2950/4000 | Loss: 0.211879 | Dataset: 2100
#   Epoch  3000/4000 | Loss: 0.209514 | Dataset: 2100
#   [Epoch 3000] CE found → dataset 2100 → 2200 (+100)
#   Epoch  3050/4000 | Loss: 0.197853 | Dataset: 2200
#   Epoch  3100/4000 | Loss: 0.195771 | Dataset: 2200
#   Epoch  3150/4000 | Loss: 0.193716 | Dataset: 2200
#   Epoch  3200/4000 | Loss: 0.191694 | Dataset: 2200
#   Epoch  3250/4000 | Loss: 0.189705 | Dataset: 2200
#   Epoch  3300/4000 | Loss: 0.187743 | Dataset: 2200
#   Epoch  3350/4000 | Loss: 0.185809 | Dataset: 2200
#   Epoch  3400/4000 | Loss: 0.183902 | Dataset: 2200
#   Epoch  3450/4000 | Loss: 0.182021 | Dataset: 2200
#   Epoch  3500/4000 | Loss: 0.180173 | Dataset: 2200
#   Epoch  3550/4000 | Loss: 0.178342 | Dataset: 2200
#   Epoch  3600/4000 | Loss: 0.176543 | Dataset: 2200
#   Epoch  3650/4000 | Loss: 0.174765 | Dataset: 2200
#   Epoch  3700/4000 | Loss: 0.173014 | Dataset: 2200
#   Epoch  3750/4000 | Loss: 0.171283 | Dataset: 2200
#   Epoch  3800/4000 | Loss: 0.169576 | Dataset: 2200
#   Epoch  3850/4000 | Loss: 0.167892 | Dataset: 2200
#   Epoch  3900/4000 | Loss: 0.166230 | Dataset: 2200
#   Epoch  3950/4000 | Loss: 0.164589 | Dataset: 2200
#   Epoch     0/4000 | Loss: 0.162968 | Dataset: 2200
#   Epoch    50/4000 | Loss: 0.161371 | Dataset: 2200
#   Epoch   100/4000 | Loss: 0.159790 | Dataset: 2200
#   Epoch   150/4000 | Loss: 0.158236 | Dataset: 2200
#   Epoch   200/4000 | Loss: 0.156693 | Dataset: 2200
#   Epoch   250/4000 | Loss: 0.155169 | Dataset: 2200
#   Epoch   300/4000 | Loss: 0.153669 | Dataset: 2200
#   Epoch   350/4000 | Loss: 0.152181 | Dataset: 2200
#   Epoch   400/4000 | Loss: 0.150715 | Dataset: 2200
#   Epoch   450/4000 | Loss: 0.149267 | Dataset: 2200
#   Epoch   500/4000 | Loss: 0.147833 | Dataset: 2200
#   Epoch   550/4000 | Loss: 0.146418 | Dataset: 2200
#   Epoch   600/4000 | Loss: 0.145019 | Dataset: 2200
#   Epoch   650/4000 | Loss: 0.143641 | Dataset: 2200
#   Epoch   700/4000 | Loss: 0.142273 | Dataset: 2200
#   Epoch   750/4000 | Loss: 0.140921 | Dataset: 2200
#   Epoch   800/4000 | Loss: 0.139586 | Dataset: 2200
#   Epoch   850/4000 | Loss: 0.138268 | Dataset: 2200
#   Epoch   900/4000 | Loss: 0.136960 | Dataset: 2200
#   Epoch   950/4000 | Loss: 0.135671 | Dataset: 2200
#   Epoch  1000/4000 | Loss: 0.134395 | Dataset: 2200
#   [Epoch 1000] CE found → dataset 2200 → 2300 (+100)
#   Epoch  1050/4000 | Loss: 0.127385 | Dataset: 2300
#   Epoch  1100/4000 | Loss: 0.126240 | Dataset: 2300
#   Epoch  1150/4000 | Loss: 0.125105 | Dataset: 2300
#   Epoch  1200/4000 | Loss: 0.123982 | Dataset: 2300
#   Epoch  1250/4000 | Loss: 0.122868 | Dataset: 2300
#   Epoch  1300/4000 | Loss: 0.121763 | Dataset: 2300
#   Epoch  1350/4000 | Loss: 0.120672 | Dataset: 2300
#   Epoch  1400/4000 | Loss: 0.119587 | Dataset: 2300
#   Epoch  1450/4000 | Loss: 0.118513 | Dataset: 2300
#   Epoch  1500/4000 | Loss: 0.117451 | Dataset: 2300
#   Epoch  1550/4000 | Loss: 0.116396 | Dataset: 2300
#   Epoch  1600/4000 | Loss: 0.115354 | Dataset: 2300
#   Epoch  1650/4000 | Loss: 0.114319 | Dataset: 2300
#   Epoch  1700/4000 | Loss: 0.113294 | Dataset: 2300
#   Epoch  1750/4000 | Loss: 0.112279 | Dataset: 2300
#   Epoch  1800/4000 | Loss: 0.111277 | Dataset: 2300
#   Epoch  1850/4000 | Loss: 0.110277 | Dataset: 2300
#   Epoch  1900/4000 | Loss: 0.109290 | Dataset: 2300
#   Epoch  1950/4000 | Loss: 0.108310 | Dataset: 2300
#   Epoch  2000/4000 | Loss: 0.107341 | Dataset: 2300
#   [Epoch 2000] CE found → dataset 2300 → 2400 (+100)
#   Epoch  2050/4000 | Loss: 0.101979 | Dataset: 2400
#   Epoch  2100/4000 | Loss: 0.101103 | Dataset: 2400
#   Epoch  2150/4000 | Loss: 0.100234 | Dataset: 2400
#   Epoch  2200/4000 | Loss: 0.099372 | Dataset: 2400
#   Epoch  2250/4000 | Loss: 0.098516 | Dataset: 2400
#   Epoch  2300/4000 | Loss: 0.097668 | Dataset: 2400
#   Epoch  2350/4000 | Loss: 0.096827 | Dataset: 2400
#   Epoch  2400/4000 | Loss: 0.095990 | Dataset: 2400
#   Epoch  2450/4000 | Loss: 0.095160 | Dataset: 2400
#   Epoch  2500/4000 | Loss: 0.094339 | Dataset: 2400
#   Epoch  2550/4000 | Loss: 0.093523 | Dataset: 2400
#   Epoch  2600/4000 | Loss: 0.092713 | Dataset: 2400
#   Epoch  2650/4000 | Loss: 0.091911 | Dataset: 2400
#   Epoch  2700/4000 | Loss: 0.091114 | Dataset: 2400
#   Epoch  2750/4000 | Loss: 0.090323 | Dataset: 2400
#   Epoch  2800/4000 | Loss: 0.089541 | Dataset: 2400
#   Epoch  2850/4000 | Loss: 0.088764 | Dataset: 2400
#   Epoch  2900/4000 | Loss: 0.087993 | Dataset: 2400
#   Epoch  2950/4000 | Loss: 0.087230 | Dataset: 2400
#   Epoch  3000/4000 | Loss: 0.086474 | Dataset: 2400
#   [Epoch 3000] CE found → dataset 2400 → 2500 (+100)
#   Epoch  3050/4000 | Loss: 0.082318 | Dataset: 2500
#   Epoch  3100/4000 | Loss: 0.081629 | Dataset: 2500
#   Epoch  3150/4000 | Loss: 0.080945 | Dataset: 2500
#   Epoch  3200/4000 | Loss: 0.080266 | Dataset: 2500
#   Epoch  3250/4000 | Loss: 0.079592 | Dataset: 2500
#   Epoch  3300/4000 | Loss: 0.078925 | Dataset: 2500
#   Epoch  3350/4000 | Loss: 0.078260 | Dataset: 2500
#   Epoch  3400/4000 | Loss: 0.077600 | Dataset: 2500
#   Epoch  3450/4000 | Loss: 0.076944 | Dataset: 2500
#   Epoch  3500/4000 | Loss: 0.076294 | Dataset: 2500
#   Epoch  3550/4000 | Loss: 0.075649 | Dataset: 2500
#   Epoch  3600/4000 | Loss: 0.075010 | Dataset: 2500
#   Epoch  3650/4000 | Loss: 0.074374 | Dataset: 2500
#   Epoch  3700/4000 | Loss: 0.073743 | Dataset: 2500
#   Epoch  3750/4000 | Loss: 0.073119 | Dataset: 2500
#   Epoch  3800/4000 | Loss: 0.072496 | Dataset: 2500
#   Epoch  3850/4000 | Loss: 0.071880 | Dataset: 2500
#   Epoch  3900/4000 | Loss: 0.071269 | Dataset: 2500
#   Epoch  3950/4000 | Loss: 0.070664 | Dataset: 2500
#   Epoch     0/4000 | Loss: 0.070061 | Dataset: 2500
#   Epoch    50/4000 | Loss: 0.069463 | Dataset: 2500
#   Epoch   100/4000 | Loss: 0.068873 | Dataset: 2500
#   Epoch   150/4000 | Loss: 0.068285 | Dataset: 2500
#   Epoch   200/4000 | Loss: 0.067702 | Dataset: 2500
#   Epoch   250/4000 | Loss: 0.067128 | Dataset: 2500
#   Epoch   300/4000 | Loss: 0.066551 | Dataset: 2500
#   Epoch   350/4000 | Loss: 0.065982 | Dataset: 2500
#   Epoch   400/4000 | Loss: 0.065421 | Dataset: 2500
#   Epoch   450/4000 | Loss: 0.064859 | Dataset: 2500
#   Epoch   500/4000 | Loss: 0.064305 | Dataset: 2500
#   Epoch   550/4000 | Loss: 0.063755 | Dataset: 2500
#   Epoch   600/4000 | Loss: 0.063211 | Dataset: 2500
#   Epoch   650/4000 | Loss: 0.062671 | Dataset: 2500
#   Epoch   700/4000 | Loss: 0.062133 | Dataset: 2500
#   Epoch   750/4000 | Loss: 0.061603 | Dataset: 2500
#   Epoch   800/4000 | Loss: 0.061078 | Dataset: 2500
#   Epoch   850/4000 | Loss: 0.060552 | Dataset: 2500
#   Epoch   900/4000 | Loss: 0.060034 | Dataset: 2500
#   Epoch   950/4000 | Loss: 0.059520 | Dataset: 2500
#   Epoch  1000/4000 | Loss: 0.059012 | Dataset: 2500
#   [Epoch 1000] CE found → dataset 2500 → 2600 (+100)
#   Epoch  1050/4000 | Loss: 0.056272 | Dataset: 2600
#   Epoch  1100/4000 | Loss: 0.055806 | Dataset: 2600
#   Epoch  1150/4000 | Loss: 0.055349 | Dataset: 2600
#   Epoch  1200/4000 | Loss: 0.054890 | Dataset: 2600
#   Epoch  1250/4000 | Loss: 0.054434 | Dataset: 2600
#   Epoch  1300/4000 | Loss: 0.053983 | Dataset: 2600
#   Epoch  1350/4000 | Loss: 0.053536 | Dataset: 2600
#   Epoch  1400/4000 | Loss: 0.053092 | Dataset: 2600
#   Epoch  1450/4000 | Loss: 0.052649 | Dataset: 2600
#   Epoch  1500/4000 | Loss: 0.052211 | Dataset: 2600
#   Epoch  1550/4000 | Loss: 0.051776 | Dataset: 2600
#   Epoch  1600/4000 | Loss: 0.051345 | Dataset: 2600
#   Epoch  1650/4000 | Loss: 0.050916 | Dataset: 2600
#   Epoch  1700/4000 | Loss: 0.050492 | Dataset: 2600
#   Epoch  1750/4000 | Loss: 0.050070 | Dataset: 2600
#   Epoch  1800/4000 | Loss: 0.049651 | Dataset: 2600
#   Epoch  1850/4000 | Loss: 0.049236 | Dataset: 2600
#   Epoch  1900/4000 | Loss: 0.048824 | Dataset: 2600
#   Epoch  1950/4000 | Loss: 0.048415 | Dataset: 2600
#   Epoch  2000/4000 | Loss: 0.048011 | Dataset: 2600
#   [Epoch 2000] CE found → dataset 2600 → 2700 (+100)
#   Epoch  2050/4000 | Loss: 0.045856 | Dataset: 2700
#   Epoch  2100/4000 | Loss: 0.045486 | Dataset: 2700
#   Epoch  2150/4000 | Loss: 0.045117 | Dataset: 2700
#   Epoch  2200/4000 | Loss: 0.044751 | Dataset: 2700
#   Epoch  2250/4000 | Loss: 0.044389 | Dataset: 2700
#   Epoch  2300/4000 | Loss: 0.044025 | Dataset: 2700
#   Epoch  2350/4000 | Loss: 0.043666 | Dataset: 2700
#   Epoch  2400/4000 | Loss: 0.043311 | Dataset: 2700
#   Epoch  2450/4000 | Loss: 0.042958 | Dataset: 2700
#   Epoch  2500/4000 | Loss: 0.042605 | Dataset: 2700
#   Epoch  2550/4000 | Loss: 0.042255 | Dataset: 2700
#   Epoch  2600/4000 | Loss: 0.041909 | Dataset: 2700
#   Epoch  2650/4000 | Loss: 0.041566 | Dataset: 2700
#   Epoch  2700/4000 | Loss: 0.041224 | Dataset: 2700
#   Epoch  2750/4000 | Loss: 0.040885 | Dataset: 2700
#   Epoch  2800/4000 | Loss: 0.040547 | Dataset: 2700
#   Epoch  2850/4000 | Loss: 0.040213 | Dataset: 2700
#   Epoch  2900/4000 | Loss: 0.039882 | Dataset: 2700
#   Epoch  2950/4000 | Loss: 0.039551 | Dataset: 2700
#   Epoch  3000/4000 | Loss: 0.039224 | Dataset: 2700
#   [Epoch 3000] CE found → dataset 2700 → 2800 (+100)
#   Epoch  3050/4000 | Loss: 0.037521 | Dataset: 2800
#   Epoch  3100/4000 | Loss: 0.037219 | Dataset: 2800
#   Epoch  3150/4000 | Loss: 0.036923 | Dataset: 2800
#   Epoch  3200/4000 | Loss: 0.036627 | Dataset: 2800
#   Epoch  3250/4000 | Loss: 0.036335 | Dataset: 2800
#   Epoch  3300/4000 | Loss: 0.036040 | Dataset: 2800
#   Epoch  3350/4000 | Loss: 0.035752 | Dataset: 2800
#   Epoch  3400/4000 | Loss: 0.035462 | Dataset: 2800
#   Epoch  3450/4000 | Loss: 0.035175 | Dataset: 2800
#   Epoch  3500/4000 | Loss: 0.034891 | Dataset: 2800
#   Epoch  3550/4000 | Loss: 0.034610 | Dataset: 2800
#   Epoch  3600/4000 | Loss: 0.034330 | Dataset: 2800
#   Epoch  3650/4000 | Loss: 0.034052 | Dataset: 2800
#   Epoch  3700/4000 | Loss: 0.033775 | Dataset: 2800
#   Epoch  3750/4000 | Loss: 0.033500 | Dataset: 2800
#   Epoch  3800/4000 | Loss: 0.033228 | Dataset: 2800
#   Epoch  3850/4000 | Loss: 0.032956 | Dataset: 2800
#   Epoch  3900/4000 | Loss: 0.032688 | Dataset: 2800
#   Epoch  3950/4000 | Loss: 0.032421 | Dataset: 2800
#   Epoch     0/4000 | Loss: 0.032157 | Dataset: 2800
#   Epoch    50/4000 | Loss: 0.031894 | Dataset: 2800
#   Epoch   100/4000 | Loss: 0.031634 | Dataset: 2800
#   Epoch   150/4000 | Loss: 0.031372 | Dataset: 2800
#   Epoch   200/4000 | Loss: 0.031116 | Dataset: 2800
#   Epoch   250/4000 | Loss: 0.030860 | Dataset: 2800
#   Epoch   300/4000 | Loss: 0.030607 | Dataset: 2800
#   Epoch   350/4000 | Loss: 0.030357 | Dataset: 2800
#   Epoch   400/4000 | Loss: 0.030106 | Dataset: 2800
#   Epoch   450/4000 | Loss: 0.029859 | Dataset: 2800
#   Epoch   500/4000 | Loss: 0.029612 | Dataset: 2800
#   Epoch   550/4000 | Loss: 0.029370 | Dataset: 2800
#   Epoch   600/4000 | Loss: 0.029127 | Dataset: 2800
#   Epoch   650/4000 | Loss: 0.028887 | Dataset: 2800
#   Epoch   700/4000 | Loss: 0.028649 | Dataset: 2800
#   Epoch   750/4000 | Loss: 0.028414 | Dataset: 2800
#   Epoch   800/4000 | Loss: 0.028180 | Dataset: 2800
#   Epoch   850/4000 | Loss: 0.027945 | Dataset: 2800
#   Epoch   900/4000 | Loss: 0.027716 | Dataset: 2800
#   Epoch   950/4000 | Loss: 0.027486 | Dataset: 2800
#   Epoch  1000/4000 | Loss: 0.027260 | Dataset: 2800
#   [Epoch 1000] CE found → dataset 2800 → 2900 (+100)
#   Epoch  1050/4000 | Loss: 0.026107 | Dataset: 2900
#   Epoch  1100/4000 | Loss: 0.025899 | Dataset: 2900
#   Epoch  1150/4000 | Loss: 0.025692 | Dataset: 2900
#   Epoch  1200/4000 | Loss: 0.025484 | Dataset: 2900
#   Epoch  1250/4000 | Loss: 0.025280 | Dataset: 2900
#   Epoch  1300/4000 | Loss: 0.025077 | Dataset: 2900
#   Epoch  1350/4000 | Loss: 0.024874 | Dataset: 2900
#   Epoch  1400/4000 | Loss: 0.024676 | Dataset: 2900
#   Epoch  1450/4000 | Loss: 0.024476 | Dataset: 2900
#   Epoch  1500/4000 | Loss: 0.024278 | Dataset: 2900
#   Epoch  1550/4000 | Loss: 0.024082 | Dataset: 2900
#   Epoch  1600/4000 | Loss: 0.023886 | Dataset: 2900
#   Epoch  1650/4000 | Loss: 0.023693 | Dataset: 2900
#   Epoch  1700/4000 | Loss: 0.023500 | Dataset: 2900
#   Epoch  1750/4000 | Loss: 0.023309 | Dataset: 2900
#   Epoch  1800/4000 | Loss: 0.023123 | Dataset: 2900
#   Epoch  1850/4000 | Loss: 0.022931 | Dataset: 2900
#   Epoch  1900/4000 | Loss: 0.022745 | Dataset: 2900
#   Epoch  1950/4000 | Loss: 0.022560 | Dataset: 2900
#   Epoch  2000/4000 | Loss: 0.022377 | Dataset: 2900
#   [Epoch 2000] CE found → dataset 2900 → 3000 (+100)
#   Epoch  2050/4000 | Loss: 0.021459 | Dataset: 3000
#   Epoch  2100/4000 | Loss: 0.021288 | Dataset: 3000
#   Epoch  2150/4000 | Loss: 0.021119 | Dataset: 3000
#   Epoch  2200/4000 | Loss: 0.020952 | Dataset: 3000
#   Epoch  2250/4000 | Loss: 0.020786 | Dataset: 3000
#   Epoch  2300/4000 | Loss: 0.020620 | Dataset: 3000
#   Epoch  2350/4000 | Loss: 0.020456 | Dataset: 3000
#   Epoch  2400/4000 | Loss: 0.020295 | Dataset: 3000
#   Epoch  2450/4000 | Loss: 0.020130 | Dataset: 3000
#   Epoch  2500/4000 | Loss: 0.019969 | Dataset: 3000
#   Epoch  2550/4000 | Loss: 0.019808 | Dataset: 3000
#   Epoch  2600/4000 | Loss: 0.019650 | Dataset: 3000
#   Epoch  2650/4000 | Loss: 0.019492 | Dataset: 3000
#   Epoch  2700/4000 | Loss: 0.019335 | Dataset: 3000
#   Epoch  2750/4000 | Loss: 0.019180 | Dataset: 3000
#   Epoch  2800/4000 | Loss: 0.019025 | Dataset: 3000
#   Epoch  2850/4000 | Loss: 0.018870 | Dataset: 3000
#   Epoch  2900/4000 | Loss: 0.018718 | Dataset: 3000
#   Epoch  2950/4000 | Loss: 0.018567 | Dataset: 3000
#   Epoch  3000/4000 | Loss: 0.018416 | Dataset: 3000
#   [Epoch 3000] CE found → dataset 3000 → 3100 (+100)
#   Epoch  3050/4000 | Loss: 0.017681 | Dataset: 3100
#   Epoch  3100/4000 | Loss: 0.017542 | Dataset: 3100
#   Epoch  3150/4000 | Loss: 0.017404 | Dataset: 3100
#   Epoch  3200/4000 | Loss: 0.017267 | Dataset: 3100
#   Epoch  3250/4000 | Loss: 0.017130 | Dataset: 3100
#   Epoch  3300/4000 | Loss: 0.016994 | Dataset: 3100
#   Epoch  3350/4000 | Loss: 0.016860 | Dataset: 3100
#   Epoch  3400/4000 | Loss: 0.016728 | Dataset: 3100
#   Epoch  3450/4000 | Loss: 0.016593 | Dataset: 3100
#   Epoch  3500/4000 | Loss: 0.016462 | Dataset: 3100
#   Epoch  3550/4000 | Loss: 0.016330 | Dataset: 3100
#   Epoch  3600/4000 | Loss: 0.016199 | Dataset: 3100
#   Epoch  3650/4000 | Loss: 0.016070 | Dataset: 3100
#   Epoch  3700/4000 | Loss: 0.015940 | Dataset: 3100
#   Epoch  3750/4000 | Loss: 0.015812 | Dataset: 3100
#   Epoch  3800/4000 | Loss: 0.015685 | Dataset: 3100
#   Epoch  3850/4000 | Loss: 0.015559 | Dataset: 3100
#   Epoch  3900/4000 | Loss: 0.015434 | Dataset: 3100
#   Epoch  3950/4000 | Loss: 0.015310 | Dataset: 3100
#   Epoch     0/4000 | Loss: 0.015186 | Dataset: 3100
#   Epoch    50/4000 | Loss: 0.015064 | Dataset: 3100
#   Epoch   100/4000 | Loss: 0.014943 | Dataset: 3100
#   Epoch   150/4000 | Loss: 0.014822 | Dataset: 3100
#   Epoch   200/4000 | Loss: 0.014701 | Dataset: 3100
#   Epoch   250/4000 | Loss: 0.014583 | Dataset: 3100
#   Epoch   300/4000 | Loss: 0.014466 | Dataset: 3100
#   Epoch   350/4000 | Loss: 0.014347 | Dataset: 3100
#   Epoch   400/4000 | Loss: 0.014231 | Dataset: 3100
#   Epoch   450/4000 | Loss: 0.014115 | Dataset: 3100
#   Epoch   500/4000 | Loss: 0.014001 | Dataset: 3100
#   Epoch   550/4000 | Loss: 0.013886 | Dataset: 3100
#   Epoch   600/4000 | Loss: 0.013775 | Dataset: 3100
#   Epoch   650/4000 | Loss: 0.013663 | Dataset: 3100
#   Epoch   700/4000 | Loss: 0.013550 | Dataset: 3100
#   Epoch   750/4000 | Loss: 0.013440 | Dataset: 3100
#   Epoch   800/4000 | Loss: 0.013331 | Dataset: 3100
#   Epoch   850/4000 | Loss: 0.013224 | Dataset: 3100
#   Epoch   900/4000 | Loss: 0.013115 | Dataset: 3100
#   Epoch   950/4000 | Loss: 0.013007 | Dataset: 3100
#   Epoch  1000/4000 | Loss: 0.012901 | Dataset: 3100
#   [Epoch 1000] CE found → dataset 3100 → 3200 (+100)
#   Epoch  1050/4000 | Loss: 0.012398 | Dataset: 3200
#   Epoch  1100/4000 | Loss: 0.012299 | Dataset: 3200
#   Epoch  1150/4000 | Loss: 0.012202 | Dataset: 3200
#   Epoch  1200/4000 | Loss: 0.012106 | Dataset: 3200
#   Epoch  1250/4000 | Loss: 0.012009 | Dataset: 3200
#   Epoch  1300/4000 | Loss: 0.011914 | Dataset: 3200
#   Epoch  1350/4000 | Loss: 0.011818 | Dataset: 3200
#   Epoch  1400/4000 | Loss: 0.011723 | Dataset: 3200
#   Epoch  1450/4000 | Loss: 0.011629 | Dataset: 3200
#   Epoch  1500/4000 | Loss: 0.011537 | Dataset: 3200
#   Epoch  1550/4000 | Loss: 0.011445 | Dataset: 3200
#   Epoch  1600/4000 | Loss: 0.011352 | Dataset: 3200
#   Epoch  1650/4000 | Loss: 0.011260 | Dataset: 3200
#   Epoch  1700/4000 | Loss: 0.011171 | Dataset: 3200
#   Epoch  1750/4000 | Loss: 0.011080 | Dataset: 3200
#   Epoch  1800/4000 | Loss: 0.010991 | Dataset: 3200
#   Epoch  1850/4000 | Loss: 0.010902 | Dataset: 3200
#   Epoch  1900/4000 | Loss: 0.010815 | Dataset: 3200
#   Epoch  1950/4000 | Loss: 0.010728 | Dataset: 3200
#   Epoch  2000/4000 | Loss: 0.010641 | Dataset: 3200
#   [Epoch 2000] CE found → dataset 3200 → 3300 (+100)
#   Epoch  2050/4000 | Loss: 0.010238 | Dataset: 3300
#   Epoch  2100/4000 | Loss: 0.010156 | Dataset: 3300
#   Epoch  2150/4000 | Loss: 0.010077 | Dataset: 3300
#   Epoch  2200/4000 | Loss: 0.009997 | Dataset: 3300
#   Epoch  2250/4000 | Loss: 0.009918 | Dataset: 3300
#   Epoch  2300/4000 | Loss: 0.009839 | Dataset: 3300
#   Epoch  2350/4000 | Loss: 0.009761 | Dataset: 3300
#   Epoch  2400/4000 | Loss: 0.009685 | Dataset: 3300
#   Epoch  2450/4000 | Loss: 0.009607 | Dataset: 3300
#   Epoch  2500/4000 | Loss: 0.009531 | Dataset: 3300
#   Epoch  2550/4000 | Loss: 0.009455 | Dataset: 3300
#   Epoch  2600/4000 | Loss: 0.009380 | Dataset: 3300
#   Epoch  2650/4000 | Loss: 0.009306 | Dataset: 3300
#   Epoch  2700/4000 | Loss: 0.009230 | Dataset: 3300
#   Epoch  2750/4000 | Loss: 0.009156 | Dataset: 3300
#   Epoch  2800/4000 | Loss: 0.009083 | Dataset: 3300
#   Epoch  2850/4000 | Loss: 0.009010 | Dataset: 3300
#   Epoch  2900/4000 | Loss: 0.008938 | Dataset: 3300
#   Epoch  2950/4000 | Loss: 0.008866 | Dataset: 3300
#   Epoch  3000/4000 | Loss: 0.008795 | Dataset: 3300
#   [Epoch 3000] CE found → dataset 3300 → 3400 (+100)
#   Epoch  3050/4000 | Loss: 0.008469 | Dataset: 3400
#   Epoch  3100/4000 | Loss: 0.008402 | Dataset: 3400
#   Epoch  3150/4000 | Loss: 0.008336 | Dataset: 3400
#   Epoch  3200/4000 | Loss: 0.008271 | Dataset: 3400
#   Epoch  3250/4000 | Loss: 0.008206 | Dataset: 3400
#   Epoch  3300/4000 | Loss: 0.008141 | Dataset: 3400
#   Epoch  3350/4000 | Loss: 0.008076 | Dataset: 3400
#   Epoch  3400/4000 | Loss: 0.008012 | Dataset: 3400
#   Epoch  3450/4000 | Loss: 0.007949 | Dataset: 3400
#   Epoch  3500/4000 | Loss: 0.007886 | Dataset: 3400
#   Epoch  3550/4000 | Loss: 0.007823 | Dataset: 3400
#   Epoch  3600/4000 | Loss: 0.007761 | Dataset: 3400
#   Epoch  3650/4000 | Loss: 0.007699 | Dataset: 3400
#   Epoch  3700/4000 | Loss: 0.007638 | Dataset: 3400
#   Epoch  3750/4000 | Loss: 0.007577 | Dataset: 3400
#   Epoch  3800/4000 | Loss: 0.007516 | Dataset: 3400
#   Epoch  3850/4000 | Loss: 0.007456 | Dataset: 3400
#   Epoch  3900/4000 | Loss: 0.007396 | Dataset: 3400
#   Epoch  3950/4000 | Loss: 0.007337 | Dataset: 3400
#   Epoch     0/4000 | Loss: 0.007278 | Dataset: 3400
#   Epoch    50/4000 | Loss: 0.007220 | Dataset: 3400
#   Epoch   100/4000 | Loss: 0.007162 | Dataset: 3400
#   Epoch   150/4000 | Loss: 0.007104 | Dataset: 3400
#   Epoch   200/4000 | Loss: 0.007048 | Dataset: 3400
#   Epoch   250/4000 | Loss: 0.006990 | Dataset: 3400
#   Epoch   300/4000 | Loss: 0.006934 | Dataset: 3400
#   Epoch   350/4000 | Loss: 0.006878 | Dataset: 3400
#   Epoch   400/4000 | Loss: 0.006822 | Dataset: 3400
#   Epoch   450/4000 | Loss: 0.006767 | Dataset: 3400
#   Epoch   500/4000 | Loss: 0.006713 | Dataset: 3400
#   Epoch   550/4000 | Loss: 0.006658 | Dataset: 3400
#   Epoch   600/4000 | Loss: 0.006604 | Dataset: 3400
#   Epoch   650/4000 | Loss: 0.006551 | Dataset: 3400
#   Epoch   700/4000 | Loss: 0.006499 | Dataset: 3400
#   Epoch   750/4000 | Loss: 0.006446 | Dataset: 3400
#   Epoch   800/4000 | Loss: 0.006393 | Dataset: 3400
#   Epoch   850/4000 | Loss: 0.006341 | Dataset: 3400
#   Epoch   900/4000 | Loss: 0.006289 | Dataset: 3400
#   Epoch   950/4000 | Loss: 0.006238 | Dataset: 3400
#   Epoch  1000/4000 | Loss: 0.006188 | Dataset: 3400
#   [Epoch 1000] CE found → dataset 3400 → 3500 (+100)
#   Epoch  1050/4000 | Loss: 0.005963 | Dataset: 3500
#   Epoch  1100/4000 | Loss: 0.005916 | Dataset: 3500
#   Epoch  1150/4000 | Loss: 0.005869 | Dataset: 3500
#   Epoch  1200/4000 | Loss: 0.005822 | Dataset: 3500
#   Epoch  1250/4000 | Loss: 0.005776 | Dataset: 3500
#   Epoch  1300/4000 | Loss: 0.005731 | Dataset: 3500
#   Epoch  1350/4000 | Loss: 0.005684 | Dataset: 3500
#   Epoch  1400/4000 | Loss: 0.005639 | Dataset: 3500
#   Epoch  1450/4000 | Loss: 0.005594 | Dataset: 3500
#   Epoch  1500/4000 | Loss: 0.005550 | Dataset: 3500
#   Epoch  1550/4000 | Loss: 0.005505 | Dataset: 3500
#   Epoch  1600/4000 | Loss: 0.005462 | Dataset: 3500
#   Epoch  1650/4000 | Loss: 0.005418 | Dataset: 3500
#   Epoch  1700/4000 | Loss: 0.005373 | Dataset: 3500
#   Epoch  1750/4000 | Loss: 0.005331 | Dataset: 3500
#   Epoch  1800/4000 | Loss: 0.005287 | Dataset: 3500
#   Epoch  1850/4000 | Loss: 0.005245 | Dataset: 3500
#   Epoch  1900/4000 | Loss: 0.005203 | Dataset: 3500
#   Epoch  1950/4000 | Loss: 0.005161 | Dataset: 3500
#   Epoch  2000/4000 | Loss: 0.005120 | Dataset: 3500
#   [Epoch 2000] CE found → dataset 3500 → 3600 (+100)
#   Epoch  2050/4000 | Loss: 0.004938 | Dataset: 3600
#   Epoch  2100/4000 | Loss: 0.004899 | Dataset: 3600
#   Epoch  2150/4000 | Loss: 0.004860 | Dataset: 3600
#   Epoch  2200/4000 | Loss: 0.004822 | Dataset: 3600
#   Epoch  2250/4000 | Loss: 0.004784 | Dataset: 3600
#   Epoch  2300/4000 | Loss: 0.004747 | Dataset: 3600
#   Epoch  2350/4000 | Loss: 0.004709 | Dataset: 3600
#   Epoch  2400/4000 | Loss: 0.004671 | Dataset: 3600
#   Epoch  2450/4000 | Loss: 0.004634 | Dataset: 3600
#   Epoch  2500/4000 | Loss: 0.004597 | Dataset: 3600
#   Epoch  2550/4000 | Loss: 0.004561 | Dataset: 3600
#   Epoch  2600/4000 | Loss: 0.004524 | Dataset: 3600
#   Epoch  2650/4000 | Loss: 0.004488 | Dataset: 3600
#   Epoch  2700/4000 | Loss: 0.004452 | Dataset: 3600
#   Epoch  2750/4000 | Loss: 0.004416 | Dataset: 3600
#   Epoch  2800/4000 | Loss: 0.004382 | Dataset: 3600
#   Epoch  2850/4000 | Loss: 0.004348 | Dataset: 3600
#   Epoch  2900/4000 | Loss: 0.004311 | Dataset: 3600
#   Epoch  2950/4000 | Loss: 0.004277 | Dataset: 3600
#   Epoch  3000/4000 | Loss: 0.004242 | Dataset: 3600
#   [Epoch 3000] CE found → dataset 3600 → 3700 (+100)
#   Epoch  3050/4000 | Loss: 0.004095 | Dataset: 3700
#   Epoch  3100/4000 | Loss: 0.004063 | Dataset: 3700
#   Epoch  3150/4000 | Loss: 0.004031 | Dataset: 3700
#   Epoch  3200/4000 | Loss: 0.003999 | Dataset: 3700
#   Epoch  3250/4000 | Loss: 0.003968 | Dataset: 3700
#   Epoch  3300/4000 | Loss: 0.003936 | Dataset: 3700
#   Epoch  3350/4000 | Loss: 0.003905 | Dataset: 3700
#   Epoch  3400/4000 | Loss: 0.003875 | Dataset: 3700
#   Epoch  3450/4000 | Loss: 0.003844 | Dataset: 3700
#   Epoch  3500/4000 | Loss: 0.003813 | Dataset: 3700
#   Epoch  3550/4000 | Loss: 0.003783 | Dataset: 3700
#   Epoch  3600/4000 | Loss: 0.003753 | Dataset: 3700
#   Epoch  3650/4000 | Loss: 0.003723 | Dataset: 3700
#   Epoch  3700/4000 | Loss: 0.003693 | Dataset: 3700
#   Epoch  3750/4000 | Loss: 0.003664 | Dataset: 3700
#   Epoch  3800/4000 | Loss: 0.003635 | Dataset: 3700
#   Epoch  3850/4000 | Loss: 0.003605 | Dataset: 3700
#   Epoch  3900/4000 | Loss: 0.003577 | Dataset: 3700
#   Epoch  3950/4000 | Loss: 0.003548 | Dataset: 3700
#   Epoch     0/4000 | Loss: 0.003519 | Dataset: 3700
#   Epoch    50/4000 | Loss: 0.003491 | Dataset: 3700
#   Epoch   100/4000 | Loss: 0.003463 | Dataset: 3700
#   Epoch   150/4000 | Loss: 0.003435 | Dataset: 3700
#   Epoch   200/4000 | Loss: 0.003409 | Dataset: 3700
#   Epoch   250/4000 | Loss: 0.003381 | Dataset: 3700
#   Epoch   300/4000 | Loss: 0.003354 | Dataset: 3700
#   Epoch   350/4000 | Loss: 0.003325 | Dataset: 3700
#   Epoch   400/4000 | Loss: 0.003299 | Dataset: 3700
#   Epoch   450/4000 | Loss: 0.003272 | Dataset: 3700
#   Epoch   500/4000 | Loss: 0.003246 | Dataset: 3700
#   Epoch   550/4000 | Loss: 0.003219 | Dataset: 3700
#   Epoch   600/4000 | Loss: 0.003193 | Dataset: 3700
#   Epoch   650/4000 | Loss: 0.003167 | Dataset: 3700
#   Epoch   700/4000 | Loss: 0.003142 | Dataset: 3700
#   Epoch   750/4000 | Loss: 0.003117 | Dataset: 3700
#   Epoch   800/4000 | Loss: 0.003092 | Dataset: 3700
#   Epoch   850/4000 | Loss: 0.003066 | Dataset: 3700
#   Epoch   900/4000 | Loss: 0.003042 | Dataset: 3700
#   Epoch   950/4000 | Loss: 0.003017 | Dataset: 3700
#   Epoch  1000/4000 | Loss: 0.002993 | Dataset: 3700
#   [Epoch 1000] CE found → dataset 3700 → 3800 (+100)
#   Epoch  1050/4000 | Loss: 0.002890 | Dataset: 3800
#   Epoch  1100/4000 | Loss: 0.002867 | Dataset: 3800
#   Epoch  1150/4000 | Loss: 0.002844 | Dataset: 3800
#   Epoch  1200/4000 | Loss: 0.002822 | Dataset: 3800
#   Epoch  1250/4000 | Loss: 0.002800 | Dataset: 3800
#   Epoch  1300/4000 | Loss: 0.002779 | Dataset: 3800
#   Epoch  1350/4000 | Loss: 0.002755 | Dataset: 3800
#   Epoch  1400/4000 | Loss: 0.002733 | Dataset: 3800
#   Epoch  1450/4000 | Loss: 0.002712 | Dataset: 3800
#   Epoch  1500/4000 | Loss: 0.002690 | Dataset: 3800
#   Epoch  1550/4000 | Loss: 0.002668 | Dataset: 3800
#   Epoch  1600/4000 | Loss: 0.002647 | Dataset: 3800
#   Epoch  1650/4000 | Loss: 0.002626 | Dataset: 3800
#   Epoch  1700/4000 | Loss: 0.002604 | Dataset: 3800
#   Epoch  1750/4000 | Loss: 0.002584 | Dataset: 3800
#   Epoch  1800/4000 | Loss: 0.002563 | Dataset: 3800
#   Epoch  1850/4000 | Loss: 0.002542 | Dataset: 3800
#   Epoch  1900/4000 | Loss: 0.002521 | Dataset: 3800
#   Epoch  1950/4000 | Loss: 0.002501 | Dataset: 3800
#   Epoch  2000/4000 | Loss: 0.002484 | Dataset: 3800
#   [Epoch 2000] CE found → dataset 3800 → 3900 (+100)
#   Epoch  2050/4000 | Loss: 0.002399 | Dataset: 3900
#   Epoch  2100/4000 | Loss: 0.002379 | Dataset: 3900
#   Epoch  2150/4000 | Loss: 0.002361 | Dataset: 3900
#   Epoch  2200/4000 | Loss: 0.002342 | Dataset: 3900
#   Epoch  2250/4000 | Loss: 0.002323 | Dataset: 3900
#   Epoch  2300/4000 | Loss: 0.002305 | Dataset: 3900
#   Epoch  2350/4000 | Loss: 0.002287 | Dataset: 3900
#   Epoch  2400/4000 | Loss: 0.002269 | Dataset: 3900
#   Epoch  2450/4000 | Loss: 0.002251 | Dataset: 3900
#   Epoch  2500/4000 | Loss: 0.002233 | Dataset: 3900
#   Epoch  2550/4000 | Loss: 0.002215 | Dataset: 3900
#   Epoch  2600/4000 | Loss: 0.002198 | Dataset: 3900
#   Epoch  2650/4000 | Loss: 0.002180 | Dataset: 3900
#   Epoch  2700/4000 | Loss: 0.002163 | Dataset: 3900
#   Epoch  2750/4000 | Loss: 0.002145 | Dataset: 3900
#   Epoch  2800/4000 | Loss: 0.002128 | Dataset: 3900
#   Epoch  2850/4000 | Loss: 0.002111 | Dataset: 3900
#   Epoch  2900/4000 | Loss: 0.002094 | Dataset: 3900
#   Epoch  2950/4000 | Loss: 0.002077 | Dataset: 3900
#   Epoch  3000/4000 | Loss: 0.002061 | Dataset: 3900
#   [Epoch 3000] CE found → dataset 3900 → 4000 (+100)
#   Epoch  3050/4000 | Loss: 0.001993 | Dataset: 4000
#   Epoch  3100/4000 | Loss: 0.001977 | Dataset: 4000
#   Epoch  3150/4000 | Loss: 0.001962 | Dataset: 4000
#   Epoch  3200/4000 | Loss: 0.001946 | Dataset: 4000
#   Epoch  3250/4000 | Loss: 0.001931 | Dataset: 4000
#   Epoch  3300/4000 | Loss: 0.001916 | Dataset: 4000
#   Epoch  3350/4000 | Loss: 0.001900 | Dataset: 4000
#   Epoch  3400/4000 | Loss: 0.001885 | Dataset: 4000
#   Epoch  3450/4000 | Loss: 0.001870 | Dataset: 4000
#   Epoch  3500/4000 | Loss: 0.001855 | Dataset: 4000
#   Epoch  3550/4000 | Loss: 0.001840 | Dataset: 4000
#   Epoch  3600/4000 | Loss: 0.001826 | Dataset: 4000
#   Epoch  3650/4000 | Loss: 0.001811 | Dataset: 4000
#   Epoch  3700/4000 | Loss: 0.001797 | Dataset: 4000
#   Epoch  3750/4000 | Loss: 0.001783 | Dataset: 4000
#   Epoch  3800/4000 | Loss: 0.001768 | Dataset: 4000
#   Epoch  3850/4000 | Loss: 0.001755 | Dataset: 4000
#   Epoch  3900/4000 | Loss: 0.001740 | Dataset: 4000
#   Epoch  3950/4000 | Loss: 0.001726 | Dataset: 4000
#   Epoch     0/4000 | Loss: 0.001712 | Dataset: 4000
#   Epoch    50/4000 | Loss: 0.001699 | Dataset: 4000
#   Epoch   100/4000 | Loss: 0.001686 | Dataset: 4000
#   Epoch   150/4000 | Loss: 0.001672 | Dataset: 4000
#   Epoch   200/4000 | Loss: 0.001658 | Dataset: 4000
#   Epoch   250/4000 | Loss: 0.001644 | Dataset: 4000
#   Epoch   300/4000 | Loss: 0.001632 | Dataset: 4000
#   Epoch   350/4000 | Loss: 0.001618 | Dataset: 4000
#   Epoch   400/4000 | Loss: 0.001605 | Dataset: 4000
#   Epoch   450/4000 | Loss: 0.001592 | Dataset: 4000
#   Epoch   500/4000 | Loss: 0.001579 | Dataset: 4000
#   Epoch   550/4000 | Loss: 0.001567 | Dataset: 4000
#   Epoch   600/4000 | Loss: 0.001553 | Dataset: 4000
#   Epoch   650/4000 | Loss: 0.001542 | Dataset: 4000
#   Epoch   700/4000 | Loss: 0.001529 | Dataset: 4000
#   Epoch   750/4000 | Loss: 0.001516 | Dataset: 4000
#   Epoch   800/4000 | Loss: 0.001506 | Dataset: 4000
#   Epoch   850/4000 | Loss: 0.001492 | Dataset: 4000
#   Epoch   900/4000 | Loss: 0.001481 | Dataset: 4000
#   Epoch   950/4000 | Loss: 0.001468 | Dataset: 4000
#   Epoch  1000/4000 | Loss: 0.001456 | Dataset: 4000
#   [Epoch 1000] CE found → dataset 4000 → 4100 (+100)
#   Epoch  1050/4000 | Loss: 0.001411 | Dataset: 4100
#   Epoch  1100/4000 | Loss: 0.001400 | Dataset: 4100
#   Epoch  1150/4000 | Loss: 0.001390 | Dataset: 4100
#   Epoch  1200/4000 | Loss: 0.001378 | Dataset: 4100
#   Epoch  1250/4000 | Loss: 0.001366 | Dataset: 4100
#   Epoch  1300/4000 | Loss: 0.001355 | Dataset: 4100
#   Epoch  1350/4000 | Loss: 0.001345 | Dataset: 4100
#   Epoch  1400/4000 | Loss: 0.001334 | Dataset: 4100
#   Epoch  1450/4000 | Loss: 0.001326 | Dataset: 4100
#   Epoch  1500/4000 | Loss: 0.001313 | Dataset: 4100
#   Epoch  1550/4000 | Loss: 0.001303 | Dataset: 4100
#   Epoch  1600/4000 | Loss: 0.001292 | Dataset: 4100
#   Epoch  1650/4000 | Loss: 0.001284 | Dataset: 4100
#   Epoch  1700/4000 | Loss: 0.001272 | Dataset: 4100
#   Epoch  1750/4000 | Loss: 0.001261 | Dataset: 4100
#   Epoch  1800/4000 | Loss: 0.001251 | Dataset: 4100
#   Epoch  1850/4000 | Loss: 0.001240 | Dataset: 4100
#   Epoch  1900/4000 | Loss: 0.001231 | Dataset: 4100
#   Epoch  1950/4000 | Loss: 0.001221 | Dataset: 4100
#   Epoch  2000/4000 | Loss: 0.001211 | Dataset: 4100
#   [Epoch 2000] CE found → dataset 4100 → 4200 (+100)
#   Epoch  2050/4000 | Loss: 0.001174 | Dataset: 4200
#   Epoch  2100/4000 | Loss: 0.001166 | Dataset: 4200
#   Epoch  2150/4000 | Loss: 0.001156 | Dataset: 4200
#   Epoch  2200/4000 | Loss: 0.001147 | Dataset: 4200
#   Epoch  2250/4000 | Loss: 0.001138 | Dataset: 4200
#   Epoch  2300/4000 | Loss: 0.001129 | Dataset: 4200
#   Epoch  2350/4000 | Loss: 0.001120 | Dataset: 4200
#   Epoch  2400/4000 | Loss: 0.001111 | Dataset: 4200
#   Epoch  2450/4000 | Loss: 0.001102 | Dataset: 4200
#   Epoch  2500/4000 | Loss: 0.001093 | Dataset: 4200
#   Epoch  2550/4000 | Loss: 0.001084 | Dataset: 4200
#   Epoch  2600/4000 | Loss: 0.001075 | Dataset: 4200
#   Epoch  2650/4000 | Loss: 0.001067 | Dataset: 4200
#   Epoch  2700/4000 | Loss: 0.001058 | Dataset: 4200
#   Epoch  2750/4000 | Loss: 0.001050 | Dataset: 4200
#   Epoch  2800/4000 | Loss: 0.001042 | Dataset: 4200
#   Epoch  2850/4000 | Loss: 0.001033 | Dataset: 4200
#   Epoch  2900/4000 | Loss: 0.001026 | Dataset: 4200
#   Epoch  2950/4000 | Loss: 0.001017 | Dataset: 4200
#   Epoch  3000/4000 | Loss: 0.001008 | Dataset: 4200
#   [Epoch 3000] CE found → dataset 4200 → 4300 (+100)
#   Epoch  3050/4000 | Loss: 0.000978 | Dataset: 4300
#   Epoch  3100/4000 | Loss: 0.000969 | Dataset: 4300
#   Epoch  3150/4000 | Loss: 0.000962 | Dataset: 4300
#   Epoch  3200/4000 | Loss: 0.000953 | Dataset: 4300
#   Epoch  3250/4000 | Loss: 0.000947 | Dataset: 4300
#   Epoch  3300/4000 | Loss: 0.000939 | Dataset: 4300
#   Epoch  3350/4000 | Loss: 0.000931 | Dataset: 4300
#   Epoch  3400/4000 | Loss: 0.000925 | Dataset: 4300
#   Epoch  3450/4000 | Loss: 0.000917 | Dataset: 4300
#   Epoch  3500/4000 | Loss: 0.000910 | Dataset: 4300
#   Epoch  3550/4000 | Loss: 0.000903 | Dataset: 4300
#   Epoch  3600/4000 | Loss: 0.000895 | Dataset: 4300
#   Epoch  3650/4000 | Loss: 0.000887 | Dataset: 4300
#   Epoch  3700/4000 | Loss: 0.000880 | Dataset: 4300
#   Epoch  3750/4000 | Loss: 0.000874 | Dataset: 4300
#   Epoch  3800/4000 | Loss: 0.000867 | Dataset: 4300
#   Epoch  3850/4000 | Loss: 0.000859 | Dataset: 4300
#   Epoch  3900/4000 | Loss: 0.000853 | Dataset: 4300
#   Epoch  3950/4000 | Loss: 0.000845 | Dataset: 4300
#   Epoch     0/4000 | Loss: 0.000838 | Dataset: 4300
#   Epoch    50/4000 | Loss: 0.000832 | Dataset: 4300
#   Epoch   100/4000 | Loss: 0.000824 | Dataset: 4300
#   Epoch   150/4000 | Loss: 0.000817 | Dataset: 4300
#   Epoch   200/4000 | Loss: 0.000810 | Dataset: 4300
#   Epoch   250/4000 | Loss: 0.000804 | Dataset: 4300
#   Epoch   300/4000 | Loss: 0.000796 | Dataset: 4300
#   Epoch   350/4000 | Loss: 0.000789 | Dataset: 4300
#   Epoch   400/4000 | Loss: 0.000782 | Dataset: 4300
#   Epoch   450/4000 | Loss: 0.000776 | Dataset: 4300
#   Epoch   500/4000 | Loss: 0.000770 | Dataset: 4300
#   Epoch   550/4000 | Loss: 0.000764 | Dataset: 4300
#   Epoch   600/4000 | Loss: 0.000758 | Dataset: 4300
#   Epoch   650/4000 | Loss: 0.000752 | Dataset: 4300
#   Epoch   700/4000 | Loss: 0.000745 | Dataset: 4300
#   Epoch   750/4000 | Loss: 0.000740 | Dataset: 4300
#   Epoch   800/4000 | Loss: 0.000734 | Dataset: 4300
#   Epoch   850/4000 | Loss: 0.000729 | Dataset: 4300
#   Epoch   900/4000 | Loss: 0.000721 | Dataset: 4300
#   Epoch   950/4000 | Loss: 0.000716 | Dataset: 4300
#   Epoch  1000/4000 | Loss: 0.000710 | Dataset: 4300
#   [Epoch 1000] CE found → dataset 4300 → 4400 (+100)
#   Epoch  1050/4000 | Loss: 0.000688 | Dataset: 4400
#   Epoch  1100/4000 | Loss: 0.000684 | Dataset: 4400
#   Epoch  1150/4000 | Loss: 0.000677 | Dataset: 4400
#   Epoch  1200/4000 | Loss: 0.000673 | Dataset: 4400
#   Epoch  1250/4000 | Loss: 0.000667 | Dataset: 4400
#   Epoch  1300/4000 | Loss: 0.000662 | Dataset: 4400
#   Epoch  1350/4000 | Loss: 0.000656 | Dataset: 4400
#   Epoch  1400/4000 | Loss: 0.000652 | Dataset: 4400
#   Epoch  1450/4000 | Loss: 0.000646 | Dataset: 4400
#   Epoch  1500/4000 | Loss: 0.000641 | Dataset: 4400
#   Epoch  1550/4000 | Loss: 0.000636 | Dataset: 4400
#   Epoch  1600/4000 | Loss: 0.000631 | Dataset: 4400
#   Epoch  1650/4000 | Loss: 0.000625 | Dataset: 4400
#   Epoch  1700/4000 | Loss: 0.000620 | Dataset: 4400
#   Epoch  1750/4000 | Loss: 0.000616 | Dataset: 4400
#   Epoch  1800/4000 | Loss: 0.000610 | Dataset: 4400
#   Epoch  1850/4000 | Loss: 0.000607 | Dataset: 4400
#   Epoch  1900/4000 | Loss: 0.000600 | Dataset: 4400
#   Epoch  1950/4000 | Loss: 0.000598 | Dataset: 4400
#   Epoch  2000/4000 | Loss: 0.000592 | Dataset: 4400
#   [Epoch 2000] CE found → dataset 4400 → 4500 (+100)
#   Epoch  2050/4000 | Loss: 0.000573 | Dataset: 4500
#   Epoch  2100/4000 | Loss: 0.000569 | Dataset: 4500
#   Epoch  2150/4000 | Loss: 0.000564 | Dataset: 4500
#   Epoch  2200/4000 | Loss: 0.000561 | Dataset: 4500
#   Epoch  2250/4000 | Loss: 0.000555 | Dataset: 4500
#   Epoch  2300/4000 | Loss: 0.000551 | Dataset: 4500
#   Epoch  2350/4000 | Loss: 0.000546 | Dataset: 4500
#   Epoch  2400/4000 | Loss: 0.000542 | Dataset: 4500
#   Epoch  2450/4000 | Loss: 0.000538 | Dataset: 4500
#   Epoch  2500/4000 | Loss: 0.000534 | Dataset: 4500
#   Epoch  2550/4000 | Loss: 0.000529 | Dataset: 4500
#   Epoch  2600/4000 | Loss: 0.000525 | Dataset: 4500
#   Epoch  2650/4000 | Loss: 0.000521 | Dataset: 4500
#   Epoch  2700/4000 | Loss: 0.000517 | Dataset: 4500
#   Epoch  2750/4000 | Loss: 0.000512 | Dataset: 4500
#   Epoch  2800/4000 | Loss: 0.000508 | Dataset: 4500
#   Epoch  2850/4000 | Loss: 0.000504 | Dataset: 4500
#   Epoch  2900/4000 | Loss: 0.000501 | Dataset: 4500
#   [Epoch 2904] Loss 0.000500 < threshold to checking SMT...
#
# ============================================================
# Training complete
#   Final loss     : 0.000500
#   Learned margin : 0.000011
#   Final dataset  : 4500
# ============================================================

# %%
fig, ax = plot_contour_density(
    f,g,a_net2,b_net2,c_net2,x_lim = [-6,6],
    y_lim = [-6,6],
    density_threshold = 1e-6,
    title =" ",
    x_axis_title = "$x_1$",
    y_axis_title = "$x_2$",
    device = device
)

# %%
# plot the blended density function
fig, ax = plot_contour_mixed_density(
    f,g,a_net1,b_net1,c_net1,a_net2,b_net2,c_net2,x_lim = [-6,6],
    y_lim = [-6,6],
    density_threshold1 = 1e-6,
    density_threshold2=1e-6,
    density_threshold=1e-6,
    title =" ",
    x_axis_title = "$x_1$",
    y_axis_title = "$x_2$",
    device = device
)
