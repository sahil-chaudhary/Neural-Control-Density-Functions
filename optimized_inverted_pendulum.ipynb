# %%
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import random
from dreal import *
import matplotlib.patches as patches
from matplotlib import cm

# %%
torch.cuda.empty_cache()
torch.manual_seed(17)
random.seed()

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Pre-allocate numerical_x
numerical_x = torch.Tensor(500, 2).uniform_(-6, 6).float().to(device)
# Out:
# Using device: cpu

# %%
# Physical constants for inverted pendulum
MASS = 0.15
GRAVITY = 9.81
LENGTH = 0.5
FRICTION = 0.1
ML2 = MASS * (LENGTH ** 2)

# %%
def f(x):
    """Vectorized inverted pendulum dynamics f(x) - handles batched input"""
    if x.dim() == 1:
        x = x.unsqueeze(0)
    
    val = torch.stack([
        x[:, 1],
        (MASS * GRAVITY * LENGTH * torch.sin(x[:, 0]) - FRICTION * x[:, 1]) / ML2
    ], dim=1)
    
    return val.squeeze(0) if val.shape[0] == 1 else val

def g(x):
    """Vectorized g(x) - handles batched input"""
    if x.dim() == 1:
        x = x.unsqueeze(0)
    
    val = torch.stack([
        torch.zeros_like(x[:, 0]),
        torch.full_like(x[:, 0], 1.0 / ML2)
    ], dim=1)
    
    return val.squeeze(0) if val.shape[0] == 1 else val

def div_f(x):
    """Vectorized divergence of f - handles batched input"""
    divergence = -FRICTION / ML2
    if x.dim() == 1:
        return torch.tensor(divergence, device=device)
    else:
        return torch.full((x.shape[0],), divergence, device=device)

def div_g(x):
    """Vectorized divergence of g"""
    if x.dim() == 1:
        return torch.tensor(0.0, device=device)
    else:
        return torch.zeros(x.shape[0], device=device)

# %%
class polynomial_net(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(polynomial_net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, output_dim)
        )
        self._initialize_weights()

    def _initialize_weights(self):
        for layer in self.net:
            if isinstance(layer, nn.Linear):
                nn.init.xavier_uniform_(layer.weight)
                nn.init.zeros_(layer.bias)

    def forward(self, x):
        return self.net(x)

class polynomial_net_bias_Zero(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(polynomial_net_bias_Zero, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, output_dim)
        )
        self._initialize_weights()

    def _initialize_weights(self):
        for layer in self.net:
            if isinstance(layer, nn.Linear):
                nn.init.xavier_uniform_(layer.weight)
                nn.init.zeros_(layer.bias)
                layer.bias.requires_grad = False
                

    def forward(self, x):
        return self.net(x)
                

class numerator_polynomial_net(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(numerator_polynomial_net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.Sigmoid(),
            nn.Linear(hidden_dim, output_dim),
            nn.Sigmoid()
        )
        self._initialize_weights()

    def _initialize_weights(self):
        for layer in self.net:
            if isinstance(layer, nn.Linear):
                nn.init.xavier_uniform_(layer.weight)
                nn.init.zeros_(layer.bias)

    def forward(self, x):
        return self.net(x)

class GammaFunctionNet(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(GammaFunctionNet, self).__init__()
        self.linear_layer = nn.Linear(input_dim, output_dim)
        nn.init.constant_(self.linear_layer.weight, 0)
        nn.init.constant_(self.linear_layer.bias, 0)
        self.linear_layer.weight.requires_grad = False

    def forward(self, x):
        if x.dim() == 1:
            return abs(self.linear_layer.bias)
        return abs(self.linear_layer.bias.expand(x.shape[0], -1))

# %%
def gradient_batch(func, x):
    """Compute gradients for a batch of inputs efficiently"""
    x = x.clone().detach().requires_grad_(True)
    output = func(x).sum()
    grad = torch.autograd.grad(outputs=output, inputs=x, create_graph=True)[0]
    return grad

def gradient_batch_special_b(func, x):
    """Compute gradients of ||f(x)||^2 for a batch efficiently"""
    x = x.clone().detach().requires_grad_(True)
    output = func(x)
    output_norm_squared = (output ** 2).sum(dim=1).sum()
    grad = torch.autograd.grad(outputs=output_norm_squared, inputs=x, create_graph=True)[0]
    return grad

# ==================== FULLY VECTORIZED CONTROL DENSITY ====================

def control_density_risk_vectorized(x, f_fun, g_fun, a_fun, b_fun, c_fun):
    """FULLY VECTORIZED - processes entire batch at once"""
    batch_size = x.shape[0]
    
    # Compute all values in batch
    divergence_at_f = div_f(x)  # [batch_size]
    divergence_at_g = div_g(x)  # [batch_size]
    
    # Compute gradients for entire batch
    grad_at_a = gradient_batch(a_fun, x)  # [batch_size, 2]
    grad_at_c = gradient_batch(c_fun, x)  # [batch_size, 2]
    grad_at_b = gradient_batch_special_b(b_fun, x)  # [batch_size, 2]
    
    # Compute function values
    a_vals = a_fun(x).squeeze()  # [batch_size]
    c_vals = c_fun(x).squeeze()  # [batch_size]
    f_vals = f(x)  # [batch_size, 2]
    g_vals = g(x)  # [batch_size, 2]
    
    # Vectorized computation of term1
    term1 = (a_vals * divergence_at_f + 
             divergence_at_g * c_vals + 
             (grad_at_a * f_vals).sum(dim=1) + 
             (grad_at_c * g_vals).sum(dim=1))
    
    # Vectorized computation of term2
    scaled_x = 2 * x + grad_at_b  # [batch_size, 2]
    combined = f_vals * a_vals.unsqueeze(1) + g_vals * c_vals.unsqueeze(1)  # [batch_size, 2]
    term2 = (scaled_x * combined).sum(dim=1)
    
    return term1 - term2

def control_density_loss(x, f_fun, g_fun, a_fun, b_fun, c_fun, gamma_fun):
    """Optimized loss computation"""
    divergence = control_density_risk_vectorized(x, f_fun, g_fun, a_fun, b_fun, c_fun)
    gamma_vals = gamma_fun(x).squeeze()
    
    loss = F.relu(gamma_vals - divergence).mean()
    a_loss = F.relu( - a_fun(x)).mean()
    gamma_loss = F.relu(-gamma_vals).mean()
    
    return loss + a_loss + gamma_loss

# %%
def checkSMTconstraints(vars, a_learnt, divergence_learnt, ball_lb, ball_ub, config, epsilon=0):
    """Check the SMT constraints for the given variables and learnt parameters"""
    ball = Expression(0)
    
    for i in range(len(vars)):
        ball += vars[i]**2
    ball_in_bound = logical_and(ball >= ball_lb, ball <= ball_ub)
    
    a_condition = a_learnt >= 0
    divergence_condition = divergence_learnt > 0
    stability_condition = logical_and(
        logical_imply(ball_in_bound, divergence_condition),
        logical_imply(ball_in_bound, a_condition)
    )
    
    return CheckSatisfiability(logical_not(stability_condition), config)

def AddCounterexamples(x, CE, N, device):
    """Adds counterexamples to the sample set efficiently"""
    nearby = []
    for i in range(CE.size()):
        lb = CE[i].lb()
        ub = CE[i].ub()
        nearby_ = np.random.uniform(lb, ub, N)
        nearby.append(nearby_)
    
    # Vectorized counterexample addition
    new_points = np.column_stack(nearby)
    new_points_tensor = torch.tensor(new_points, dtype=torch.float32, device=device)
    x = torch.cat((x, new_points_tensor), dim=0)
    x = torch.unique(x, dim=0)
    
    return x, new_points_tensor

# ==================== SYMBOLIC NN CLASSES ====================

class SymbolicNN:
    """Convert neural networks to symbolic expressions for dReal"""
    def __init__(self, net):
        self.weights = []
        self.biases = []
        self.extract_params(net)

    def extract_params(self, net):
        for layer in net.net:
            if isinstance(layer, nn.Linear):
                self.weights.append(layer.weight.detach().cpu().numpy())
                if layer.bias is not None:
                    self.biases.append(layer.bias.detach().cpu().numpy())

    def forward_symbolic(self, vars):
        z = vars
        for i in range(len(self.weights) - 1):
            z = self._linear_symbolic(z, self.weights[i], self.biases[i])
            z = [tanh(zi) for zi in z]
        z = self._linear_symbolic(z, self.weights[-1], self.biases[-1])
        return z

    def _linear_symbolic(self, x, weight, bias):
        out = []
        for i in range(weight.shape[0]):
            expr = bias[i]
            for j in range(weight.shape[1]):
                expr += weight[i,j] * x[j]
            out.append(expr)
        return out

class activSymbolicNN:
    """Convert neural networks with sigmoid to symbolic expressions"""
    def __init__(self, net):
        self.weights = []
        self.biases = []
        self.extract_params(net)

    def extract_params(self, net):
        for layer in net.net:
            if isinstance(layer, nn.Linear):
                self.weights.append(layer.weight.detach().cpu().numpy())
                if layer.bias is not None:
                    self.biases.append(layer.bias.detach().cpu().numpy())

    def forward_symbolic(self, vars):
        z = vars
        for i in range(len(self.weights)):
            z = self._linear_symbolic(z, self.weights[i], self.biases[i])
            z = [(1/(1 + exp(-zi))) for zi in z]
        return z

    def _linear_symbolic(self, x, weight, bias):
        out = []
        for i in range(weight.shape[0]):
            expr = bias[i]
            for j in range(weight.shape[1]):
                expr += weight[i,j] * x[j]
            out.append(expr)
        return out

def candidate_constraint_learnt(vars, a_fun, b_fun, c_fun):
    """Construct candidate constraints for the learnt functions"""
    a_sym = activSymbolicNN(a_fun).forward_symbolic(vars)[0]
    b_sym = SymbolicNN(b_fun).forward_symbolic(vars)
    c_sym = SymbolicNN(c_fun).forward_symbolic(vars)[0]
    
    b_sym = sum([bi**2 for bi in b_sym])
    
    # Symbolic dynamics for inverted pendulum
    f_val = [
        vars[1],
        (MASS * GRAVITY * LENGTH * sin(vars[0]) - FRICTION * vars[1]) / ML2
    ]
    g_val = [
        0.0 * vars[0],
        1.0 / ML2
    ]
    
    f_div = -FRICTION / ML2
    g_div = 0
    
    grad_a = [a_sym.Differentiate(vars[i]) for i in range(len(vars))]
    grad_c = [c_sym.Differentiate(vars[i]) for i in range(len(vars))]
    grad_b = [b_sym.Differentiate(vars[i]) for i in range(len(vars))]
    
    constraint1 = (a_sym * f_div + g_div * c_sym + 
                   sum([grad_a[i] * f_val[i] for i in range(len(f_val))]) + 
                   sum([grad_c[i] * g_val[i] for i in range(len(g_val))]))
    
    scaled_vars = [2 * var_i for var_i in vars]
    constraint2 = [scaled_vars[i] + grad_b[i] for i in range(len(vars))]
    constraint2 = sum([constraint2[i] * (f_val[i] * a_sym + g_val[i] * c_sym) 
                      for i in range(len(f_val))])
    
    constraint = constraint1 - constraint2
    return a_sym, constraint

# %%
def train_density(x, epochs=2000, lr=1e-2, ball_lb=0.5, ball_ub=2, check_interval=10):
    """Train density function with SMT-based counterexample refinement"""
    loss_total_density = []
    

    a_net = numerator_polynomial_net(2, 3, 1).to(device)
    c_net = polynomial_net(2, 12, 1).to(device)
    b_net = polynomial_net_bias_Zero(2, 3, 2).to(device)
    gamma_net = GammaFunctionNet(2, 1).to(device)
    
    optimizer = torch.optim.RMSprop(
        list(a_net.parameters()) + list(c_net.parameters()) + 
        list(b_net.parameters()) + list(gamma_net.parameters()), 
        lr=lr
    )
    
    # Configure dReal SMT solver
    config = Config()
    config.use_polytope_in_forall = True
    config.use_local_optimization = True
    config.precision = 1e-5
    
    valid = False
    print("Training density function with SMT verification")
    print(f"Initial dataset size: {x.shape[0]}")
    
    while not valid:
        for epoch in range(epochs):
            optimizer.zero_grad()
            loss = control_density_loss(x, f, g, a_net, b_net, c_net, gamma_net)
            loss_total_density.append(loss.item())
            loss.backward()
            optimizer.step()
            
            if loss.item() < 5e-4:
                print(f"  [Epoch {epoch}] Loss reached zero!")
                valid = True
                break
            
            if epoch % 50 == 0:
                print(f"Epoch {epoch}/{epochs}, Loss: {loss.item():.4f}, Dataset size: {x.shape[0]}")
            
            # Check for counterexamples periodically
            if epoch % check_interval == 0 and epoch > 0:
                print(f"  [Epoch {epoch}] Checking SMT constraints...")
                vars = [Variable("x1"), Variable("x2")]
                
                try:
                    a_learnt, divergence_learnt = candidate_constraint_learnt(vars, a_net, b_net, c_net)
                    CE = checkSMTconstraints(vars, a_learnt, divergence_learnt, ball_lb, ball_ub, config)
                    
                    if CE:
                        print(f" Counterexample found! Adding 100 new points...")
                        x_before = x.shape[0]
                        x, n_pt_tensor = AddCounterexamples(x, CE, 100, device)
                        x_after = x.shape[0]
                        print(f"  Dataset size: {x_before} → {x_after} (+{x_after - x_before} unique)")
                    else:
                        valid = True
                        print(" No counterexample found - constraints satisfied!")
                        break
                except Exception as e:
                    print(f"   SMT check failed: {e}")
                    continue
        
        # if not valid:
        #     print("Training loop completed without validation. Checking final constraints...")
        #     vars = [Variable("x1"), Variable("x2")]
        #     try:
        #         a_learnt, divergence_learnt = candidate_constraint_learnt(vars, a_net, b_net, c_net)
        #         CE = checkSMTconstraints(vars, a_learnt, divergence_learnt, ball_lb, ball_ub, config)
        #         if not CE:
        #             valid = True
        #             print("Final check passed!")
        #         else:
        #             print(" Final check found counterexamples, but continuing...")
        #             valid = True
        #     except:
        #         valid = True
    
    print(f"\nTraining completed!")
    print(f"Final Loss: {loss.item():.4f}")
    test_point = torch.tensor([[0, 0]], dtype=torch.float32, device=device)
    print(f"The learned margin is {gamma_net(test_point).item():.6f}")
    print(f"Final dataset size: {x.shape[0]}")
    
    return loss_total_density, a_net, b_net, c_net, gamma_net

# %%
def plot_results(risks, labels):
    """Plot risk curves"""
    plt.figure(figsize=(10, 6))
    for risk, label in zip(risks, labels):
        plt.plot(risk, label=label)
    plt.xlabel("Iteration")
    plt.ylabel("Risk")
    plt.title("Risk Over Iterations")
    plt.legend()
    plt.grid()
    plt.show()


def plot_density_contours(a_nn, b_nn, c_nn,density_threshold, device, plot_flow=True):
    """Plot density contours with optional flow field"""
    x1 = torch.linspace(-6, 6, 100)
    x2 = torch.linspace(-6, 6, 100)
    X, Y = np.meshgrid(x1.cpu().numpy(), x2.cpu().numpy())
    
    grid_points = torch.tensor(np.column_stack([X.ravel(), Y.ravel()]), 
                               dtype=torch.float32).to(device)
    
    with torch.no_grad():
        rho_set = a_nn(grid_points) / (torch.exp(
            torch.sum(grid_points**2, dim=1, keepdim=True) + 
            torch.sum((b_nn(grid_points))**2, dim=1, keepdim=True)
        ))
        rho_set = rho_set.squeeze().cpu().numpy().reshape(X.shape)
    
    fig, ax = plt.subplots(figsize=(8, 6))

    
    ax.contour(X,Y,rho_set-density_threshold,levels=1,colors='black', linewidths=2,linestyles='solid', label='Density')

    filled_contours = ax.contourf(X, Y, rho_set, levels=10, alpha=0.3, cmap=cm.coolwarm)
    plt.colorbar(filled_contours, label='Density Value')
    
    if plot_flow:
        x1_flow = np.linspace(-6, 6, 20)
        x2_flow = np.linspace(-6, 6, 20)
        X_flow, Y_flow = np.meshgrid(x1_flow, x2_flow)
        flow_points = torch.tensor(np.column_stack([X_flow.ravel(), Y_flow.ravel()]), 
                                   dtype=torch.float32).to(device)
        
        with torch.no_grad():
            u_values = (c_nn(flow_points) / (a_nn(flow_points) + 1e-9)).squeeze()
        
        DX = np.zeros_like(X_flow)
        DY = np.zeros_like(Y_flow)
        
        for i in range(len(x1_flow)):
            for j in range(len(x2_flow)):
                idx = i * len(x1_flow) + j
                x = torch.tensor([X_flow[i, j], Y_flow[i, j]], device=device)
                f_val = f(x)
                g_val = g(x)
                u = u_values[idx]
                
                flow = f_val + g_val * u
                DX[i, j] = flow[0].cpu().numpy()
                DY[i, j] = flow[1].cpu().numpy()
        
        magnitude = np.sqrt(DX**2 + DY**2) + 1e-9
        DX = DX / magnitude
        DY = DY / magnitude
        # magnitudex = np.sqrt(DX**2)
        # magnitudey = np.sqrt(DY**2 )
        # DX_norm = DX / magnitudex
        # DY_norm = DY / magnitudey
        
        ax.streamplot(X_flow, Y_flow, DX, DY, color='gray', linewidth=0.5,
                     density=1.0, arrowstyle='-|>', arrowsize=1.5)
    
    circle = plt.Circle((0, 0), 6, color='r', fill=False, 
                        linewidth=1.5, label='Valid Region')
    ax.add_artist(circle)
    
    ax.set_xlabel('Angle (rad)')
    ax.set_ylabel('Angular velocity')
    ax.set_title('Density Function Contours with Flow Field')
    ax.legend()
    ax.grid(True)
    plt.show()
    
    return fig, ax

# %%
print("=" * 60)
print("INVERTED PENDULUM CONTROL DENSITY LEARNING")
print("=" * 60)

# Train the density function
loss_density, a_ret, b_ret, c_ret, gamma_net = train_density(
    numerical_x, epochs=4000, lr=1e-4, ball_lb=0.5, ball_ub=6, check_interval=1500
)
# Out:
# ============================================================
# INVERTED PENDULUM CONTROL DENSITY LEARNING
# ============================================================
# Training density function with SMT verification
# Initial dataset size: 500
# Epoch 0/4000, Loss: 2.7243, Dataset size: 500
# Epoch 50/4000, Loss: 1.2409, Dataset size: 500
# Epoch 100/4000, Loss: 1.0276, Dataset size: 500
# Epoch 150/4000, Loss: 0.9262, Dataset size: 500
# Epoch 200/4000, Loss: 0.8545, Dataset size: 500
# Epoch 250/4000, Loss: 0.7993, Dataset size: 500
# Epoch 300/4000, Loss: 0.7500, Dataset size: 500
# Epoch 350/4000, Loss: 0.7074, Dataset size: 500
# Epoch 400/4000, Loss: 0.6679, Dataset size: 500
# Epoch 450/4000, Loss: 0.6304, Dataset size: 500
# Epoch 500/4000, Loss: 0.5958, Dataset size: 500
# Epoch 550/4000, Loss: 0.5624, Dataset size: 500
# Epoch 600/4000, Loss: 0.5285, Dataset size: 500
# Epoch 650/4000, Loss: 0.4953, Dataset size: 500
# Epoch 700/4000, Loss: 0.4644, Dataset size: 500
# Epoch 750/4000, Loss: 0.4342, Dataset size: 500
# Epoch 800/4000, Loss: 0.4043, Dataset size: 500
# Epoch 850/4000, Loss: 0.3767, Dataset size: 500
# Epoch 900/4000, Loss: 0.3511, Dataset size: 500
# Epoch 950/4000, Loss: 0.3277, Dataset size: 500
# Epoch 1000/4000, Loss: 0.3044, Dataset size: 500
# Epoch 1050/4000, Loss: 0.2841, Dataset size: 500
# Epoch 1100/4000, Loss: 0.2654, Dataset size: 500
# Epoch 1150/4000, Loss: 0.2461, Dataset size: 500
# Epoch 1200/4000, Loss: 0.2263, Dataset size: 500
# Epoch 1250/4000, Loss: 0.2048, Dataset size: 500
# Epoch 1300/4000, Loss: 0.1906, Dataset size: 500
# Epoch 1350/4000, Loss: 0.1768, Dataset size: 500
# Epoch 1400/4000, Loss: 0.1659, Dataset size: 500
# Epoch 1450/4000, Loss: 0.1561, Dataset size: 500
# Epoch 1500/4000, Loss: 0.1491, Dataset size: 500
#   [Epoch 1500] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 500 → 600 (+100 unique)
# Epoch 1550/4000, Loss: 0.1252, Dataset size: 600
# Epoch 1600/4000, Loss: 0.1183, Dataset size: 600
# Epoch 1650/4000, Loss: 0.1155, Dataset size: 600
# Epoch 1700/4000, Loss: 0.1131, Dataset size: 600
# Epoch 1750/4000, Loss: 0.1109, Dataset size: 600
# Epoch 1800/4000, Loss: 0.1089, Dataset size: 600
# Epoch 1850/4000, Loss: 0.1070, Dataset size: 600
# Epoch 1900/4000, Loss: 0.1080, Dataset size: 600
# Epoch 1950/4000, Loss: 0.1061, Dataset size: 600
# Epoch 2000/4000, Loss: 0.1033, Dataset size: 600
# Epoch 2050/4000, Loss: 0.1004, Dataset size: 600
# Epoch 2100/4000, Loss: 0.0980, Dataset size: 600
# Epoch 2150/4000, Loss: 0.0958, Dataset size: 600
# Epoch 2200/4000, Loss: 0.0939, Dataset size: 600
# Epoch 2250/4000, Loss: 0.0950, Dataset size: 600
# Epoch 2300/4000, Loss: 0.0936, Dataset size: 600
# Epoch 2350/4000, Loss: 0.0919, Dataset size: 600
# Epoch 2400/4000, Loss: 0.0895, Dataset size: 600
# Epoch 2450/4000, Loss: 0.0876, Dataset size: 600
# Epoch 2500/4000, Loss: 0.0892, Dataset size: 600
# Epoch 2550/4000, Loss: 0.0864, Dataset size: 600
# Epoch 2600/4000, Loss: 0.0840, Dataset size: 600
# Epoch 2650/4000, Loss: 0.0819, Dataset size: 600
# Epoch 2700/4000, Loss: 0.0804, Dataset size: 600
# Epoch 2750/4000, Loss: 0.0785, Dataset size: 600
# Epoch 2800/4000, Loss: 0.0790, Dataset size: 600
# Epoch 2850/4000, Loss: 0.0746, Dataset size: 600
# Epoch 2900/4000, Loss: 0.0731, Dataset size: 600
# Epoch 2950/4000, Loss: 0.0721, Dataset size: 600
# Epoch 3000/4000, Loss: 0.0693, Dataset size: 600
#   [Epoch 3000] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 600 → 700 (+100 unique)
# Epoch 3050/4000, Loss: 0.0580, Dataset size: 700
# Epoch 3100/4000, Loss: 0.0576, Dataset size: 700
# Epoch 3150/4000, Loss: 0.0552, Dataset size: 700
# Epoch 3200/4000, Loss: 0.0536, Dataset size: 700
# Epoch 3250/4000, Loss: 0.0540, Dataset size: 700
# Epoch 3300/4000, Loss: 0.0508, Dataset size: 700
# Epoch 3350/4000, Loss: 0.0497, Dataset size: 700
# Epoch 3400/4000, Loss: 0.0500, Dataset size: 700
# Epoch 3450/4000, Loss: 0.0481, Dataset size: 700
# Epoch 3500/4000, Loss: 0.0473, Dataset size: 700
# Epoch 3550/4000, Loss: 0.0477, Dataset size: 700
# Epoch 3600/4000, Loss: 0.0452, Dataset size: 700
# Epoch 3650/4000, Loss: 0.0443, Dataset size: 700
# Epoch 3700/4000, Loss: 0.0434, Dataset size: 700
# Epoch 3750/4000, Loss: 0.0423, Dataset size: 700
# Epoch 3800/4000, Loss: 0.0412, Dataset size: 700
# Epoch 3850/4000, Loss: 0.0399, Dataset size: 700
# Epoch 3900/4000, Loss: 0.0387, Dataset size: 700
# Epoch 3950/4000, Loss: 0.0377, Dataset size: 700
# Epoch 0/4000, Loss: 0.0375, Dataset size: 700
# Epoch 50/4000, Loss: 0.0355, Dataset size: 700
# Epoch 100/4000, Loss: 0.0346, Dataset size: 700
# Epoch 150/4000, Loss: 0.0338, Dataset size: 700
# Epoch 200/4000, Loss: 0.0347, Dataset size: 700
# Epoch 250/4000, Loss: 0.0326, Dataset size: 700
# Epoch 300/4000, Loss: 0.0321, Dataset size: 700
# Epoch 350/4000, Loss: 0.0310, Dataset size: 700
# Epoch 400/4000, Loss: 0.0302, Dataset size: 700
# Epoch 450/4000, Loss: 0.0294, Dataset size: 700
# Epoch 500/4000, Loss: 0.0284, Dataset size: 700
# Epoch 550/4000, Loss: 0.0277, Dataset size: 700
# Epoch 600/4000, Loss: 0.0269, Dataset size: 700
# Epoch 650/4000, Loss: 0.0261, Dataset size: 700
# Epoch 700/4000, Loss: 0.0254, Dataset size: 700
# Epoch 750/4000, Loss: 0.0241, Dataset size: 700
# Epoch 800/4000, Loss: 0.0233, Dataset size: 700
# Epoch 850/4000, Loss: 0.0226, Dataset size: 700
# Epoch 900/4000, Loss: 0.0218, Dataset size: 700
# Epoch 950/4000, Loss: 0.0218, Dataset size: 700
# Epoch 1000/4000, Loss: 0.0204, Dataset size: 700
# Epoch 1050/4000, Loss: 0.0197, Dataset size: 700
# Epoch 1100/4000, Loss: 0.0218, Dataset size: 700
# Epoch 1150/4000, Loss: 0.0186, Dataset size: 700
# Epoch 1200/4000, Loss: 0.0180, Dataset size: 700
# Epoch 1250/4000, Loss: 0.0176, Dataset size: 700
# Epoch 1300/4000, Loss: 0.0172, Dataset size: 700
# Epoch 1350/4000, Loss: 0.0170, Dataset size: 700
# Epoch 1400/4000, Loss: 0.0162, Dataset size: 700
# Epoch 1450/4000, Loss: 0.0158, Dataset size: 700
# Epoch 1500/4000, Loss: 0.0151, Dataset size: 700
#   [Epoch 1500] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 700 → 787 (+87 unique)
# Epoch 1550/4000, Loss: 0.0129, Dataset size: 787
# Epoch 1600/4000, Loss: 0.0128, Dataset size: 787
# Epoch 1650/4000, Loss: 0.0119, Dataset size: 787
# Epoch 1700/4000, Loss: 0.0114, Dataset size: 787
# Epoch 1750/4000, Loss: 0.0109, Dataset size: 787
# Epoch 1800/4000, Loss: 0.0102, Dataset size: 787
# Epoch 1850/4000, Loss: 0.0096, Dataset size: 787
# Epoch 1900/4000, Loss: 0.0090, Dataset size: 787
# Epoch 1950/4000, Loss: 0.0084, Dataset size: 787
# Epoch 2000/4000, Loss: 0.0082, Dataset size: 787
# Epoch 2050/4000, Loss: 0.0077, Dataset size: 787
# Epoch 2100/4000, Loss: 0.0075, Dataset size: 787
# Epoch 2150/4000, Loss: 0.0075, Dataset size: 787
# Epoch 2200/4000, Loss: 0.0072, Dataset size: 787
# Epoch 2250/4000, Loss: 0.0070, Dataset size: 787
# Epoch 2300/4000, Loss: 0.0067, Dataset size: 787
# Epoch 2350/4000, Loss: 0.0066, Dataset size: 787
# Epoch 2400/4000, Loss: 0.0063, Dataset size: 787
# Epoch 2450/4000, Loss: 0.0062, Dataset size: 787
# Epoch 2500/4000, Loss: 0.0063, Dataset size: 787
# Epoch 2550/4000, Loss: 0.0061, Dataset size: 787
# Epoch 2600/4000, Loss: 0.0058, Dataset size: 787
# Epoch 2650/4000, Loss: 0.0057, Dataset size: 787
# Epoch 2700/4000, Loss: 0.0064, Dataset size: 787
# Epoch 2750/4000, Loss: 0.0054, Dataset size: 787
# Epoch 2800/4000, Loss: 0.0052, Dataset size: 787
# Epoch 2850/4000, Loss: 0.0053, Dataset size: 787
# Epoch 2900/4000, Loss: 0.0052, Dataset size: 787
# Epoch 2950/4000, Loss: 0.0050, Dataset size: 787
# Epoch 3000/4000, Loss: 0.0047, Dataset size: 787
#   [Epoch 3000] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 787 → 793 (+6 unique)
# Epoch 3050/4000, Loss: 0.0047, Dataset size: 793
# Epoch 3100/4000, Loss: 0.0044, Dataset size: 793
# Epoch 3150/4000, Loss: 0.0043, Dataset size: 793
# Epoch 3200/4000, Loss: 0.0041, Dataset size: 793
# Epoch 3250/4000, Loss: 0.0040, Dataset size: 793
# Epoch 3300/4000, Loss: 0.0047, Dataset size: 793
# Epoch 3350/4000, Loss: 0.0036, Dataset size: 793
# Epoch 3400/4000, Loss: 0.0035, Dataset size: 793
# Epoch 3450/4000, Loss: 0.0033, Dataset size: 793
# Epoch 3500/4000, Loss: 0.0030, Dataset size: 793
# Epoch 3550/4000, Loss: 0.0027, Dataset size: 793
# Epoch 3600/4000, Loss: 0.0025, Dataset size: 793
# Epoch 3650/4000, Loss: 0.0032, Dataset size: 793
# Epoch 3700/4000, Loss: 0.0020, Dataset size: 793
# Epoch 3750/4000, Loss: 0.0020, Dataset size: 793
# Epoch 3800/4000, Loss: 0.0021, Dataset size: 793
# Epoch 3850/4000, Loss: 0.0019, Dataset size: 793
# Epoch 3900/4000, Loss: 0.0019, Dataset size: 793
# Epoch 3950/4000, Loss: 0.0019, Dataset size: 793
# Epoch 0/4000, Loss: 0.0019, Dataset size: 793
# Epoch 50/4000, Loss: 0.0019, Dataset size: 793
# Epoch 100/4000, Loss: 0.0027, Dataset size: 793
# Epoch 150/4000, Loss: 0.0020, Dataset size: 793
# Epoch 200/4000, Loss: 0.0019, Dataset size: 793
# Epoch 250/4000, Loss: 0.0020, Dataset size: 793
# Epoch 300/4000, Loss: 0.0018, Dataset size: 793
# Epoch 350/4000, Loss: 0.0018, Dataset size: 793
# Epoch 400/4000, Loss: 0.0018, Dataset size: 793
# Epoch 450/4000, Loss: 0.0018, Dataset size: 793
# Epoch 500/4000, Loss: 0.0018, Dataset size: 793
# Epoch 550/4000, Loss: 0.0018, Dataset size: 793
# Epoch 600/4000, Loss: 0.0018, Dataset size: 793
# Epoch 650/4000, Loss: 0.0018, Dataset size: 793
# Epoch 700/4000, Loss: 0.0017, Dataset size: 793
# Epoch 750/4000, Loss: 0.0018, Dataset size: 793
# Epoch 800/4000, Loss: 0.0017, Dataset size: 793
# Epoch 850/4000, Loss: 0.0017, Dataset size: 793
# Epoch 900/4000, Loss: 0.0018, Dataset size: 793
# Epoch 950/4000, Loss: 0.0017, Dataset size: 793
# Epoch 1000/4000, Loss: 0.0017, Dataset size: 793
# Epoch 1050/4000, Loss: 0.0018, Dataset size: 793
# Epoch 1100/4000, Loss: 0.0017, Dataset size: 793
# Epoch 1150/4000, Loss: 0.0016, Dataset size: 793
# Epoch 1200/4000, Loss: 0.0016, Dataset size: 793
# Epoch 1250/4000, Loss: 0.0017, Dataset size: 793
# Epoch 1300/4000, Loss: 0.0017, Dataset size: 793
# Epoch 1350/4000, Loss: 0.0017, Dataset size: 793
# Epoch 1400/4000, Loss: 0.0016, Dataset size: 793
# Epoch 1450/4000, Loss: 0.0016, Dataset size: 793
# Epoch 1500/4000, Loss: 0.0016, Dataset size: 793
#   [Epoch 1500] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 793 → 797 (+4 unique)
# Epoch 1550/4000, Loss: 0.0016, Dataset size: 797
# Epoch 1600/4000, Loss: 0.0016, Dataset size: 797
# Epoch 1650/4000, Loss: 0.0015, Dataset size: 797
# Epoch 1700/4000, Loss: 0.0015, Dataset size: 797
# Epoch 1750/4000, Loss: 0.0015, Dataset size: 797
# Epoch 1800/4000, Loss: 0.0016, Dataset size: 797
# Epoch 1850/4000, Loss: 0.0015, Dataset size: 797
# Epoch 1900/4000, Loss: 0.0024, Dataset size: 797
# Epoch 1950/4000, Loss: 0.0017, Dataset size: 797
# Epoch 2000/4000, Loss: 0.0015, Dataset size: 797
# Epoch 2050/4000, Loss: 0.0016, Dataset size: 797
# Epoch 2100/4000, Loss: 0.0015, Dataset size: 797
# Epoch 2150/4000, Loss: 0.0015, Dataset size: 797
# Epoch 2200/4000, Loss: 0.0015, Dataset size: 797
# Epoch 2250/4000, Loss: 0.0015, Dataset size: 797
# Epoch 2300/4000, Loss: 0.0015, Dataset size: 797
# Epoch 2350/4000, Loss: 0.0015, Dataset size: 797
# Epoch 2400/4000, Loss: 0.0015, Dataset size: 797
# Epoch 2450/4000, Loss: 0.0015, Dataset size: 797
# Epoch 2500/4000, Loss: 0.0014, Dataset size: 797
# Epoch 2550/4000, Loss: 0.0015, Dataset size: 797
# Epoch 2600/4000, Loss: 0.0015, Dataset size: 797
# Epoch 2650/4000, Loss: 0.0014, Dataset size: 797
# Epoch 2700/4000, Loss: 0.0014, Dataset size: 797
# Epoch 2750/4000, Loss: 0.0014, Dataset size: 797
# Epoch 2800/4000, Loss: 0.0015, Dataset size: 797
# Epoch 2850/4000, Loss: 0.0014, Dataset size: 797
# Epoch 2900/4000, Loss: 0.0014, Dataset size: 797
# Epoch 2950/4000, Loss: 0.0014, Dataset size: 797
# Epoch 3000/4000, Loss: 0.0014, Dataset size: 797
#   [Epoch 3000] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 797 → 801 (+4 unique)
# Epoch 3050/4000, Loss: 0.0014, Dataset size: 801
# Epoch 3100/4000, Loss: 0.0014, Dataset size: 801
# Epoch 3150/4000, Loss: 0.0013, Dataset size: 801
# Epoch 3200/4000, Loss: 0.0013, Dataset size: 801
# Epoch 3250/4000, Loss: 0.0013, Dataset size: 801
# Epoch 3300/4000, Loss: 0.0042, Dataset size: 801
# Epoch 3350/4000, Loss: 0.0013, Dataset size: 801
# Epoch 3400/4000, Loss: 0.0014, Dataset size: 801
# Epoch 3450/4000, Loss: 0.0014, Dataset size: 801
# Epoch 3500/4000, Loss: 0.0013, Dataset size: 801
# Epoch 3550/4000, Loss: 0.0013, Dataset size: 801
# Epoch 3600/4000, Loss: 0.0013, Dataset size: 801
# Epoch 3650/4000, Loss: 0.0014, Dataset size: 801
# Epoch 3700/4000, Loss: 0.0014, Dataset size: 801
# Epoch 3750/4000, Loss: 0.0013, Dataset size: 801
# Epoch 3800/4000, Loss: 0.0013, Dataset size: 801
# Epoch 3850/4000, Loss: 0.0013, Dataset size: 801
# Epoch 3900/4000, Loss: 0.0015, Dataset size: 801
# Epoch 3950/4000, Loss: 0.0013, Dataset size: 801
# Epoch 0/4000, Loss: 0.0025, Dataset size: 801
# Epoch 50/4000, Loss: 0.0013, Dataset size: 801
# Epoch 100/4000, Loss: 0.0014, Dataset size: 801
# Epoch 150/4000, Loss: 0.0013, Dataset size: 801
# Epoch 200/4000, Loss: 0.0012, Dataset size: 801
# Epoch 250/4000, Loss: 0.0013, Dataset size: 801
# Epoch 300/4000, Loss: 0.0012, Dataset size: 801
# Epoch 350/4000, Loss: 0.0013, Dataset size: 801
# Epoch 400/4000, Loss: 0.0012, Dataset size: 801
# Epoch 450/4000, Loss: 0.0013, Dataset size: 801
# Epoch 500/4000, Loss: 0.0012, Dataset size: 801
# Epoch 550/4000, Loss: 0.0013, Dataset size: 801
# Epoch 600/4000, Loss: 0.0013, Dataset size: 801
# Epoch 650/4000, Loss: 0.0015, Dataset size: 801
# Epoch 700/4000, Loss: 0.0012, Dataset size: 801
# Epoch 750/4000, Loss: 0.0012, Dataset size: 801
# Epoch 800/4000, Loss: 0.0012, Dataset size: 801
# Epoch 850/4000, Loss: 0.0013, Dataset size: 801
# Epoch 900/4000, Loss: 0.0011, Dataset size: 801
# Epoch 950/4000, Loss: 0.0012, Dataset size: 801
# Epoch 1000/4000, Loss: 0.0011, Dataset size: 801
# Epoch 1050/4000, Loss: 0.0013, Dataset size: 801
# Epoch 1100/4000, Loss: 0.0011, Dataset size: 801
# Epoch 1150/4000, Loss: 0.0013, Dataset size: 801
# Epoch 1200/4000, Loss: 0.0011, Dataset size: 801
# Epoch 1250/4000, Loss: 0.0012, Dataset size: 801
# Epoch 1300/4000, Loss: 0.0011, Dataset size: 801
# Epoch 1350/4000, Loss: 0.0011, Dataset size: 801
# Epoch 1400/4000, Loss: 0.0011, Dataset size: 801
# Epoch 1450/4000, Loss: 0.0021, Dataset size: 801
# Epoch 1500/4000, Loss: 0.0011, Dataset size: 801
#   [Epoch 1500] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 801 → 803 (+2 unique)
# Epoch 1550/4000, Loss: 0.0011, Dataset size: 803
# Epoch 1600/4000, Loss: 0.0011, Dataset size: 803
# Epoch 1650/4000, Loss: 0.0011, Dataset size: 803
# Epoch 1700/4000, Loss: 0.0011, Dataset size: 803
# Epoch 1750/4000, Loss: 0.0010, Dataset size: 803
# Epoch 1800/4000, Loss: 0.0011, Dataset size: 803
# Epoch 1850/4000, Loss: 0.0011, Dataset size: 803
# Epoch 1900/4000, Loss: 0.0012, Dataset size: 803
# Epoch 1950/4000, Loss: 0.0013, Dataset size: 803
# Epoch 2000/4000, Loss: 0.0013, Dataset size: 803
# Epoch 2050/4000, Loss: 0.0011, Dataset size: 803
# Epoch 2100/4000, Loss: 0.0011, Dataset size: 803
# Epoch 2150/4000, Loss: 0.0010, Dataset size: 803
# Epoch 2200/4000, Loss: 0.0010, Dataset size: 803
# Epoch 2250/4000, Loss: 0.0010, Dataset size: 803
# Epoch 2300/4000, Loss: 0.0010, Dataset size: 803
# Epoch 2350/4000, Loss: 0.0010, Dataset size: 803
# Epoch 2400/4000, Loss: 0.0010, Dataset size: 803
# Epoch 2450/4000, Loss: 0.0010, Dataset size: 803
# Epoch 2500/4000, Loss: 0.0010, Dataset size: 803
# Epoch 2550/4000, Loss: 0.0038, Dataset size: 803
# Epoch 2600/4000, Loss: 0.0010, Dataset size: 803
# Epoch 2650/4000, Loss: 0.0012, Dataset size: 803
# Epoch 2700/4000, Loss: 0.0012, Dataset size: 803
# Epoch 2750/4000, Loss: 0.0010, Dataset size: 803
# Epoch 2800/4000, Loss: 0.0010, Dataset size: 803
# Epoch 2850/4000, Loss: 0.0010, Dataset size: 803
# Epoch 2900/4000, Loss: 0.0009, Dataset size: 803
# Epoch 2950/4000, Loss: 0.0009, Dataset size: 803
# Epoch 3000/4000, Loss: 0.0011, Dataset size: 803
#   [Epoch 3000] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 803 → 807 (+4 unique)
# Epoch 3050/4000, Loss: 0.0010, Dataset size: 807
# Epoch 3100/4000, Loss: 0.0009, Dataset size: 807
# Epoch 3150/4000, Loss: 0.0009, Dataset size: 807
# Epoch 3200/4000, Loss: 0.0009, Dataset size: 807
# Epoch 3250/4000, Loss: 0.0009, Dataset size: 807
# Epoch 3300/4000, Loss: 0.0009, Dataset size: 807
# Epoch 3350/4000, Loss: 0.0010, Dataset size: 807
# Epoch 3400/4000, Loss: 0.0009, Dataset size: 807
# Epoch 3450/4000, Loss: 0.0010, Dataset size: 807
# Epoch 3500/4000, Loss: 0.0009, Dataset size: 807
# Epoch 3550/4000, Loss: 0.0009, Dataset size: 807
# Epoch 3600/4000, Loss: 0.0010, Dataset size: 807
# Epoch 3650/4000, Loss: 0.0009, Dataset size: 807
# Epoch 3700/4000, Loss: 0.0009, Dataset size: 807
# Epoch 3750/4000, Loss: 0.0010, Dataset size: 807
# Epoch 3800/4000, Loss: 0.0009, Dataset size: 807
# Epoch 3850/4000, Loss: 0.0009, Dataset size: 807
# Epoch 3900/4000, Loss: 0.0009, Dataset size: 807
# Epoch 3950/4000, Loss: 0.0009, Dataset size: 807
# Epoch 0/4000, Loss: 0.0009, Dataset size: 807
# Epoch 50/4000, Loss: 0.0009, Dataset size: 807
# Epoch 100/4000, Loss: 0.0008, Dataset size: 807
# Epoch 150/4000, Loss: 0.0009, Dataset size: 807
# Epoch 200/4000, Loss: 0.0011, Dataset size: 807
# Epoch 250/4000, Loss: 0.0008, Dataset size: 807
# Epoch 300/4000, Loss: 0.0009, Dataset size: 807
# Epoch 350/4000, Loss: 0.0009, Dataset size: 807
# Epoch 400/4000, Loss: 0.0009, Dataset size: 807
# Epoch 450/4000, Loss: 0.0008, Dataset size: 807
# Epoch 500/4000, Loss: 0.0008, Dataset size: 807
# Epoch 550/4000, Loss: 0.0008, Dataset size: 807
# Epoch 600/4000, Loss: 0.0010, Dataset size: 807
# Epoch 650/4000, Loss: 0.0008, Dataset size: 807
# Epoch 700/4000, Loss: 0.0008, Dataset size: 807
# Epoch 750/4000, Loss: 0.0008, Dataset size: 807
# Epoch 800/4000, Loss: 0.0008, Dataset size: 807
# Epoch 850/4000, Loss: 0.0009, Dataset size: 807
# Epoch 900/4000, Loss: 0.0008, Dataset size: 807
# Epoch 950/4000, Loss: 0.0008, Dataset size: 807
# Epoch 1000/4000, Loss: 0.0009, Dataset size: 807
# Epoch 1050/4000, Loss: 0.0008, Dataset size: 807
# Epoch 1100/4000, Loss: 0.0008, Dataset size: 807
# Epoch 1150/4000, Loss: 0.0008, Dataset size: 807
# Epoch 1200/4000, Loss: 0.0008, Dataset size: 807
# Epoch 1250/4000, Loss: 0.0008, Dataset size: 807
# Epoch 1300/4000, Loss: 0.0008, Dataset size: 807
# Epoch 1350/4000, Loss: 0.0008, Dataset size: 807
# Epoch 1400/4000, Loss: 0.0008, Dataset size: 807
# Epoch 1450/4000, Loss: 0.0008, Dataset size: 807
# Epoch 1500/4000, Loss: 0.0008, Dataset size: 807
#   [Epoch 1500] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 807 → 811 (+4 unique)
# Epoch 1550/4000, Loss: 0.0011, Dataset size: 811
# Epoch 1600/4000, Loss: 0.0007, Dataset size: 811
# Epoch 1650/4000, Loss: 0.0008, Dataset size: 811
# Epoch 1700/4000, Loss: 0.0007, Dataset size: 811
# Epoch 1750/4000, Loss: 0.0008, Dataset size: 811
# Epoch 1800/4000, Loss: 0.0007, Dataset size: 811
# Epoch 1850/4000, Loss: 0.0008, Dataset size: 811
# Epoch 1900/4000, Loss: 0.0007, Dataset size: 811
# Epoch 1950/4000, Loss: 0.0008, Dataset size: 811
# Epoch 2000/4000, Loss: 0.0007, Dataset size: 811
# Epoch 2050/4000, Loss: 0.0008, Dataset size: 811
# Epoch 2100/4000, Loss: 0.0008, Dataset size: 811
# Epoch 2150/4000, Loss: 0.0007, Dataset size: 811
# Epoch 2200/4000, Loss: 0.0007, Dataset size: 811
# Epoch 2250/4000, Loss: 0.0008, Dataset size: 811
# Epoch 2300/4000, Loss: 0.0007, Dataset size: 811
# Epoch 2350/4000, Loss: 0.0007, Dataset size: 811
# Epoch 2400/4000, Loss: 0.0008, Dataset size: 811
# Epoch 2450/4000, Loss: 0.0007, Dataset size: 811
# Epoch 2500/4000, Loss: 0.0007, Dataset size: 811
# Epoch 2550/4000, Loss: 0.0007, Dataset size: 811
# Epoch 2600/4000, Loss: 0.0007, Dataset size: 811
# Epoch 2650/4000, Loss: 0.0007, Dataset size: 811
# Epoch 2700/4000, Loss: 0.0007, Dataset size: 811
# Epoch 2750/4000, Loss: 0.0007, Dataset size: 811
# Epoch 2800/4000, Loss: 0.0007, Dataset size: 811
# Epoch 2850/4000, Loss: 0.0007, Dataset size: 811
# Epoch 2900/4000, Loss: 0.0007, Dataset size: 811
# Epoch 2950/4000, Loss: 0.0007, Dataset size: 811
# Epoch 3000/4000, Loss: 0.0007, Dataset size: 811
#   [Epoch 3000] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 811 → 813 (+2 unique)
# Epoch 3050/4000, Loss: 0.0008, Dataset size: 813
# Epoch 3100/4000, Loss: 0.0007, Dataset size: 813
# Epoch 3150/4000, Loss: 0.0007, Dataset size: 813
# Epoch 3200/4000, Loss: 0.0007, Dataset size: 813
# Epoch 3250/4000, Loss: 0.0008, Dataset size: 813
# Epoch 3300/4000, Loss: 0.0007, Dataset size: 813
# Epoch 3350/4000, Loss: 0.0006, Dataset size: 813
# Epoch 3400/4000, Loss: 0.0011, Dataset size: 813
# Epoch 3450/4000, Loss: 0.0006, Dataset size: 813
# Epoch 3500/4000, Loss: 0.0008, Dataset size: 813
# Epoch 3550/4000, Loss: 0.0006, Dataset size: 813
# Epoch 3600/4000, Loss: 0.0006, Dataset size: 813
# Epoch 3650/4000, Loss: 0.0006, Dataset size: 813
# Epoch 3700/4000, Loss: 0.0006, Dataset size: 813
# Epoch 3750/4000, Loss: 0.0006, Dataset size: 813
# Epoch 3800/4000, Loss: 0.0007, Dataset size: 813
# Epoch 3850/4000, Loss: 0.0006, Dataset size: 813
# Epoch 3900/4000, Loss: 0.0006, Dataset size: 813
# Epoch 3950/4000, Loss: 0.0006, Dataset size: 813
# Epoch 0/4000, Loss: 0.0007, Dataset size: 813
# Epoch 50/4000, Loss: 0.0007, Dataset size: 813
# Epoch 100/4000, Loss: 0.0007, Dataset size: 813
# Epoch 150/4000, Loss: 0.0006, Dataset size: 813
# Epoch 200/4000, Loss: 0.0006, Dataset size: 813
# Epoch 250/4000, Loss: 0.0007, Dataset size: 813
# Epoch 300/4000, Loss: 0.0006, Dataset size: 813
# Epoch 350/4000, Loss: 0.0006, Dataset size: 813
# Epoch 400/4000, Loss: 0.0007, Dataset size: 813
# Epoch 450/4000, Loss: 0.0007, Dataset size: 813
# Epoch 500/4000, Loss: 0.0007, Dataset size: 813
# Epoch 550/4000, Loss: 0.0006, Dataset size: 813
# Epoch 600/4000, Loss: 0.0006, Dataset size: 813
# Epoch 650/4000, Loss: 0.0007, Dataset size: 813
# Epoch 700/4000, Loss: 0.0006, Dataset size: 813
# Epoch 750/4000, Loss: 0.0006, Dataset size: 813
# Epoch 800/4000, Loss: 0.0006, Dataset size: 813
# Epoch 850/4000, Loss: 0.0006, Dataset size: 813
# Epoch 900/4000, Loss: 0.0006, Dataset size: 813
# Epoch 950/4000, Loss: 0.0010, Dataset size: 813
# Epoch 1000/4000, Loss: 0.0006, Dataset size: 813
# Epoch 1050/4000, Loss: 0.0006, Dataset size: 813
# Epoch 1100/4000, Loss: 0.0006, Dataset size: 813
# Epoch 1150/4000, Loss: 0.0007, Dataset size: 813
# Epoch 1200/4000, Loss: 0.0006, Dataset size: 813
# Epoch 1250/4000, Loss: 0.0007, Dataset size: 813
# Epoch 1300/4000, Loss: 0.0006, Dataset size: 813
# Epoch 1350/4000, Loss: 0.0006, Dataset size: 813
# Epoch 1400/4000, Loss: 0.0006, Dataset size: 813
# Epoch 1450/4000, Loss: 0.0006, Dataset size: 813
# Epoch 1500/4000, Loss: 0.0007, Dataset size: 813
#   [Epoch 1500] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 813 → 913 (+100 unique)
# Epoch 1550/4000, Loss: 0.0005, Dataset size: 913
# Epoch 1600/4000, Loss: 0.0005, Dataset size: 913
# Epoch 1650/4000, Loss: 0.0005, Dataset size: 913
# Epoch 1700/4000, Loss: 0.0005, Dataset size: 913
# Epoch 1750/4000, Loss: 0.0005, Dataset size: 913
# Epoch 1800/4000, Loss: 0.0005, Dataset size: 913
# Epoch 1850/4000, Loss: 0.0005, Dataset size: 913
# Epoch 1900/4000, Loss: 0.0005, Dataset size: 913
# Epoch 1950/4000, Loss: 0.0005, Dataset size: 913
# Epoch 2000/4000, Loss: 0.0005, Dataset size: 913
# Epoch 2050/4000, Loss: 0.0006, Dataset size: 913
# Epoch 2100/4000, Loss: 0.0005, Dataset size: 913
# Epoch 2150/4000, Loss: 0.0446, Dataset size: 913
# Epoch 2200/4000, Loss: 0.0005, Dataset size: 913
# Epoch 2250/4000, Loss: 0.0005, Dataset size: 913
# Epoch 2300/4000, Loss: 0.0005, Dataset size: 913
# Epoch 2350/4000, Loss: 0.0005, Dataset size: 913
# Epoch 2400/4000, Loss: 0.0005, Dataset size: 913
# Epoch 2450/4000, Loss: 0.0005, Dataset size: 913
# Epoch 2500/4000, Loss: 0.0006, Dataset size: 913
# Epoch 2550/4000, Loss: 0.0006, Dataset size: 913
# Epoch 2600/4000, Loss: 0.0005, Dataset size: 913
# Epoch 2650/4000, Loss: 0.0005, Dataset size: 913
# Epoch 2700/4000, Loss: 0.0005, Dataset size: 913
# Epoch 2750/4000, Loss: 0.0005, Dataset size: 913
# Epoch 2800/4000, Loss: 0.0005, Dataset size: 913
# Epoch 2850/4000, Loss: 0.0005, Dataset size: 913
# Epoch 2900/4000, Loss: 0.0005, Dataset size: 913
#   [Epoch 2919] Loss reached zero!
#
# Training completed!
# Final Loss: 0.0005
# The learned margin is 0.000000
# Final dataset size: 913

# %%
# Plot loss curve
print("\nPlotting loss curve...")
risks = [loss_density]
plot_results(risks, labels=['Loss due to density'])
# Out:
# Plotting loss curve...

# %%
# Visualize density
print("\nGenerating density visualization...")
grid_size = 100
x1 = torch.linspace(-6, 6, grid_size)
x2 = torch.linspace(-6, 6, grid_size)
x1_grid, x2_grid = torch.meshgrid(x1, x2, indexing='ij')
grid_points = torch.stack([x1_grid.ravel(), x2_grid.ravel()], dim=1).to(device)

with torch.no_grad():
    rho_set = a_ret(grid_points) / (torch.exp(
        torch.sum(grid_points**2, dim=1, keepdim=True) + 
        torch.sum((b_ret(grid_points))**2, dim=1, keepdim=True)
    ))

violations_set = rho_set.detach().cpu().numpy().reshape(grid_size, grid_size)

plt.figure(figsize=(8, 6))
plt.imshow(violations_set, extent=[-6, 6, -6, 6], origin='lower',
            cmap='coolwarm', aspect='auto')
plt.colorbar(label="density values (should be positive)")
plt.xlabel("x1 (angle)")
plt.ylabel("x2 (angular velocity)")
plt.title("Density Visualization")
circle = patches.Circle((0, 0), 6, color='black', fill=False, 
                        linewidth=1, label="$||x||^2 \\leq 6$")
plt.gca().add_patch(circle)
plt.legend(loc='upper right')
plt.grid(False)
plt.show()
# Out:
# Generating density visualization...

# %%
    # Visualize divergence/violations
    print("\nGenerating divergence visualization...")
    # Note: control_density_risk_vectorized needs gradients, so we don't use no_grad here
    divergence_set = control_density_risk_vectorized(grid_points, f, g, a_ret, b_ret, c_ret)
    
    violations_set = torch.where(divergence_set <= 0, 1, -1)
    violations_set = violations_set.detach().cpu().numpy().reshape(grid_size, grid_size)
    
    plt.figure(figsize=(8, 6))
    plt.imshow(violations_set, extent=[-6, 6, -6, 6], origin='lower',
               cmap='coolwarm', aspect='auto')
    plt.colorbar(label="1 indicates violations, -1 indicates satisfactions")
    plt.xlabel("x1 (angle)")
    plt.ylabel("x2 (angular velocity)")
    plt.title("Violations Set Visualization")
    circle = patches.Circle((0, 0), 6, color='black', fill=False, 
                            linewidth=2, label="$||x||^2 \\leq 6$")
    plt.gca().add_patch(circle)
    plt.legend(loc='upper right')
    plt.grid(False)
    plt.show()
# Out:
# Generating divergence visualization...

# %%
# Plot density contours with flow field
print("\nPlotting density contours with flow field...")
plot_density_contours(a_net, b_net, c_net,5e-8, device, plot_flow=True)

print("\n" + "=" * 60)
print("EXPERIMENT COMPLETED!")
print("=" * 60)
# Out:
# Plotting density contours with flow field...
# /tmp/ipykernel_780269/2736553463.py:33: UserWarning: The following kwargs were not used by contour: 'label'
#   ax.contour(X,Y,rho_set-density_threshold,levels=1,colors='black', linewidths=2,linestyles='solid', label='Density')
# ============================================================
# EXPERIMENT COMPLETED!
# ============================================================

# %%
# save the models
torch.save(a_ret.state_dict(), 'inverted_pendulum_a_net.pth')
torch.save(b_ret.state_dict(), 'inverted_pendulum_b_net.pth')
torch.save(c_ret.state_dict(), 'inverted_pendulum_c_net.pth')

# %%
torch.manual_seed(2004)
random.seed()

# learn a new controller with new sets of data

numerical_x = torch.Tensor(500, 2).uniform_(-6, 6).float().to(device)

loss_density1, a_ret1, b_ret1, c_ret1, gamma_net1 = train_density(
    numerical_x, epochs=4000, lr=1e-4, ball_lb=0.5, ball_ub=6, check_interval=1500
)

# Plot loss curve
print("\nPlotting loss curve for new controller...")
risks = [loss_density1]
plot_results(risks, labels=['Loss due to density for new controller'])
# Out:
# Training density function with SMT verification
# Initial dataset size: 500
# Epoch 0/4000, Loss: 99.7213, Dataset size: 500
# Epoch 50/4000, Loss: 77.4834, Dataset size: 500
# Epoch 100/4000, Loss: 66.5834, Dataset size: 500
# Epoch 150/4000, Loss: 57.7793, Dataset size: 500
# Epoch 200/4000, Loss: 50.1188, Dataset size: 500
# Epoch 250/4000, Loss: 43.5753, Dataset size: 500
# Epoch 300/4000, Loss: 38.0943, Dataset size: 500
# Epoch 350/4000, Loss: 33.0669, Dataset size: 500
# Epoch 400/4000, Loss: 28.7568, Dataset size: 500
# Epoch 450/4000, Loss: 24.9272, Dataset size: 500
# Epoch 500/4000, Loss: 21.4711, Dataset size: 500
# Epoch 550/4000, Loss: 18.5436, Dataset size: 500
# Epoch 600/4000, Loss: 15.9753, Dataset size: 500
# Epoch 650/4000, Loss: 13.7502, Dataset size: 500
# Epoch 700/4000, Loss: 11.6533, Dataset size: 500
# Epoch 750/4000, Loss: 9.7957, Dataset size: 500
# Epoch 800/4000, Loss: 8.2889, Dataset size: 500
# Epoch 850/4000, Loss: 7.0779, Dataset size: 500
# Epoch 900/4000, Loss: 6.0462, Dataset size: 500
# Epoch 950/4000, Loss: 5.0742, Dataset size: 500
# Epoch 1000/4000, Loss: 4.1360, Dataset size: 500
# Epoch 1050/4000, Loss: 3.3111, Dataset size: 500
# Epoch 1100/4000, Loss: 2.6618, Dataset size: 500
# Epoch 1150/4000, Loss: 2.1130, Dataset size: 500
# Epoch 1200/4000, Loss: 1.7046, Dataset size: 500
# Epoch 1250/4000, Loss: 1.4199, Dataset size: 500
# Epoch 1300/4000, Loss: 1.1845, Dataset size: 500
# Epoch 1350/4000, Loss: 1.0078, Dataset size: 500
# Epoch 1400/4000, Loss: 0.8816, Dataset size: 500
# Epoch 1450/4000, Loss: 0.7969, Dataset size: 500
# Epoch 1500/4000, Loss: 0.7287, Dataset size: 500
#   [Epoch 1500] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 500 → 600 (+100 unique)
# Epoch 1550/4000, Loss: 0.5942, Dataset size: 600
# Epoch 1600/4000, Loss: 0.5727, Dataset size: 600
# Epoch 1650/4000, Loss: 0.5563, Dataset size: 600
# Epoch 1700/4000, Loss: 0.5394, Dataset size: 600
# Epoch 1750/4000, Loss: 0.5218, Dataset size: 600
# Epoch 1800/4000, Loss: 0.5059, Dataset size: 600
# Epoch 1850/4000, Loss: 0.4938, Dataset size: 600
# Epoch 1900/4000, Loss: 0.4812, Dataset size: 600
# Epoch 1950/4000, Loss: 0.4686, Dataset size: 600
# Epoch 2000/4000, Loss: 0.4536, Dataset size: 600
# Epoch 2050/4000, Loss: 0.4389, Dataset size: 600
# Epoch 2100/4000, Loss: 0.4246, Dataset size: 600
# Epoch 2150/4000, Loss: 0.4100, Dataset size: 600
# Epoch 2200/4000, Loss: 0.3954, Dataset size: 600
# Epoch 2250/4000, Loss: 0.3833, Dataset size: 600
# Epoch 2300/4000, Loss: 0.3659, Dataset size: 600
# Epoch 2350/4000, Loss: 0.3514, Dataset size: 600
# Epoch 2400/4000, Loss: 0.3383, Dataset size: 600
# Epoch 2450/4000, Loss: 0.3241, Dataset size: 600
# Epoch 2500/4000, Loss: 0.3107, Dataset size: 600
# Epoch 2550/4000, Loss: 0.2969, Dataset size: 600
# Epoch 2600/4000, Loss: 0.2838, Dataset size: 600
# Epoch 2650/4000, Loss: 0.2714, Dataset size: 600
# Epoch 2700/4000, Loss: 0.2581, Dataset size: 600
# Epoch 2750/4000, Loss: 0.2441, Dataset size: 600
# Epoch 2800/4000, Loss: 0.2317, Dataset size: 600
# Epoch 2850/4000, Loss: 0.2203, Dataset size: 600
# Epoch 2900/4000, Loss: 0.2095, Dataset size: 600
# Epoch 2950/4000, Loss: 0.1990, Dataset size: 600
# Epoch 3000/4000, Loss: 0.1892, Dataset size: 600
#   [Epoch 3000] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 600 → 700 (+100 unique)
# Epoch 3050/4000, Loss: 0.1589, Dataset size: 700
# Epoch 3100/4000, Loss: 0.1525, Dataset size: 700
# Epoch 3150/4000, Loss: 0.1464, Dataset size: 700
# Epoch 3200/4000, Loss: 0.1407, Dataset size: 700
# Epoch 3250/4000, Loss: 0.1350, Dataset size: 700
# Epoch 3300/4000, Loss: 0.1293, Dataset size: 700
# Epoch 3350/4000, Loss: 0.1274, Dataset size: 700
# Epoch 3400/4000, Loss: 0.1217, Dataset size: 700
# Epoch 3450/4000, Loss: 0.1205, Dataset size: 700
# Epoch 3500/4000, Loss: 0.1147, Dataset size: 700
# Epoch 3550/4000, Loss: 0.1126, Dataset size: 700
# Epoch 3600/4000, Loss: 0.1144, Dataset size: 700
# Epoch 3650/4000, Loss: 0.1095, Dataset size: 700
# Epoch 3700/4000, Loss: 0.1085, Dataset size: 700
# Epoch 3750/4000, Loss: 0.1065, Dataset size: 700
# Epoch 3800/4000, Loss: 0.1051, Dataset size: 700
# Epoch 3850/4000, Loss: 0.1067, Dataset size: 700
# Epoch 3900/4000, Loss: 0.1026, Dataset size: 700
# Epoch 3950/4000, Loss: 0.1014, Dataset size: 700
# Epoch 0/4000, Loss: 0.1004, Dataset size: 700
# Epoch 50/4000, Loss: 0.0994, Dataset size: 700
# Epoch 100/4000, Loss: 0.0997, Dataset size: 700
# Epoch 150/4000, Loss: 0.0970, Dataset size: 700
# Epoch 200/4000, Loss: 0.0966, Dataset size: 700
# Epoch 250/4000, Loss: 0.0974, Dataset size: 700
# Epoch 300/4000, Loss: 0.0939, Dataset size: 700
# Epoch 350/4000, Loss: 0.0933, Dataset size: 700
# Epoch 400/4000, Loss: 0.0934, Dataset size: 700
# Epoch 450/4000, Loss: 0.0905, Dataset size: 700
# Epoch 500/4000, Loss: 0.0902, Dataset size: 700
# Epoch 550/4000, Loss: 0.0892, Dataset size: 700
# Epoch 600/4000, Loss: 0.0882, Dataset size: 700
# Epoch 650/4000, Loss: 0.0869, Dataset size: 700
# Epoch 700/4000, Loss: 0.0886, Dataset size: 700
# Epoch 750/4000, Loss: 0.0856, Dataset size: 700
# Epoch 800/4000, Loss: 0.0847, Dataset size: 700
# Epoch 850/4000, Loss: 0.0840, Dataset size: 700
# Epoch 900/4000, Loss: 0.0834, Dataset size: 700
# Epoch 950/4000, Loss: 0.0848, Dataset size: 700
# Epoch 1000/4000, Loss: 0.0812, Dataset size: 700
# Epoch 1050/4000, Loss: 0.0806, Dataset size: 700
# Epoch 1100/4000, Loss: 0.0800, Dataset size: 700
# Epoch 1150/4000, Loss: 0.0794, Dataset size: 700
# Epoch 1200/4000, Loss: 0.0789, Dataset size: 700
# Epoch 1250/4000, Loss: 0.0782, Dataset size: 700
# Epoch 1300/4000, Loss: 0.0778, Dataset size: 700
# Epoch 1350/4000, Loss: 0.0771, Dataset size: 700
# Epoch 1400/4000, Loss: 0.0765, Dataset size: 700
# Epoch 1450/4000, Loss: 0.0762, Dataset size: 700
# Epoch 1500/4000, Loss: 0.0756, Dataset size: 700
#   [Epoch 1500] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 700 → 800 (+100 unique)
# Epoch 1550/4000, Loss: 0.0655, Dataset size: 800
# Epoch 1600/4000, Loss: 0.0651, Dataset size: 800
# Epoch 1650/4000, Loss: 0.0643, Dataset size: 800
# Epoch 1700/4000, Loss: 0.0632, Dataset size: 800
# Epoch 1750/4000, Loss: 0.0628, Dataset size: 800
# Epoch 1800/4000, Loss: 0.0625, Dataset size: 800
# Epoch 1850/4000, Loss: 0.0621, Dataset size: 800
# Epoch 1900/4000, Loss: 0.0620, Dataset size: 800
# Epoch 1950/4000, Loss: 0.0614, Dataset size: 800
# Epoch 2000/4000, Loss: 0.0609, Dataset size: 800
# Epoch 2050/4000, Loss: 0.0604, Dataset size: 800
# Epoch 2100/4000, Loss: 0.0598, Dataset size: 800
# Epoch 2150/4000, Loss: 0.0637, Dataset size: 800
# Epoch 2200/4000, Loss: 0.0606, Dataset size: 800
# Epoch 2250/4000, Loss: 0.0590, Dataset size: 800
# Epoch 2300/4000, Loss: 0.0584, Dataset size: 800
# Epoch 2350/4000, Loss: 0.0575, Dataset size: 800
# Epoch 2400/4000, Loss: 0.0580, Dataset size: 800
# Epoch 2450/4000, Loss: 0.0569, Dataset size: 800
# Epoch 2500/4000, Loss: 0.0568, Dataset size: 800
# Epoch 2550/4000, Loss: 0.0565, Dataset size: 800
# Epoch 2600/4000, Loss: 0.0574, Dataset size: 800
# Epoch 2650/4000, Loss: 0.0557, Dataset size: 800
# Epoch 2700/4000, Loss: 0.0565, Dataset size: 800
# Epoch 2750/4000, Loss: 0.0549, Dataset size: 800
# Epoch 2800/4000, Loss: 0.0556, Dataset size: 800
# Epoch 2850/4000, Loss: 0.0537, Dataset size: 800
# Epoch 2900/4000, Loss: 0.0548, Dataset size: 800
# Epoch 2950/4000, Loss: 0.0527, Dataset size: 800
# Epoch 3000/4000, Loss: 0.0531, Dataset size: 800
#   [Epoch 3000] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 800 → 900 (+100 unique)
# Epoch 3050/4000, Loss: 0.0468, Dataset size: 900
# Epoch 3100/4000, Loss: 0.0462, Dataset size: 900
# Epoch 3150/4000, Loss: 0.0471, Dataset size: 900
# Epoch 3200/4000, Loss: 0.0458, Dataset size: 900
# Epoch 3250/4000, Loss: 0.0454, Dataset size: 900
# Epoch 3300/4000, Loss: 0.0448, Dataset size: 900
# Epoch 3350/4000, Loss: 0.0445, Dataset size: 900
# Epoch 3400/4000, Loss: 0.0442, Dataset size: 900
# Epoch 3450/4000, Loss: 0.0480, Dataset size: 900
# Epoch 3500/4000, Loss: 0.0438, Dataset size: 900
# Epoch 3550/4000, Loss: 0.0472, Dataset size: 900
# Epoch 3600/4000, Loss: 0.0429, Dataset size: 900
# Epoch 3650/4000, Loss: 0.0427, Dataset size: 900
# Epoch 3700/4000, Loss: 0.0424, Dataset size: 900
# Epoch 3750/4000, Loss: 0.0423, Dataset size: 900
# Epoch 3800/4000, Loss: 0.0425, Dataset size: 900
# Epoch 3850/4000, Loss: 0.0449, Dataset size: 900
# Epoch 3900/4000, Loss: 0.0426, Dataset size: 900
# Epoch 3950/4000, Loss: 0.0419, Dataset size: 900
# Epoch 0/4000, Loss: 0.0417, Dataset size: 900
# Epoch 50/4000, Loss: 0.0406, Dataset size: 900
# Epoch 100/4000, Loss: 0.0408, Dataset size: 900
# Epoch 150/4000, Loss: 0.0399, Dataset size: 900
# Epoch 200/4000, Loss: 0.0393, Dataset size: 900
# Epoch 250/4000, Loss: 0.0391, Dataset size: 900
# Epoch 300/4000, Loss: 0.0392, Dataset size: 900
# Epoch 350/4000, Loss: 0.0389, Dataset size: 900
# Epoch 400/4000, Loss: 0.0384, Dataset size: 900
# Epoch 450/4000, Loss: 0.0399, Dataset size: 900
# Epoch 500/4000, Loss: 0.0415, Dataset size: 900
# Epoch 550/4000, Loss: 0.0375, Dataset size: 900
# Epoch 600/4000, Loss: 0.0377, Dataset size: 900
# Epoch 650/4000, Loss: 0.0373, Dataset size: 900
# Epoch 700/4000, Loss: 0.0384, Dataset size: 900
# Epoch 750/4000, Loss: 0.0367, Dataset size: 900
# Epoch 800/4000, Loss: 0.0359, Dataset size: 900
# Epoch 850/4000, Loss: 0.0360, Dataset size: 900
# Epoch 900/4000, Loss: 0.0358, Dataset size: 900
# Epoch 950/4000, Loss: 0.0375, Dataset size: 900
# Epoch 1000/4000, Loss: 0.0351, Dataset size: 900
# Epoch 1050/4000, Loss: 0.0349, Dataset size: 900
# Epoch 1100/4000, Loss: 0.0349, Dataset size: 900
# Epoch 1150/4000, Loss: 0.0347, Dataset size: 900
# Epoch 1200/4000, Loss: 0.0362, Dataset size: 900
# Epoch 1250/4000, Loss: 0.0340, Dataset size: 900
# Epoch 1300/4000, Loss: 0.0340, Dataset size: 900
# Epoch 1350/4000, Loss: 0.0337, Dataset size: 900
# Epoch 1400/4000, Loss: 0.0334, Dataset size: 900
# Epoch 1450/4000, Loss: 0.0332, Dataset size: 900
# Epoch 1500/4000, Loss: 0.0332, Dataset size: 900
#   [Epoch 1500] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 900 → 1000 (+100 unique)
# Epoch 1550/4000, Loss: 0.0306, Dataset size: 1000
# Epoch 1600/4000, Loss: 0.0291, Dataset size: 1000
# Epoch 1650/4000, Loss: 0.0290, Dataset size: 1000
# Epoch 1700/4000, Loss: 0.0327, Dataset size: 1000
# Epoch 1750/4000, Loss: 0.0285, Dataset size: 1000
# Epoch 1800/4000, Loss: 0.0285, Dataset size: 1000
# Epoch 1850/4000, Loss: 0.0280, Dataset size: 1000
# Epoch 1900/4000, Loss: 0.0311, Dataset size: 1000
# Epoch 1950/4000, Loss: 0.0277, Dataset size: 1000
# Epoch 2000/4000, Loss: 0.0274, Dataset size: 1000
# Epoch 2050/4000, Loss: 0.0275, Dataset size: 1000
# Epoch 2100/4000, Loss: 0.0267, Dataset size: 1000
# Epoch 2150/4000, Loss: 0.0265, Dataset size: 1000
# Epoch 2200/4000, Loss: 0.0261, Dataset size: 1000
# Epoch 2250/4000, Loss: 0.0258, Dataset size: 1000
# Epoch 2300/4000, Loss: 0.0253, Dataset size: 1000
# Epoch 2350/4000, Loss: 0.0250, Dataset size: 1000
# Epoch 2400/4000, Loss: 0.0276, Dataset size: 1000
# Epoch 2450/4000, Loss: 0.0242, Dataset size: 1000
# Epoch 2500/4000, Loss: 0.0245, Dataset size: 1000
# Epoch 2550/4000, Loss: 0.0237, Dataset size: 1000
# Epoch 2600/4000, Loss: 0.0232, Dataset size: 1000
# Epoch 2650/4000, Loss: 0.0229, Dataset size: 1000
# Epoch 2700/4000, Loss: 0.0225, Dataset size: 1000
# Epoch 2750/4000, Loss: 0.0222, Dataset size: 1000
# Epoch 2800/4000, Loss: 0.0219, Dataset size: 1000
# Epoch 2850/4000, Loss: 0.0217, Dataset size: 1000
# Epoch 2900/4000, Loss: 0.0244, Dataset size: 1000
# Epoch 2950/4000, Loss: 0.0209, Dataset size: 1000
# Epoch 3000/4000, Loss: 0.0206, Dataset size: 1000
#   [Epoch 3000] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 1000 → 1100 (+100 unique)
# Epoch 3050/4000, Loss: 0.0186, Dataset size: 1100
# Epoch 3100/4000, Loss: 0.0185, Dataset size: 1100
# Epoch 3150/4000, Loss: 0.0185, Dataset size: 1100
# Epoch 3200/4000, Loss: 0.0185, Dataset size: 1100
# Epoch 3250/4000, Loss: 0.0185, Dataset size: 1100
# Epoch 3300/4000, Loss: 0.0182, Dataset size: 1100
# Epoch 3350/4000, Loss: 0.0180, Dataset size: 1100
# Epoch 3400/4000, Loss: 0.0180, Dataset size: 1100
# Epoch 3450/4000, Loss: 0.0179, Dataset size: 1100
# Epoch 3500/4000, Loss: 0.0179, Dataset size: 1100
# Epoch 3550/4000, Loss: 0.0179, Dataset size: 1100
# Epoch 3600/4000, Loss: 0.0181, Dataset size: 1100
# Epoch 3650/4000, Loss: 0.0175, Dataset size: 1100
# Epoch 3700/4000, Loss: 0.0177, Dataset size: 1100
# Epoch 3750/4000, Loss: 0.0173, Dataset size: 1100
# Epoch 3800/4000, Loss: 0.0172, Dataset size: 1100
# Epoch 3850/4000, Loss: 0.0203, Dataset size: 1100
# Epoch 3900/4000, Loss: 0.0202, Dataset size: 1100
# Epoch 3950/4000, Loss: 0.0199, Dataset size: 1100
# Epoch 0/4000, Loss: 0.0169, Dataset size: 1100
# Epoch 50/4000, Loss: 0.0168, Dataset size: 1100
# Epoch 100/4000, Loss: 0.0167, Dataset size: 1100
# Epoch 150/4000, Loss: 0.0166, Dataset size: 1100
# Epoch 200/4000, Loss: 0.0165, Dataset size: 1100
# Epoch 250/4000, Loss: 0.0166, Dataset size: 1100
# Epoch 300/4000, Loss: 0.0162, Dataset size: 1100
# Epoch 350/4000, Loss: 0.0161, Dataset size: 1100
# Epoch 400/4000, Loss: 0.0160, Dataset size: 1100
# Epoch 450/4000, Loss: 0.0159, Dataset size: 1100
# Epoch 500/4000, Loss: 0.0158, Dataset size: 1100
# Epoch 550/4000, Loss: 0.0156, Dataset size: 1100
# Epoch 600/4000, Loss: 0.0155, Dataset size: 1100
# Epoch 650/4000, Loss: 0.0154, Dataset size: 1100
# Epoch 700/4000, Loss: 0.0161, Dataset size: 1100
# Epoch 750/4000, Loss: 0.0388, Dataset size: 1100
# Epoch 800/4000, Loss: 0.0149, Dataset size: 1100
# Epoch 850/4000, Loss: 0.0147, Dataset size: 1100
# Epoch 900/4000, Loss: 0.0146, Dataset size: 1100
# Epoch 950/4000, Loss: 0.0144, Dataset size: 1100
# Epoch 1000/4000, Loss: 0.0145, Dataset size: 1100
# Epoch 1050/4000, Loss: 0.0141, Dataset size: 1100
# Epoch 1100/4000, Loss: 0.0138, Dataset size: 1100
# Epoch 1150/4000, Loss: 0.0138, Dataset size: 1100
# Epoch 1200/4000, Loss: 0.0136, Dataset size: 1100
# Epoch 1250/4000, Loss: 0.0134, Dataset size: 1100
# Epoch 1300/4000, Loss: 0.0131, Dataset size: 1100
# Epoch 1350/4000, Loss: 0.0134, Dataset size: 1100
# Epoch 1400/4000, Loss: 0.0127, Dataset size: 1100
# Epoch 1450/4000, Loss: 0.0128, Dataset size: 1100
# Epoch 1500/4000, Loss: 0.0135, Dataset size: 1100
#   [Epoch 1500] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 1100 → 1199 (+99 unique)
# Epoch 1550/4000, Loss: 0.0114, Dataset size: 1199
# Epoch 1600/4000, Loss: 0.0113, Dataset size: 1199
# Epoch 1650/4000, Loss: 0.0113, Dataset size: 1199
# Epoch 1700/4000, Loss: 0.0112, Dataset size: 1199
# Epoch 1750/4000, Loss: 0.0111, Dataset size: 1199
# Epoch 1800/4000, Loss: 0.0109, Dataset size: 1199
# Epoch 1850/4000, Loss: 0.0108, Dataset size: 1199
# Epoch 1900/4000, Loss: 0.0106, Dataset size: 1199
# Epoch 1950/4000, Loss: 0.0105, Dataset size: 1199
# Epoch 2000/4000, Loss: 0.0104, Dataset size: 1199
# Epoch 2050/4000, Loss: 0.0480, Dataset size: 1199
# Epoch 2100/4000, Loss: 0.0102, Dataset size: 1199
# Epoch 2150/4000, Loss: 0.0185, Dataset size: 1199
# Epoch 2200/4000, Loss: 0.0100, Dataset size: 1199
# Epoch 2250/4000, Loss: 0.0100, Dataset size: 1199
# Epoch 2300/4000, Loss: 0.0099, Dataset size: 1199
# Epoch 2350/4000, Loss: 0.0098, Dataset size: 1199
# Epoch 2400/4000, Loss: 0.0097, Dataset size: 1199
# Epoch 2450/4000, Loss: 0.0096, Dataset size: 1199
# Epoch 2500/4000, Loss: 0.0095, Dataset size: 1199
# Epoch 2550/4000, Loss: 0.0094, Dataset size: 1199
# Epoch 2600/4000, Loss: 0.0092, Dataset size: 1199
# Epoch 2650/4000, Loss: 0.0092, Dataset size: 1199
# Epoch 2700/4000, Loss: 0.0091, Dataset size: 1199
# Epoch 2750/4000, Loss: 0.0091, Dataset size: 1199
# Epoch 2800/4000, Loss: 0.0089, Dataset size: 1199
# Epoch 2850/4000, Loss: 0.0088, Dataset size: 1199
# Epoch 2900/4000, Loss: 0.0087, Dataset size: 1199
# Epoch 2950/4000, Loss: 0.0085, Dataset size: 1199
# Epoch 3000/4000, Loss: 0.0084, Dataset size: 1199
#   [Epoch 3000] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 1199 → 1298 (+99 unique)
# Epoch 3050/4000, Loss: 0.0077, Dataset size: 1298
# Epoch 3100/4000, Loss: 0.0076, Dataset size: 1298
# Epoch 3150/4000, Loss: 0.0076, Dataset size: 1298
# Epoch 3200/4000, Loss: 0.0075, Dataset size: 1298
# Epoch 3250/4000, Loss: 0.0077, Dataset size: 1298
# Epoch 3300/4000, Loss: 0.0073, Dataset size: 1298
# Epoch 3350/4000, Loss: 0.0073, Dataset size: 1298
# Epoch 3400/4000, Loss: 0.0072, Dataset size: 1298
# Epoch 3450/4000, Loss: 0.0071, Dataset size: 1298
# Epoch 3500/4000, Loss: 0.0069, Dataset size: 1298
# Epoch 3550/4000, Loss: 0.0069, Dataset size: 1298
# Epoch 3600/4000, Loss: 0.0067, Dataset size: 1298
# Epoch 3650/4000, Loss: 0.0066, Dataset size: 1298
# Epoch 3700/4000, Loss: 0.0065, Dataset size: 1298
# Epoch 3750/4000, Loss: 0.0064, Dataset size: 1298
# Epoch 3800/4000, Loss: 0.0063, Dataset size: 1298
# Epoch 3850/4000, Loss: 0.0090, Dataset size: 1298
# Epoch 3900/4000, Loss: 0.0061, Dataset size: 1298
# Epoch 3950/4000, Loss: 0.0060, Dataset size: 1298
# Epoch 0/4000, Loss: 0.0059, Dataset size: 1298
# Epoch 50/4000, Loss: 0.0058, Dataset size: 1298
# Epoch 100/4000, Loss: 0.0058, Dataset size: 1298
# Epoch 150/4000, Loss: 0.0057, Dataset size: 1298
# Epoch 200/4000, Loss: 0.0083, Dataset size: 1298
# Epoch 250/4000, Loss: 0.0056, Dataset size: 1298
# Epoch 300/4000, Loss: 0.0056, Dataset size: 1298
# Epoch 350/4000, Loss: 0.0055, Dataset size: 1298
# Epoch 400/4000, Loss: 0.0054, Dataset size: 1298
# Epoch 450/4000, Loss: 0.0054, Dataset size: 1298
# Epoch 500/4000, Loss: 0.0055, Dataset size: 1298
# Epoch 550/4000, Loss: 0.0054, Dataset size: 1298
# Epoch 600/4000, Loss: 0.0053, Dataset size: 1298
# Epoch 650/4000, Loss: 0.0053, Dataset size: 1298
# Epoch 700/4000, Loss: 0.0052, Dataset size: 1298
# Epoch 750/4000, Loss: 0.0054, Dataset size: 1298
# Epoch 800/4000, Loss: 0.0052, Dataset size: 1298
# Epoch 850/4000, Loss: 0.0051, Dataset size: 1298
# Epoch 900/4000, Loss: 0.0050, Dataset size: 1298
# Epoch 950/4000, Loss: 0.0050, Dataset size: 1298
# Epoch 1000/4000, Loss: 0.0052, Dataset size: 1298
# Epoch 1050/4000, Loss: 0.0049, Dataset size: 1298
# Epoch 1100/4000, Loss: 0.0048, Dataset size: 1298
# Epoch 1150/4000, Loss: 0.0048, Dataset size: 1298
# Epoch 1200/4000, Loss: 0.0048, Dataset size: 1298
# Epoch 1250/4000, Loss: 0.0047, Dataset size: 1298
# Epoch 1300/4000, Loss: 0.0048, Dataset size: 1298
# Epoch 1350/4000, Loss: 0.0049, Dataset size: 1298
# Epoch 1400/4000, Loss: 0.0047, Dataset size: 1298
# Epoch 1450/4000, Loss: 0.0046, Dataset size: 1298
# Epoch 1500/4000, Loss: 0.0046, Dataset size: 1298
#   [Epoch 1500] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 1298 → 1397 (+99 unique)
# Epoch 1550/4000, Loss: 0.0043, Dataset size: 1397
# Epoch 1600/4000, Loss: 0.0042, Dataset size: 1397
# Epoch 1650/4000, Loss: 0.0043, Dataset size: 1397
# Epoch 1700/4000, Loss: 0.0042, Dataset size: 1397
# Epoch 1750/4000, Loss: 0.0041, Dataset size: 1397
# Epoch 1800/4000, Loss: 0.0042, Dataset size: 1397
# Epoch 1850/4000, Loss: 0.0041, Dataset size: 1397
# Epoch 1900/4000, Loss: 0.0040, Dataset size: 1397
# Epoch 1950/4000, Loss: 0.0040, Dataset size: 1397
# Epoch 2000/4000, Loss: 0.0039, Dataset size: 1397
# Epoch 2050/4000, Loss: 0.0039, Dataset size: 1397
# Epoch 2100/4000, Loss: 0.0038, Dataset size: 1397
# Epoch 2150/4000, Loss: 0.0038, Dataset size: 1397
# Epoch 2200/4000, Loss: 0.0037, Dataset size: 1397
# Epoch 2250/4000, Loss: 0.0036, Dataset size: 1397
# Epoch 2300/4000, Loss: 0.0036, Dataset size: 1397
# Epoch 2350/4000, Loss: 0.0047, Dataset size: 1397
# Epoch 2400/4000, Loss: 0.0036, Dataset size: 1397
# Epoch 2450/4000, Loss: 0.0035, Dataset size: 1397
# Epoch 2500/4000, Loss: 0.0035, Dataset size: 1397
# Epoch 2550/4000, Loss: 0.0034, Dataset size: 1397
# Epoch 2600/4000, Loss: 0.0034, Dataset size: 1397
# Epoch 2650/4000, Loss: 0.0034, Dataset size: 1397
# Epoch 2700/4000, Loss: 0.0034, Dataset size: 1397
# Epoch 2750/4000, Loss: 0.0034, Dataset size: 1397
# Epoch 2800/4000, Loss: 0.0042, Dataset size: 1397
# Epoch 2850/4000, Loss: 0.0033, Dataset size: 1397
# Epoch 2900/4000, Loss: 0.0033, Dataset size: 1397
# Epoch 2950/4000, Loss: 0.0033, Dataset size: 1397
# Epoch 3000/4000, Loss: 0.0033, Dataset size: 1397
#   [Epoch 3000] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 1397 → 1488 (+91 unique)
# Epoch 3050/4000, Loss: 0.0031, Dataset size: 1488
# Epoch 3100/4000, Loss: 0.0030, Dataset size: 1488
# Epoch 3150/4000, Loss: 0.0030, Dataset size: 1488
# Epoch 3200/4000, Loss: 0.0031, Dataset size: 1488
# Epoch 3250/4000, Loss: 0.0030, Dataset size: 1488
# Epoch 3300/4000, Loss: 0.0029, Dataset size: 1488
# Epoch 3350/4000, Loss: 0.0029, Dataset size: 1488
# Epoch 3400/4000, Loss: 0.0029, Dataset size: 1488
# Epoch 3450/4000, Loss: 0.0029, Dataset size: 1488
# Epoch 3500/4000, Loss: 0.0028, Dataset size: 1488
# Epoch 3550/4000, Loss: 0.0029, Dataset size: 1488
# Epoch 3600/4000, Loss: 0.0028, Dataset size: 1488
# Epoch 3650/4000, Loss: 0.0028, Dataset size: 1488
# Epoch 3700/4000, Loss: 0.0028, Dataset size: 1488
# Epoch 3750/4000, Loss: 0.0027, Dataset size: 1488
# Epoch 3800/4000, Loss: 0.0027, Dataset size: 1488
# Epoch 3850/4000, Loss: 0.0028, Dataset size: 1488
# Epoch 3900/4000, Loss: 0.0026, Dataset size: 1488
# Epoch 3950/4000, Loss: 0.0026, Dataset size: 1488
# Epoch 0/4000, Loss: 0.0027, Dataset size: 1488
# Epoch 50/4000, Loss: 0.0027, Dataset size: 1488
# Epoch 100/4000, Loss: 0.0025, Dataset size: 1488
# Epoch 150/4000, Loss: 0.0024, Dataset size: 1488
# Epoch 200/4000, Loss: 0.0024, Dataset size: 1488
# Epoch 250/4000, Loss: 0.0024, Dataset size: 1488
# Epoch 300/4000, Loss: 0.0024, Dataset size: 1488
# Epoch 350/4000, Loss: 0.0023, Dataset size: 1488
# Epoch 400/4000, Loss: 0.0023, Dataset size: 1488
# Epoch 450/4000, Loss: 0.0023, Dataset size: 1488
# Epoch 500/4000, Loss: 0.0026, Dataset size: 1488
# Epoch 550/4000, Loss: 0.0022, Dataset size: 1488
# Epoch 600/4000, Loss: 0.0022, Dataset size: 1488
# Epoch 650/4000, Loss: 0.0021, Dataset size: 1488
# Epoch 700/4000, Loss: 0.0026, Dataset size: 1488
# Epoch 750/4000, Loss: 0.0021, Dataset size: 1488
# Epoch 800/4000, Loss: 0.0021, Dataset size: 1488
# Epoch 850/4000, Loss: 0.0021, Dataset size: 1488
# Epoch 900/4000, Loss: 0.0020, Dataset size: 1488
# Epoch 950/4000, Loss: 0.0020, Dataset size: 1488
# Epoch 1000/4000, Loss: 0.0021, Dataset size: 1488
# Epoch 1050/4000, Loss: 0.0312, Dataset size: 1488
# Epoch 1100/4000, Loss: 0.0020, Dataset size: 1488
# Epoch 1150/4000, Loss: 0.0019, Dataset size: 1488
# Epoch 1200/4000, Loss: 0.0019, Dataset size: 1488
# Epoch 1250/4000, Loss: 0.0018, Dataset size: 1488
# Epoch 1300/4000, Loss: 0.0018, Dataset size: 1488
# Epoch 1350/4000, Loss: 0.0019, Dataset size: 1488
# Epoch 1400/4000, Loss: 0.0018, Dataset size: 1488
# Epoch 1450/4000, Loss: 0.0022, Dataset size: 1488
# Epoch 1500/4000, Loss: 0.0018, Dataset size: 1488
#   [Epoch 1500] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 1488 → 1588 (+100 unique)
# Epoch 1550/4000, Loss: 0.0019, Dataset size: 1588
# Epoch 1600/4000, Loss: 0.0019, Dataset size: 1588
# Epoch 1650/4000, Loss: 0.0017, Dataset size: 1588
# Epoch 1700/4000, Loss: 0.0016, Dataset size: 1588
# Epoch 1750/4000, Loss: 0.0019, Dataset size: 1588
# Epoch 1800/4000, Loss: 0.0017, Dataset size: 1588
# Epoch 1850/4000, Loss: 0.0018, Dataset size: 1588
# Epoch 1900/4000, Loss: 0.0016, Dataset size: 1588
# Epoch 1950/4000, Loss: 0.0016, Dataset size: 1588
# Epoch 2000/4000, Loss: 0.0016, Dataset size: 1588
# Epoch 2050/4000, Loss: 0.0016, Dataset size: 1588
# Epoch 2100/4000, Loss: 0.0016, Dataset size: 1588
# Epoch 2150/4000, Loss: 0.0025, Dataset size: 1588
# Epoch 2200/4000, Loss: 0.0018, Dataset size: 1588
# Epoch 2250/4000, Loss: 0.0016, Dataset size: 1588
# Epoch 2300/4000, Loss: 0.0018, Dataset size: 1588
# Epoch 2350/4000, Loss: 0.0016, Dataset size: 1588
# Epoch 2400/4000, Loss: 0.0015, Dataset size: 1588
# Epoch 2450/4000, Loss: 0.0015, Dataset size: 1588
# Epoch 2500/4000, Loss: 0.0016, Dataset size: 1588
# Epoch 2550/4000, Loss: 0.0015, Dataset size: 1588
# Epoch 2600/4000, Loss: 0.1063, Dataset size: 1588
# Epoch 2650/4000, Loss: 0.0019, Dataset size: 1588
# Epoch 2700/4000, Loss: 0.0015, Dataset size: 1588
# Epoch 2750/4000, Loss: 0.0015, Dataset size: 1588
# Epoch 2800/4000, Loss: 0.0017, Dataset size: 1588
# Epoch 2850/4000, Loss: 0.0015, Dataset size: 1588
# Epoch 2900/4000, Loss: 0.0014, Dataset size: 1588
# Epoch 2950/4000, Loss: 0.0014, Dataset size: 1588
# Epoch 3000/4000, Loss: 0.0014, Dataset size: 1588
#   [Epoch 3000] Checking SMT constraints...
#  Counterexample found! Adding 100 new points...
#   Dataset size: 1588 → 1594 (+6 unique)
# Epoch 3050/4000, Loss: 0.0014, Dataset size: 1594
# Epoch 3100/4000, Loss: 0.0013, Dataset size: 1594
# Epoch 3150/4000, Loss: 0.0013, Dataset size: 1594
# Epoch 3200/4000, Loss: 0.0013, Dataset size: 1594
# Epoch 3250/4000, Loss: 0.0014, Dataset size: 1594
# Epoch 3300/4000, Loss: 0.0024, Dataset size: 1594
# Epoch 3350/4000, Loss: 0.0014, Dataset size: 1594
# Epoch 3400/4000, Loss: 0.0012, Dataset size: 1594
# Epoch 3450/4000, Loss: 0.0012, Dataset size: 1594
# Epoch 3500/4000, Loss: 0.0012, Dataset size: 1594
# Epoch 3550/4000, Loss: 0.0012, Dataset size: 1594
# Epoch 3600/4000, Loss: 0.0012, Dataset size: 1594
# Epoch 3650/4000, Loss: 0.0012, Dataset size: 1594
# Epoch 3700/4000, Loss: 0.0011, Dataset size: 1594
# Epoch 3750/4000, Loss: 0.0012, Dataset size: 1594
# Epoch 3800/4000, Loss: 0.0011, Dataset size: 1594
# Epoch 3850/4000, Loss: 0.0011, Dataset size: 1594
# Epoch 3900/4000, Loss: 0.0015, Dataset size: 1594
# Epoch 3950/4000, Loss: 0.0011, Dataset size: 1594
# Epoch 0/4000, Loss: 0.0011, Dataset size: 1594
# Epoch 50/4000, Loss: 0.0010, Dataset size: 1594
# Epoch 100/4000, Loss: 0.0010, Dataset size: 1594
# Epoch 150/4000, Loss: 0.0010, Dataset size: 1594
# Epoch 200/4000, Loss: 0.0010, Dataset size: 1594
# Epoch 250/4000, Loss: 0.0010, Dataset size: 1594
# Epoch 300/4000, Loss: 0.0009, Dataset size: 1594
# Epoch 350/4000, Loss: 0.0009, Dataset size: 1594
# Epoch 400/4000, Loss: 0.0010, Dataset size: 1594
# Epoch 450/4000, Loss: 0.0009, Dataset size: 1594
# Epoch 500/4000, Loss: 0.0009, Dataset size: 1594
# Epoch 550/4000, Loss: 0.0009, Dataset size: 1594
# Epoch 600/4000, Loss: 0.0008, Dataset size: 1594
# Epoch 650/4000, Loss: 0.0008, Dataset size: 1594
# Epoch 700/4000, Loss: 0.0007, Dataset size: 1594
# Epoch 750/4000, Loss: 0.0007, Dataset size: 1594
# Epoch 800/4000, Loss: 0.0014, Dataset size: 1594
# Epoch 850/4000, Loss: 0.0008, Dataset size: 1594
# Epoch 900/4000, Loss: 0.0006, Dataset size: 1594
# Epoch 950/4000, Loss: 0.0006, Dataset size: 1594
# Epoch 1000/4000, Loss: 0.0006, Dataset size: 1594
# Epoch 1050/4000, Loss: 0.0006, Dataset size: 1594
# Epoch 1100/4000, Loss: 0.0005, Dataset size: 1594
# Epoch 1150/4000, Loss: 0.0005, Dataset size: 1594
#   [Epoch 1180] Loss reached zero!
#
# Training completed!
# Final Loss: 0.0005
# The learned margin is 0.000000
# Final dataset size: 1594
#
# Plotting loss curve for new controller...

# %%
# Visualize density
print("\nGenerating density visualization...")
grid_size = 100
x1 = torch.linspace(-6, 6, grid_size)
x2 = torch.linspace(-6, 6, grid_size)
x1_grid, x2_grid = torch.meshgrid(x1, x2, indexing='ij')
grid_points = torch.stack([x1_grid.ravel(), x2_grid.ravel()], dim=1).to(device)

with torch.no_grad():
    rho_set = a_ret1(grid_points) / (torch.exp(
        torch.sum(grid_points**2, dim=1, keepdim=True) + 
        torch.sum((b_ret1(grid_points))**2, dim=1, keepdim=True)
    ))

violations_set = rho_set.detach().cpu().numpy().reshape(grid_size, grid_size)

plt.figure(figsize=(8, 6))
plt.imshow(violations_set, extent=[-6, 6, -6, 6], origin='lower',
            cmap='coolwarm', aspect='auto')
plt.colorbar(label="density values (should be positive)")
plt.xlabel("x1 (angle)")
plt.ylabel("x2 (angular velocity)")
plt.title("Density Visualization")
circle = patches.Circle((0, 0), 6, color='black', fill=False, 
                        linewidth=2, label="$||x||^2 \\leq 6$")
plt.gca().add_patch(circle)
plt.legend(loc='upper right')
plt.grid(False)
plt.show()
# Out:
# Generating density visualization...

# %%
    # Visualize divergence/violations
    print("\nGenerating divergence visualization...")
    # Note: control_density_risk_vectorized needs gradients, so we don't use no_grad here
    divergence_set = control_density_risk_vectorized(grid_points, f, g, a_ret1, b_ret1, c_ret1)
    
    violations_set = torch.where(divergence_set <= 0, 1, -1)
    violations_set = violations_set.detach().cpu().numpy().reshape(grid_size, grid_size)
    
    plt.figure(figsize=(8, 6))
    plt.imshow(violations_set, extent=[-6, 6, -6, 6], origin='lower',
               cmap='coolwarm', aspect='auto')
    plt.colorbar(label="1 indicates violations, -1 indicates satisfactions")
    plt.xlabel("x1 (angle)")
    plt.ylabel("x2 (angular velocity)")
    plt.title("Violations Set Visualization")
    circle = patches.Circle((0, 0), 6, color='black', fill=False, 
                            linewidth=2, label="$||x||^2 \\leq 6$")
    plt.gca().add_patch(circle)
    plt.legend(loc='upper right')
    plt.grid(False)
    plt.show()
# Out:
# Generating divergence visualization...

# %%
print("\nPlotting density contours with flow field for new controller...")
plot_density_contours(a_net1, b_net1, c_net1,5e-8, device, plot_flow=True)
print("\n" + "=" * 60)
# Out:
# Plotting density contours with flow field for new controller...
# /tmp/ipykernel_780269/2736553463.py:33: UserWarning: The following kwargs were not used by contour: 'label'
#   ax.contour(X,Y,rho_set-density_threshold,levels=1,colors='black', linewidths=2,linestyles='solid', label='Density')
# ============================================================

# %%
# save the models
torch.save(a_ret1.state_dict(), 'inverted_pendulum_a_net1.pth')
torch.save(b_ret1.state_dict(), 'inverted_pendulum_b_net1.pth')
torch.save(c_ret1.state_dict(), 'inverted_pendulum_c_net1.pth')

# %%
INPUT_DIM = 2
HIDDEN_DIM_A = 3
HIDDEN_DIM_B = 3
HIDDEN_DIM_C = 12
OUTPUT_DIM_B = 2

# LOAD THE MODELS
a_net = numerator_polynomial_net(INPUT_DIM, HIDDEN_DIM_A, 1).to(device)
a_net.load_state_dict(torch.load('Model_Paths/inverted_pendulum_a_net.pth', map_location=device))
b_net = polynomial_net_bias_Zero(INPUT_DIM, HIDDEN_DIM_B, OUTPUT_DIM_B).to(device)
b_net.load_state_dict(torch.load('Model_Paths/inverted_pendulum_b_net.pth', map_location=device))
c_net = polynomial_net(INPUT_DIM, HIDDEN_DIM_C, 1).to(device)
c_net.load_state_dict(torch.load('Model_Paths/inverted_pendulum_c_net.pth', map_location=device))

a_net1 = numerator_polynomial_net(INPUT_DIM, HIDDEN_DIM_A, 1).to(device)
a_net1.load_state_dict(torch.load('Model_Paths/inverted_pendulum_a_net1.pth', map_location=device))
b_net1 = polynomial_net_bias_Zero(INPUT_DIM, HIDDEN_DIM_B, OUTPUT_DIM_B).to(device)
b_net1.load_state_dict(torch.load('Model_Paths/inverted_pendulum_b_net1.pth', map_location=device))
c_net1 = polynomial_net(INPUT_DIM, HIDDEN_DIM_C, 1).to(device)
c_net1.load_state_dict(torch.load('Model_Paths/inverted_pendulum_c_net1.pth', map_location=device))

print("Models loaded successfully.")
a_net.eval()
b_net.eval()
c_net.eval()
a_net1.eval()
b_net1.eval()
c_net1.eval()
# Out:
# Models loaded successfully.
# /tmp/ipykernel_3764329/1582713909.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   a_net.load_state_dict(torch.load('Model_Paths/inverted_pendulum_a_net.pth', map_location=device))
# /tmp/ipykernel_3764329/1582713909.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   b_net.load_state_dict(torch.load('Model_Paths/inverted_pendulum_b_net.pth', map_location=device))
# /tmp/ipykernel_3764329/1582713909.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   c_net.load_state_dict(torch.load('Model_Paths/inverted_pendulum_c_net.pth', map_location=device))
# /tmp/ipykernel_3764329/1582713909.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   a_net1.load_state_dict(torch.load('Model_Paths/inverted_pendulum_a_net1.pth', map_location=device))
# /tmp/ipykernel_3764329/1582713909.py:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   b_net1.load_state_dict(torch.load('Model_Paths/inverted_pendulum_b_net1.pth', map_location=device))
# /tmp/ipykernel_3764329/1582713909.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   c_net1.load_state_dict(torch.load('Model_Paths/inverted_pendulum_c_net1.pth', map_location=device))
# polynomial_net(
#   (net): Sequential(
#     (0): Linear(in_features=2, out_features=12, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=12, out_features=1, bias=True)
#   )
# )

# %%
def plot_density_countours(a_nn, b_nn, c_nn,density_threshold, device, plot_flow=True):
    # create meshgrid
    x1 = torch.linspace(-6, 6, 100)
    x2 = torch.linspace(-6, 6, 100)
    X, Y = np.meshgrid(x1,x2)

    # Convert to torch tensor
    grid_points = torch.tensor(np.column_stack([X.ravel(), Y.ravel()]), dtype=torch.float32).to(device)

    # compute the modified density function
    with torch.no_grad():
        rho_set = a_nn(grid_points) / (torch.exp( torch.sum(grid_points**2, dim=1, keepdim=True) + torch.sum((b_nn(grid_points))**2, dim=1, keepdim=True)))
        rho_set = rho_set.squeeze()
        rho_set = rho_set.cpu().numpy().reshape(X.shape)
    # plot the density function
    fig, ax = plt.subplots(figsize=(8, 6))
    # contours = ax.contour(X, Y, rho_set, levels=10, colors='k')

    ax.contour(X,Y,rho_set-density_threshold,levels=0,colors='black', linewidths=2,linestyles='solid', label='Mixed Density')

    filled_contours = ax.contourf(X, Y, rho_set, levels=10, alpha=0.3, cmap=cm.coolwarm)
    plt.colorbar(filled_contours, label='Density Value')

    if plot_flow:
        # create coarser grid for flow field
        x1_flow = np.linspace(-6, 6, 20)
        x2_flow = np.linspace(-6, 6, 20)
        X_flow, Y_flow = np.meshgrid(x1_flow, x2_flow)
        flow_points = torch.tensor(np.column_stack([X_flow.ravel(), Y_flow.ravel()]), dtype=torch.float32).to(device)

        # evaluate control policy u
        with torch.no_grad():
            u_values = c_nn(flow_points) / a_nn(flow_points)
               
        # Calculate vector field
        DX = np.zeros_like(X_flow)
        DY = np.zeros_like(Y_flow)
        
        for i in range(len(x1_flow)):
            for j in range(len(x2_flow)):
                idx = i * len(x1_flow) + j
                x = torch.tensor([X_flow[i, j], Y_flow[i, j]], device=device)
                f_val = f(x)
                g_val = g(x)
                u = u_values[idx]
                
                # Compute flow: f(x) + g(x)u
                flow = f_val + g_val * u
                DX[i, j] = flow[0].cpu().numpy()
                DY[i, j] = flow[1].cpu().numpy()
        
        # Normalize vectors for better visualization
        magnitude = np.sqrt(DX**2 + DY**2)
        DX = DX / magnitude
        DY = DY / magnitude
        
        # Plot flow field
        ax.streamplot(X_flow, Y_flow, DX, DY, color='gray', linewidth=0.5,
                     density=1.0, arrowstyle='-|>', arrowsize=1.5)
    
    # Add valid region circle
    circle = plt.Circle((0, 0), 6, color='r', fill=False, linewidth=1.5, label='Valid Region')
    ax.add_artist(circle)
    
    # Customize plot
    ax.set_xlabel('Angle', fontsize=12)
    ax.set_ylabel('Angular velocity', fontsize=12)
    ax.set_title('Inverted Pendulum', fontsize=10, fontweight='bold')
    from matplotlib.lines import Line2D
    legend_elements = [
        Line2D([0], [0], color='black', linewidth=2, linestyle='-', label='RoA due to learned density'),
        Line2D([0], [0], color='red', linewidth=2, linestyle='--', label='Valid Region')
    ]
    ax.legend(handles=legend_elements, loc='upper right', fontsize=11)
    
    
    
    plt.show()
    
    return fig, ax

# Call the function to plot density contours and flow field
plot_density_countours(a_net, b_net, c_net,5e-8, device, plot_flow=True)


# Call the function to plot density contours and flow field
plot_density_countours(a_net1, b_net1, c_net1,5e-8, device, plot_flow=True)
# Out:
# /tmp/ipykernel_3764329/328148718.py:19: UserWarning: The following kwargs were not used by contour: 'label'
#   ax.contour(X,Y,rho_set-density_threshold,levels=0,colors='black', linewidths=2,linestyles='solid', label='Mixed Density')
# (<Figure size 800x600 with 2 Axes>,
#  <Axes: title={'center': 'Inverted Pendulum'}, xlabel='Angle', ylabel='Angular velocity'>)

# %%
def plot_mixed_density_countours(a_nn, b_nn, c_nn,a_nn1,b_nn1,c_nn1, density_threshold, device, plot_flow=True):
    # create meshgrid
    x1 = torch.linspace(-6, 6, 100)
    x2 = torch.linspace(-6, 6, 100)
    X, Y = np.meshgrid(x1,x2)

    # Convert to torch tensor
    grid_points = torch.tensor(np.column_stack([X.ravel(), Y.ravel()]), dtype=torch.float32).to(device)

    # compute the modified density function
    with torch.no_grad():
        rho_set1 = a_nn(grid_points) / (torch.exp( torch.sum(grid_points**2, dim=1, keepdim=True) + torch.sum((b_nn(grid_points))**2, dim=1, keepdim=True)))
        rho_set2 = a_nn1(grid_points) / (torch.exp( torch.sum(grid_points**2, dim=1, keepdim=True) + torch.sum((b_nn1(grid_points))**2, dim=1, keepdim=True)))
        rho_set =  rho_set1+rho_set2
        rho_set = rho_set.squeeze()
        rho_set = rho_set.cpu().numpy().reshape(X.shape)
    # plot the density function
    fig, ax = plt.subplots(figsize=(8, 6))
    
    ax.contour(X,Y,rho_set-density_threshold,levels=0,colors='black', linewidths=2,linestyles='solid', label='Mixed Density')
    filled_contours = ax.contourf(X, Y, rho_set, levels=20, alpha=0.3, cmap=cm.coolwarm)
    plt.colorbar(filled_contours, label='Density Value')

    if plot_flow:
        # create coarser grid for flow field
        x1_flow = np.linspace(-6, 6, 20)
        x2_flow = np.linspace(-6, 6, 20)
        X_flow, Y_flow = np.meshgrid(x1_flow, x2_flow)
        flow_points = torch.tensor(np.column_stack([X_flow.ravel(), Y_flow.ravel()]), dtype=torch.float32).to(device)

        # evaluate control policy u
        with torch.no_grad():
            rho_set1 = a_nn(flow_points) / (torch.exp( torch.sum(flow_points**2, dim=1, keepdim=True) + torch.sum((b_nn(flow_points))**2, dim=1, keepdim=True)))
            rho_set2 = a_nn1(flow_points) / (torch.exp( torch.sum(flow_points**2, dim=1, keepdim=True) + torch.sum((b_nn1(flow_points))**2, dim=1, keepdim=True)))
            u_values1 = c_nn(flow_points) / a_nn(flow_points)
            u_values2 = c_nn1(flow_points) / a_nn1(flow_points)
            weight1 = rho_set1 / (rho_set1+rho_set2)
            weight2 = rho_set2 / (rho_set1+rho_set2)
            u_values = weight1 * u_values1 + weight2 * u_values2
               
        # Calculate vector field
        DX = np.zeros_like(X_flow)
        DY = np.zeros_like(Y_flow)
        
        for i in range(len(x1_flow)):
            for j in range(len(x2_flow)):
                idx = i * len(x1_flow) + j
                x = torch.tensor([X_flow[i, j], Y_flow[i, j]], device=device)
                f_val = f(x)
                g_val = g(x)
                u = u_values[idx]
                
                # Compute flow: f(x) + g(x)u
                flow = f_val + g_val * u
                DX[i, j] = flow[0].cpu().numpy()
                DY[i, j] = flow[1].cpu().numpy()
        
        # Normalize vectors for better visualization
        magnitude = np.sqrt(DX**2 + DY**2)
        DX = DX / magnitude
        DY = DY / magnitude
        
        # Plot flow field
        ax.streamplot(X_flow, Y_flow, DX, DY, color='gray', linewidth=0.5,
                     density=1.0, arrowstyle='<|-', arrowsize=1.5)
    
    # Add valid region circle
    circle = plt.Circle((0, 0), 6, color='r', fill=False, linewidth=1.5, label='Valid Region')
    ax.add_artist(circle)
    
    # Customize plot
    ax.set_xlabel('Angle', fontsize=12)
    ax.set_ylabel('Angular velocity', fontsize=12)
    ax.set_title('Inverted Pendulum: Mixed density', fontsize=14, fontweight='bold')
    from matplotlib.lines import Line2D
    legend_elements = [
        Line2D([0], [0], color='black', linewidth=2, linestyle='-', label='RoA due to mixed density'),
        Line2D([0], [0], color='red', linewidth=2, linestyle='--', label='Valid Region')
    ]
    ax.legend(handles=legend_elements, loc='upper right', fontsize=11)
    
    
   
    
    plt.show()
    
    return fig, ax


# Call the function to plot density contours and flow field
plot_mixed_density_countours(a_net, b_net, c_net,a_net1,b_net1,c_net1, 5e-8, device, plot_flow=True)
# Out:
# /tmp/ipykernel_3764329/1594921170.py:20: UserWarning: The following kwargs were not used by contour: 'label'
#   ax.contour(X,Y,rho_set-density_threshold,levels=0,colors='black', linewidths=2,linestyles='solid', label='Mixed Density')
# (<Figure size 800x600 with 2 Axes>,
#  <Axes: title={'center': 'Inverted Pendulum: Mixed density'}, xlabel='Angle', ylabel='Angular velocity'>)

# %% [markdown]
# # get the density from lyapunov,
#
# we will choose $\alpha=2$ for now

# %%
def tanh(x):
    return (exp(x) - exp(-x)) / (exp(x) + exp(-x))

def lyapunov(x):
    # x is assumed to be a tensor of shape [N, 2]
    x1 = x[:, 0]
    x2 = x[:, 1]
    
    # Use torch.torch.tanh for numerical computation
    V = torch.tanh((0.1592191 + 0.6047373* torch.tanh((-1.2250961 - 1.1751087 * x1 + 0.028802002 * x2)) - 0.69419956 * torch.tanh((-0.81576663 + 0.02652748* x1 - 0.00072127824999999998 * x2)) - 1.1177092 * torch.tanh((-0.53083205 + 0.043899357 * x1 - 0.0029811477000000002 * x2)) - 1.1329674000000001 * torch.tanh((0.89248989999999995 - 0.55178492999999995 * x1 - 0.034781724 * x2)) + 0.77995585999999995 * torch.tanh((0.93392560000000002 - 0.0067463684999999997 * x1 - 0.0067418180000000001 * x2)) - 0.26213419999999998 * torch.tanh((1.0895116 + 0.44463265000000002 * x1 + 0.2598702 * x2))))-0.212

    
    # V will have shape [N]
    return V

def get_density(x, alpha):
    # V will be shape [N] from the fixed lyapunov function
    V = lyapunov(x) 
    rho = V ** (-alpha)
    
    # Return shape [N, 1] for consistency with other densities
    return rho.to(device).unsqueeze(1)

def lyapunov_control(x, device):
    # x is shape [N, 2]
    # Define Ku as a torch tensor for efficient computation
    Ku = torch.tensor([-23.586397, -5.314206], device=device, dtype=x.dtype)
    
    # Vectorized calculation using matrix multiplication
    # (x @ Ku) results in shape [N]
    u = torch.matmul(x, Ku) 
    
    # Return shape [N, 1] for consistency with other controllers
    return u.unsqueeze(1)

# %%
def plot_density_and_flow(density_threshold,alpha_val, device, plot_flow=True):
    x1 = torch.linspace(-6, 6, 100)
    x2 = torch.linspace(-6, 6, 100)
    X, Y = np.meshgrid(x1.cpu().numpy(), x2.cpu().numpy())
    grid_points = torch.tensor(np.column_stack([X.ravel(), Y.ravel()]), 
                               dtype=torch.float32).to(device)
    
    with torch.no_grad():
        rho_set = get_density(grid_points, alpha=alpha_val)
        rho_set = rho_set.squeeze().cpu().numpy().reshape(X.shape)
        
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.contour(X,Y,rho_set-density_threshold,levels=1,colors='black', linewidths=2,linestyles='solid', label='Lyapunov')
    filled_contours = ax.contourf(X, Y, rho_set, levels=10, alpha=0.3, cmap=cm.coolwarm)
    plt.colorbar(filled_contours, label='Density Value')
    
    if plot_flow:
        x1_flow = np.linspace(-6, 6, 20)
        x2_flow = np.linspace(-6, 6, 20)
        X_flow, Y_flow = np.meshgrid(x1_flow, x2_flow)
        flow_points = torch.tensor(np.column_stack([X_flow.ravel(), Y_flow.ravel()]), 
                                   dtype=torch.float32).to(device)
        
        DX = np.zeros_like(X_flow)
        DY = np.zeros_like(Y_flow)
        
        # --- Vectorized Flow Calculation ---
        with torch.no_grad():
            u_values = lyapunov_control(flow_points, device) # [N_flow, 1]
            f_vals = f(flow_points) # [N_flow, 2]
            g_vals = g(flow_points) # [N_flow, 2]
            
            # u_values [N_flow, 1] broadcasts correctly with g_vals [N_flow, 2]
            flow = f_vals + g_vals * u_values 
            
            DX = flow[:, 0].cpu().numpy().reshape(X_flow.shape)
            DY = flow[:, 1].cpu().numpy().reshape(Y_flow.shape)
        # --- End Vectorized ---
            
        # magnitudex = np.sqrt(DX**2)
        # magnitudey = np.sqrt(DY**2 )
        # DX_norm = DX / magnitudex
        # DY_norm = DY / magnitudey
        magnitude = np.sqrt(DX**2 + DY**2) + 1e-9
        DX_norm = DX / magnitude
        DY_norm = DY / magnitude
        
        ax.streamplot(X_flow, Y_flow, DX_norm, DY_norm, color='gray', linewidth=0.5,
                      density=0.5, arrowstyle='-|>', arrowsize=1.5)
                      
    circle = plt.Circle((0, 0), 6, color='r', fill=False, 
                        linewidth=1.5, label='Valid Region')
    ax.add_artist(circle)
    ax.set_xlabel('Angle (rad)')
    ax.set_ylabel('Angular velocity')
    ax.set_title('Lyapunov-based Density Function Contours with Flow Field')
    ax.legend()
    ax.grid(True)
    plt.show()
    return fig, ax

# --- IMPORTANT: Call the function correctly ---
# You need to pass the alpha_val you set earlier
plot_density_and_flow(5e-8, alpha_val=0.1,  device=device, plot_flow=True)
# Out:
# /tmp/ipykernel_3764329/3544275469.py:13: UserWarning: The following kwargs were not used by contour: 'label'
#   ax.contour(X,Y,rho_set-density_threshold,levels=1,colors='black', linewidths=2,linestyles='solid', label='Lyapunov')
# (<Figure size 800x600 with 2 Axes>,
#  <Axes: title={'center': 'Lyapunov-based Density Function Contours with Flow Field'}, xlabel='Angle (rad)', ylabel='Angular velocity'>)

# %%
def plot_mixed_learned_lyapunov_and_Density(a_nn,b_nn,c_nn,a_nn1,b_nn1,c_nn1,density_threshold,alpha_val, device, plot_flow=True):
    """
    Plots the contours of a mixed density (Learned + lyapunov) and 
    the flow field of the corresponding mixed control policy.
    """
    # create meshgrid
    x1 = torch.linspace(-6, 6, 100)
    x2 = torch.linspace(-6, 6, 100)
    X, Y = np.meshgrid(x1.cpu().numpy(), x2.cpu().numpy())
    
    # Convert to torch tensor
    grid_points = torch.tensor(np.column_stack([X.ravel(), Y.ravel()]), dtype=torch.float32).to(device)
    
    # compute the modified density function
    with torch.no_grad():
        rho_set1 = 100 * (a_nn(grid_points)) / (torch.exp( 
            torch.sum(grid_points**2, dim=1, keepdim=True) + 
            torch.sum((b_nn(grid_points))**2, dim=1, keepdim=True) 
        ))
        rho_set2 = 10 * (a_nn1(grid_points)) / (torch.exp( 
            torch.sum(grid_points**2, dim=1, keepdim=True) + 
            torch.sum((b_nn1(grid_points))**2, dim=1, keepdim=True) 
        ))
        # Call the fixed get_density function
        rho_set3 = (1e-16) * get_density(grid_points, alpha_val) 
        
        # All inputs are [N, 1], so this works
        rho_set = rho_set1 + rho_set2 + rho_set3 
        rho_set = rho_set.squeeze().cpu().numpy().reshape(X.shape)
        
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.contour(X,Y,rho_set-density_threshold,levels=0,colors='black', linewidths=2,linestyles='solid', label='Lyapunov')
    filled_contours = ax.contourf(X, Y, rho_set, levels=10, alpha=0.3, cmap=cm.coolwarm)
    plt.colorbar(filled_contours, label='Density Value')

    if plot_flow:
        x1_flow = np.linspace(-6, 6, 20)
        x2_flow = np.linspace(-6, 6, 20)
        X_flow, Y_flow = np.meshgrid(x1_flow, x2_flow)
        flow_points = torch.tensor(np.column_stack([X_flow.ravel(), Y_flow.ravel()]), 
                                   dtype=torch.float32).to(device)
        
        with torch.no_grad():
            # Calculate densities (all [N_flow, 1])
            rho_set1 = 100 * (a_nn(flow_points)) / (torch.exp( 
                torch.sum(flow_points**2, dim=1, keepdim=True) + 
                torch.sum((b_nn(flow_points))**2, dim=1, keepdim=True) 
            ))
            rho_set2 = 10* (a_nn1(flow_points)) / (torch.exp( 
                torch.sum(flow_points**2, dim=1, keepdim=True) + 
                torch.sum((b_nn1(flow_points))**2, dim=1, keepdim=True) 
            ))
            rho_set3 = (1e-16) * get_density(flow_points, alpha_val)
            
            # Calculate controls (all [N_flow, 1])
            u_values1 = c_nn(flow_points) / (a_nn(flow_points) + 1e-9) # Added epsilon
            u_values2 = c_nn1(flow_points) / (a_nn1(flow_points) + 1e-9) # Added epsilon
            u_values3 = lyapunov_control(flow_points, device)
            
            # Calculate weights (all [N_flow, 1])
            rho_total = rho_set1 + rho_set2 + rho_set3 + 1e-9 # Added epsilon
            weight1 =  rho_set1 / rho_total
            weight2 =  rho_set2 / rho_total
            weight3 = rho_set3 / rho_total
            
            # Calculate mixed control (all [N_flow, 1])
            u_values = weight1 * u_values1 + weight2 * u_values2 + weight3 * u_values3

            # --- Vectorized Flow Calculation ---
            f_vals = f(flow_points) # [N_flow, 2]
            g_vals = g(flow_points) # [N_flow, 2]
            
            # u_values [N_flow, 1] broadcasts correctly
            flow = f_vals + g_vals * u_values 
            
            DX = flow[:, 0].cpu().numpy().reshape(X_flow.shape)
            DY = flow[:, 1].cpu().numpy().reshape(Y_flow.shape)
            # --- End Vectorized ---

        magnitude = np.sqrt(DX**2 + DY**2) + 1e-9
        DX_norm = DX / magnitude
        DY_norm = DY / magnitude
        # magnitudex = np.sqrt(DX**2)
        # magnitudey = np.sqrt(DY**2 )
        # DX_norm = DX / magnitudex
        # DY_norm = DY / magnitudey
        
        ax.streamplot(X_flow, Y_flow, DX_norm, DY_norm, color='gray', linewidth=0.5,
                      density=1.0, arrowstyle='-|>', arrowsize=1.5)
                      
    circle = plt.Circle((0, 0), 6, color='r', fill=False,
                        linewidth=1.5, label='Valid Region')
    ax.add_artist(circle)
    ax.set_xlabel('Angle (rad)')
    ax.set_ylabel('Angular velocity')
    ax.set_title('Mixed Learned and Lyapunov-based Density Function Contours with Flow Field')
    ax.legend()
    ax.grid(True)
    plt.show()
    return fig, ax

# %%
plot_mixed_learned_lyapunov_and_Density( a_net,b_net,c_net,a_net1,b_net1,c_net1, 5e-8,alpha_val=0.1, device=device, plot_flow=True)
# Out:
# /tmp/ipykernel_3764329/1762028182.py:32: UserWarning: The following kwargs were not used by contour: 'label'
#   ax.contour(X,Y,rho_set-density_threshold,levels=0,colors='black', linewidths=2,linestyles='solid', label='Lyapunov')
# (<Figure size 800x600 with 2 Axes>,
#  <Axes: title={'center': 'Mixed Learned and Lyapunov-based Density Function Contours with Flow Field'}, xlabel='Angle (rad)', ylabel='Angular velocity'>)

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.patches import Circle


def plot_combined_roa(a_nn, b_nn, c_nn, a_nn1, b_nn1, c_nn1, 
                      device, alpha=0.005, 
                      density_threshold=0.55, 
                      lyapunov_threshold=0.27,
                      plot_flow=True):
    """
    Plot both ROAs on the same plot for direct comparison
    """
    
    # Create meshgrid
    x1 = torch.linspace(-6, 6, 200)
    x2 = torch.linspace(-6, 6, 200)
    X, Y = np.meshgrid(x1, x2)

    grid_points = torch.tensor(np.column_stack([X.ravel(), Y.ravel()]),
                               dtype=torch.float32).to(device)

    with torch.no_grad():
        # Compute densities
        rho1 = 10 * a_nn(grid_points) / (
            torch.exp(torch.sum(grid_points**2, dim=1, keepdim=True)
                     + torch.sum((b_nn(grid_points))**2, dim=1, keepdim=True)))
        rho2 = 10 * a_nn1(grid_points) / (
            torch.exp(torch.sum(grid_points**2, dim=1, keepdim=True)
                     + torch.sum((b_nn1(grid_points))**2, dim=1, keepdim=True)))
        
        # FIX: Call get_density with the entire batch at once
        rho3 = (1e-17)* get_density(grid_points, alpha)

        rho_total = rho1 + rho2 + rho3
        rho_vals = rho_total.squeeze().cpu().numpy().reshape(X.shape)
        
        # Compute Lyapunov values - also vectorized
        lyap_vals = lyapunov(grid_points).cpu().numpy().reshape(X.shape)

    # Create single plot
    fig, ax = plt.subplots(figsize=(8, 6))

    # Plot density contours
    filled_contours = ax.contourf(X, Y, rho_vals, alpha=0.3, 
                                  cmap=cm.coolwarm)
    plt.colorbar(filled_contours, ax=ax, label='Combined Density Value')

    # Draw both ROAs
    contour_density = ax.contour(X, Y, rho_vals-density_threshold, levels=0,
                                colors='black', linewidths=2, 
                                linestyles='solid', label='Density+Lyapunov ROA')
    
    contour_lyap = ax.contour(X, Y, lyap_vals, levels=[lyapunov_threshold], 
                             colors='blue', linewidths=2, 
                                linestyles='solid', label='Lyapunov ROA')
    if plot_flow:
        # Flow field
        x1_flow = np.linspace(-6, 6, 20)
        x2_flow = np.linspace(-6, 6, 20)
        X_flow, Y_flow = np.meshgrid(x1_flow, x2_flow)
        flow_points = torch.tensor(np.column_stack([X_flow.ravel(), Y_flow.ravel()]),
                                dtype=torch.float32).to(device)

        with torch.no_grad():
            rho1_flow = 10 * a_nn(flow_points) / (
                torch.exp(torch.sum(flow_points**2, dim=1, keepdim=True)
                        + torch.sum((b_nn(flow_points))**2, dim=1, keepdim=True)))
            rho2_flow = 10 * a_nn1(flow_points) / (
                torch.exp(torch.sum(flow_points**2, dim=1, keepdim=True)
                        + torch.sum((b_nn1(flow_points))**2, dim=1, keepdim=True)))
            
            # FIX: Vectorized call
            rho3_flow = (1e-17)* get_density(flow_points, alpha)

            rho_total_flow = rho1_flow + rho2_flow + rho3_flow
            w1, w2, w3 = rho1_flow / rho_total_flow, rho2_flow / rho_total_flow, rho3_flow / rho_total_flow

            u1 = c_nn(flow_points) / a_nn(flow_points)
            u2 = c_nn1(flow_points) / a_nn1(flow_points)
            
            # FIX: Vectorized call
            u3 = lyapunov_control(flow_points, device)

            u_values = w1 * u1 + w2 * u2 + w3 * u3

        DX, DY = np.zeros_like(X_flow), np.zeros_like(Y_flow)
        for i in range(len(x1_flow)):
            for j in range(len(x2_flow)):
                idx = i * len(x1_flow) + j
                x = torch.tensor([X_flow[i, j], Y_flow[i, j]], device=device)
                f_val = f(x)
                g_val = g(x)
                u = u_values[idx]
                flow = f_val + g_val * u
                DX[i, j], DY[i, j] = flow[0].cpu().numpy(), flow[1].cpu().numpy()

        magnitude = np.sqrt(DX**2 + DY**2)
        DX, DY = DX / (magnitude + 1e-8), DY / (magnitude + 1e-8)

        ax.streamplot(X_flow, Y_flow, DX, DY, color='gray',
                     linewidth=0.5, density=1.0,
                     arrowstyle='-|>', arrowsize=1.5)

    # Valid region circle
    circle = Circle((0, 0), 6, color='red', fill=False, 
                   linewidth=2, linestyle='--', label='Valid Region')
    ax.add_artist(circle)

    ax.set_xlabel('Angle', fontsize=12)
    ax.set_ylabel('Anglular velocity', fontsize=12)
    ax.set_title('Inverted Pendulum', fontsize=14, fontweight='bold')
    
    # Create custom legend
    from matplotlib.lines import Line2D
    legend_elements = [
        Line2D([0], [0], color='black', linewidth=3, linestyle='-', label='Density+Lyapunov'),
        Line2D([0], [0], color='magenta', linewidth=3, linestyle='-', label='Lyapunov'),
        Line2D([0], [0], color='red', linewidth=2, linestyle='--', label='Valid Region')
    ]
    ax.legend(handles=legend_elements, loc='upper right', fontsize=11)
    
    ax.grid(True, alpha=0.3)
    ax.set_aspect('equal')

    plt.tight_layout()
    plt.show()

    return fig, ax

# %%
# 2. Combined plot (similar to your reference image)
fig, ax = plot_combined_roa(a_net, b_net, c_net, a_net1, b_net1, c_net1, 
                           device, alpha=0.005, 
                           density_threshold=5e-8, 
                           lyapunov_threshold=0.11)
# Out:
# /tmp/ipykernel_3764329/1457647083.py:52: UserWarning: The following kwargs were not used by contour: 'label'
#   contour_density = ax.contour(X, Y, rho_vals-density_threshold, levels=0,
# /tmp/ipykernel_3764329/1457647083.py:56: UserWarning: The following kwargs were not used by contour: 'label'
#   contour_lyap = ax.contour(X, Y, lyap_vals, levels=[lyapunov_threshold],
